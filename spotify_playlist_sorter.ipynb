# %% [markdown]
# # Spotify Playlist Sorter (with songdata.io)
#
# This notebook implements a `SpotifyPlaylistSorter` class to sort music playlists based on:
# - Harmonic mixing (Camelot keys)
# - BPM (Tempo)
# - Energy levels
#
# **How it works:**
# - Uses **songdata.io** for track analysis data (Key, BPM, Energy) instead of local audio analysis.
# - Scrapes data from songdata.io using BeautifulSoup.
# - The user **selects the starting (anchor) track** manually.
#
# ## Prerequisites
# 1.  Run `spotify_auth.ipynb` first to set up authentication and get playlist ids.
# 2.  Have your playlist ID ready.
#
# ## Features
# - Loads playlist metadata from Spotify.
# - **Scrapes track data** from songdata.io to get Key, BPM, and Energy.
# - Builds a Camelot wheel neighbor map.
# - Allows the user to select the starting anchor track.
# - Sorts the playlist by finding the best transitions based on Key, BPM, and Energy.
# - Compares the original and sorted order.
# - Updates the playlist order on Spotify (with confirmation).

# %%
import os
import base64
import json
import requests
from dotenv import load_dotenv
import spotipy
import pandas as pd
import numpy as np
from typing import List, Dict, Optional
import time
import logging
from bs4 import BeautifulSoup

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

# Load environment variables
load_dotenv()

# Get Spotify credentials
CLIENT_ID = os.getenv('SPOTIFY_CLIENT_ID')
CLIENT_SECRET = os.getenv('SPOTIFY_CLIENT_SECRET')
REDIRECT_URI = 'http://127.0.0.1:8888/callback' # Or your configured URI

# Set up authentication scope
SCOPE = "playlist-modify-public playlist-modify-private playlist-read-private playlist-read-collaborative"

# Try to load cached token if it exists
try:
    with open('.spotify_cache', 'r') as f:
        token_info = json.load(f)
        access_token = token_info['access_token']
        logging.info("Using cached token")
        # Initialize Spotify client with cached token
        sp = spotipy.Spotify(auth=access_token)

        # Test if token is still valid
        try:
            sp.current_user()
            logging.info("Token is valid")
        except spotipy.exceptions.SpotifyException as e:
            if e.http_status == 401: # Token expired
                 logging.warning("Cached token expired, attempting refresh...")
                 # If refresh token exists, try to refresh
                 if 'refresh_token' in token_info:
                     refresh_token = token_info['refresh_token']
                     # Refresh the token
                     token_url = 'https://accounts.spotify.com/api/token'
                     auth_header = base64.b64encode(f"{CLIENT_ID}:{CLIENT_SECRET}".encode()).decode()

                     refresh_data = {
                         'grant_type': 'refresh_token',
                         'refresh_token': refresh_token
                     }

                     headers = {
                         'Authorization': f'Basic {auth_header}',
                         'Content-Type': 'application/x-www-form-urlencoded'
                     }

                     refresh_response = requests.post(token_url, data=refresh_data, headers=headers)

                     if refresh_response.status_code == 200:
                         new_token_info = refresh_response.json()
                         # Preserve the refresh token if not returned by Spotify
                         if 'refresh_token' not in new_token_info:
                             new_token_info['refresh_token'] = refresh_token

                         # Update cache file
                         with open('.spotify_cache', 'w') as f_write:
                             json.dump(new_token_info, f_write)

                         access_token = new_token_info['access_token']
                         sp = spotipy.Spotify(auth=access_token)
                         logging.info("Token refreshed successfully")
                     else:
                         logging.error(f"Failed to refresh token ({refresh_response.status_code}): {refresh_response.text}")
                         raise Exception("Failed to refresh token, need to re-authenticate")
                 else:
                     raise Exception("Cached token expired and no refresh token available, need to re-authenticate")
            else: # Other Spotify API error
                 raise e # Re-raise other errors

except (FileNotFoundError):
    logging.error("Authentication required: .spotify_cache file not found.")
    logging.error("Please run spotify_auth.ipynb first to authenticate with Spotify.")
    raise Exception("Authentication required. Run spotify_auth.ipynb first.")
except Exception as e:
    logging.error(f"An error occurred during authentication setup: {str(e)}")
    raise Exception(f"Authentication failed: {str(e)}")
# Out:
# INFO: Using cached token
# INFO: Token is valid

# %%
class SpotifyPlaylistSorter:
    def __init__(self, playlist_id: str):
        self.playlist_id = playlist_id
        self.sp = sp # Assumes 'sp' is the authenticated spotipy client
        self.tracks_data = None
        self.camelot_map = self._build_camelot_map()
        self.playlist_name = None
        self.original_track_order = None

    def _build_camelot_map(self) -> Dict[str, List[str]]:
        """Build a map of compatible Camelot keys."""
        camelot_map = {}
        numbers = range(1, 13)
        letters = ['A', 'B']

        for num in numbers:
            for letter in letters:
                key = f"{num}{letter}"
                neighbors = []

                # Same number, different letter (switching between minor/major)
                other_letter = 'B' if letter == 'A' else 'A'
                neighbors.append(f"{num}{other_letter}")

                # Same letter, adjacent numbers
                prev_num = 12 if num == 1 else num - 1
                next_num = 1 if num == 12 else num + 1
                neighbors.extend([f"{prev_num}{letter}", f"{next_num}{letter}"])

                camelot_map[key] = neighbors

        return camelot_map

    def _scrape_songdata_io(self) -> Optional[pd.DataFrame]:
        """Scrape track data from songdata.io for the playlist."""
        url = f"https://songdata.io/playlist/{self.playlist_id}"
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        logging.info(f"Attempting to scrape data from: {url}")

        try:
            response = requests.get(url, headers=headers, timeout=30)
            response.raise_for_status()
        except requests.exceptions.RequestException as e:
            logging.error(f"Failed to fetch data from songdata.io: {e}")
            return None

        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the table - adjust selector if songdata.io changes structure
        table = soup.find('table', id='table_chart')
        if not table:
            logging.error("Could not find the track table (id='table_chart') on the page.")
            logging.error("The website structure might have changed.")
            # Try finding by class as a fallback
            table = soup.find('table', class_='table')
            if not table:
                 logging.error("Could not find the track table by class either.")
                 return None
            else:
                 logging.warning("Found table using class='table' as fallback.")

        table_body = table.find('tbody', id='table_body')
        if not table_body:
            # Fallback if tbody doesn't have the specific ID
            table_body = table.find('tbody')
            if not table_body:
                logging.error("Could not find the table body (tbody) within the table.")
                return None
            else:
                logging.warning("Found tbody without specific ID.")

        tracks = []
        rows = table_body.find_all('tr', class_='table_object')

        if not rows:
             logging.error("Found table body, but no rows with class='table_object'.")
             return None

        logging.info(f"Found {len(rows)} potential track rows in the table.")

        for row in rows:
            try:
                # Extract data based on common class names (inspect songdata.io for accuracy)
                track_name_tag = row.find('td', class_='table_name')
                track_name = track_name_tag.find('a').text.strip() if track_name_tag and track_name_tag.find('a') else None

                artist_tag = row.find('td', class_='table_artist')
                artist = artist_tag.text.strip() if artist_tag else None

                key_tag = row.find('td', class_='table_key')
                key = key_tag.text.strip() if key_tag else None

                camelot_tag = row.find('td', class_='table_camelot')
                camelot = camelot_tag.text.strip() if camelot_tag else None

                bpm_tag = row.find('td', class_='table_bpm')
                bpm = bpm_tag.text.strip() if bpm_tag else None

                energy_tag = row.find('td', class_='table_energy')
                energy = energy_tag.text.strip() if energy_tag else None

                # Popularity is often in 'table_data' but might need specific identification
                all_data_tags = row.find_all('td', class_='table_data')
                popularity = None
                if len(all_data_tags) > 5:
                    release_date_tag = row.find('td', class_='table_data', string=lambda t: t and ('-' in t or '/' in t))
                    if release_date_tag:
                        prev_sibling = release_date_tag.find_previous_sibling('td', class_='table_data')
                        if prev_sibling:
                            popularity = prev_sibling.text.strip()

                # Spotify ID is usually in a data-src attribute
                spotify_link_cell = row.find('td', id='spotify_obj')
                spotify_id = spotify_link_cell['data-src'].strip() if spotify_link_cell and 'data-src' in spotify_link_cell.attrs else None

                if not all([track_name, artist, camelot, bpm, energy, spotify_id]):
                     logging.warning(f"Skipping row due to missing essential data (Name, Artist, Camelot, BPM, Energy, ID): {track_name}, {artist}")
                     continue

                tracks.append({
                    'id': spotify_id,
                    'Track': track_name,
                    'Artist': artist,
                    'Key': key,
                    'Camelot': camelot,
                    'BPM': bpm,
                    'Energy': energy,
                    'Popularity': popularity
                })
            except Exception as e:
                logging.warning(f"Error parsing a row: {e}. Row content: {row.text[:100]}...")
                continue

        if not tracks:
            logging.error("No tracks successfully parsed from the table.")
            return None

        df = pd.DataFrame(tracks)

        # --- Data Cleaning and Type Conversion ---
        try:
            # Convert relevant columns to numeric, coercing errors to NaN
            df['BPM'] = pd.to_numeric(df['BPM'], errors='coerce')
            # Energy from songdata.io might be 1-10 scale or 0-1. Let's assume 0-1 for now.
            raw_energy = pd.to_numeric(df['Energy'], errors='coerce')
            if raw_energy.max() > 1.0:
                 logging.warning("Detected Energy values > 1. Assuming 1-10 scale and normalizing to 0-1.")
                 df['Energy'] = raw_energy / 10.0
            else:
                 df['Energy'] = raw_energy

            df['Popularity'] = pd.to_numeric(df['Popularity'], errors='coerce')

            # Validate Camelot format (e.g., '1A', '12B')
            df['Camelot'] = df['Camelot'].str.upper()
            valid_camelot_mask = df['Camelot'].str.match(r'^[1-9]A$|^1[0-2]A$|^[1-9]B$|^1[0-2]B$', na=False)
            invalid_camelot = df[~valid_camelot_mask]['Camelot'].unique()
            if len(invalid_camelot) > 0:
                logging.warning(f"Found potentially invalid Camelot keys: {invalid_camelot}. Replacing with NaN.")
                df.loc[~valid_camelot_mask, 'Camelot'] = np.nan

        except Exception as e:
            logging.error(f"Error during data type conversion: {e}")

        logging.info(f"Successfully scraped and parsed {len(df)} tracks.")
        return df

    def load_playlist(self):
        """Load playlist name from Spotify and track data by scraping songdata.io."""
        logging.info(f"Loading playlist metadata for: {self.playlist_id}")
        try:
            # Get playlist name from Spotify (more reliable than scraping)
            playlist_info = self.sp.playlist(self.playlist_id, fields="name")
            self.playlist_name = playlist_info['name']
            logging.info(f"Playlist Name (from Spotify): '{self.playlist_name}'")
        except Exception as e:
            logging.warning(f"Failed to get playlist name from Spotify: {e}. Will proceed without it.")
            self.playlist_name = f"Playlist {self.playlist_id}"

        # Scrape track data from songdata.io
        scraped_data = self._scrape_songdata_io()

        if scraped_data is None or scraped_data.empty:
            logging.error("Failed to scrape data from songdata.io. Cannot proceed.")
            self.tracks_data = pd.DataFrame()
            self.original_track_order = []
            return None
        else:
            self.tracks_data = scraped_data
            # Store original order based on scraped table
            self.original_track_order = self.tracks_data['id'].tolist()
            logging.info(f"Using original track order based on songdata.io table ({len(self.original_track_order)} tracks).")

            # Ensure required columns exist even if scraping missed some
            for col in ['id', 'Track', 'Artist', 'Camelot', 'BPM', 'Energy', 'Popularity']:
                 if col not in self.tracks_data.columns:
                     self.tracks_data[col] = np.nan

            # Drop rows where essential sorting keys are missing AFTER scraping
            initial_count = len(self.tracks_data)
            self.tracks_data.dropna(subset=['id', 'Camelot', 'BPM', 'Energy'], inplace=True)
            dropped_count = initial_count - len(self.tracks_data)
            if dropped_count > 0:
                logging.warning(f"Dropped {dropped_count} tracks due to missing essential data (ID, Camelot, BPM, or Energy) after scraping.")

            if self.tracks_data.empty:
                 logging.error("No tracks remaining after dropping those with missing essential data.")
                 return None

        return self.tracks_data

    def calculate_transition_score(self, track1: pd.Series, track2: pd.Series) -> float:
        """Calculate transition score between two tracks using scraped data."""
        # --- Key Compatibility ---
        key1 = track1.get('Camelot')
        key2 = track2.get('Camelot')

        if pd.isna(key1) or pd.isna(key2) or key1 not in self.camelot_map:
            key_compatible = False
            key_multiplier = 0.5
            if key1 not in self.camelot_map and not pd.isna(key1):
                 logging.debug(f"Key {key1} not in camelot map for score calc.")
        else:
            key_compatible = key2 in self.camelot_map[key1]
            key_multiplier = 1.5 if key_compatible else 0.5

        # --- BPM Difference Score ---
        bpm1 = track1.get('BPM')
        bpm2 = track2.get('BPM')
        if pd.isna(bpm1) or pd.isna(bpm2):
            bpm_score = 0.0
            bpm_diff = float('inf')
        else:
            bpm_diff = abs(bpm1 - bpm2)
            bpm_score = max(0, 1 - (bpm_diff / 20.0))

        # --- Energy Transition Score ---
        energy1 = track1.get('Energy')
        energy2 = track2.get('Energy')
        if pd.isna(energy1) or pd.isna(energy2):
             energy_score = 0.5
        else:
            energy_diff = energy2 - energy1
            if energy_diff >= -0.1:
                energy_score = max(0, 1 - abs(energy_diff) * 0.5)
            else:
                energy_score = max(0, 1 - abs(energy_diff) * 1.5)

        # --- Combine Scores ---
        base_score = (bpm_score * 0.6) + (energy_score * 0.4)
        final_score = base_score * key_multiplier

        # --- Optional Bonuses ---
        if key_compatible and key1 == key2:
             final_score *= 1.1

        if bpm_diff <= 3:
             final_score *= 1.1

        return final_score

    def sort_playlist(self, start_track_id: str) -> List[str]:
        """Sort the playlist using transition scores, starting from anchor."""
        if self.tracks_data is None or self.tracks_data.empty:
            logging.error("Track data is not loaded or is empty. Cannot sort.")
            return []

        sortable_tracks = self.tracks_data.copy()

        if start_track_id not in sortable_tracks['id'].values:
             logging.error(f"Start track ID '{start_track_id}' not found in the loaded & filtered tracks.")
             if self.original_track_order and start_track_id in self.original_track_order:
                  logging.warning("Anchor track was present initially but filtered out due to missing data. Cannot use as anchor.")
             return []

        logging.info(f"Starting sort with anchor track ID: {start_track_id}")
        current_id = start_track_id
        sorted_ids = [current_id]
        remaining_tracks = sortable_tracks.set_index('id', drop=False)
        remaining_tracks = remaining_tracks.drop(current_id)

        while not remaining_tracks.empty:
            current_track_data = sortable_tracks[sortable_tracks['id'] == current_id]
            if current_track_data.empty:
                 logging.error(f"Could not find data for current track ID: {current_id}. Stopping sort.")
                 break
            current_track = current_track_data.iloc[0]

            scores = remaining_tracks.apply(
                lambda x: self.calculate_transition_score(current_track, x),
                axis=1
            )

            if scores.empty or scores.isna().all():
                logging.warning(f"Could not calculate valid scores from {current_track.get('Track', current_id)}. Stopping sort.")
                break

            next_track_idx = scores.idxmax()
            next_track = remaining_tracks.loc[next_track_idx]

            sorted_ids.append(next_track['id'])
            remaining_tracks = remaining_tracks.drop(next_track_idx)

            current_id = next_track['id']
            logging.debug(f"Added: {next_track.get('Track', current_id)} (Score: {scores.loc[next_track_idx]:.2f})")

        original_ids_set = set(self.original_track_order) if self.original_track_order else set()
        sorted_ids_set = set(sorted_ids)
        initial_sortable_ids = set(sortable_tracks['id'])
        missing_from_sort = list(initial_sortable_ids - sorted_ids_set)

        if missing_from_sort:
             logging.warning(f"Sort finished, but {len(missing_from_sort)} tracks that had data were not placed.")
             missing_tracks_ordered = [tid for tid in self.original_track_order if tid in missing_from_sort]
             logging.info(f"Appending {len(missing_tracks_ordered)} tracks that were not placed during sorting.")
             sorted_ids.extend(missing_tracks_ordered)
        elif len(sorted_ids) < len(initial_sortable_ids):
             logging.warning(f"Sorting ended with {len(sorted_ids)} tracks, but started with {len(initial_sortable_ids)} sortable tracks.")

        logging.info(f"Playlist sorting complete. Final track count: {len(sorted_ids)}")
        return sorted_ids

    def compare_playlists(self, sorted_ids: List[str]):
        """Compare original (scraped order) and sorted playlist."""
        if self.tracks_data is None or self.tracks_data.empty or not self.original_track_order:
            logging.error("Cannot compare playlists: Data not loaded or original order missing.")
            return pd.DataFrame(), pd.DataFrame()

        compare_df = self.tracks_data.copy()
        valid_original_ids = [tid for tid in self.original_track_order if tid in compare_df['id'].values]
        valid_sorted_ids = [tid for tid in sorted_ids if tid in compare_df['id'].values]

        if not valid_original_ids or not valid_sorted_ids:
             logging.error("No valid track data found for comparison after filtering.")
             return pd.DataFrame(), pd.DataFrame()

        original_df = compare_df.set_index('id').loc[valid_original_ids].reset_index()
        sorted_df = compare_df.set_index('id').loc[valid_sorted_ids].reset_index()

        original_df['Position'] = range(1, len(original_df) + 1)
        sorted_df['Position'] = range(1, len(sorted_df) + 1)

        position_map = {id_val: pos for pos, id_val in enumerate(valid_original_ids, 1)}
        sorted_df['Original Position'] = sorted_df['id'].map(position_map)
        sorted_df['Original Position'] = sorted_df['Original Position'].fillna('N/A')

        sorted_df['Position'] = pd.to_numeric(sorted_df['Position'], errors='coerce')
        sorted_df['Original Position'] = pd.to_numeric(sorted_df['Original Position'], errors='coerce')

        sorted_df['Position Change'] = sorted_df.apply(
            lambda row: row['Original Position'] - row['Position'] if pd.notna(row['Original Position']) and pd.notna(row['Position']) else np.nan,
            axis=1
        )

        return original_df, sorted_df

    def _get_track_uris(self, track_ids: List[str]) -> Dict[str, str]:
        """Fetch Spotify URIs for a list of track IDs."""
        uri_map = {}
        if not track_ids:
            return uri_map

        for i in range(0, len(track_ids), 50):
            batch_ids = track_ids[i:i+50]
            try:
                results = self.sp.tracks(tracks=batch_ids)
                for track in results['tracks']:
                    if track and track['id'] and track['uri']:
                        uri_map[track['id']] = track['uri']
                    elif track and track['id']:
                         logging.warning(f"Could not find URI for track ID: {track['id']}")
            except Exception as e:
                logging.error(f"Failed to fetch track details batch (starting index {i}): {e}")
            time.sleep(0.5)

        return uri_map

    def update_spotify_playlist(self, sorted_ids: List[str]):
        """Update the Spotify playlist with the new track order."""
        if not sorted_ids:
             logging.error("No sorted track IDs provided to update playlist.")
             return
        if self.tracks_data is None or self.tracks_data.empty:
             logging.error("No track data available to map IDs to URIs.")
             return

        logging.info(f"Fetching URIs for {len(sorted_ids)} sorted tracks...")
        uri_map = self._get_track_uris(sorted_ids)

        track_uris = [uri_map[track_id] for track_id in sorted_ids if track_id in uri_map]

        if not track_uris:
            logging.error("No valid track URIs could be fetched for the sorted IDs. Cannot update playlist.")
            return

        if len(track_uris) != len(sorted_ids):
             logging.warning(f"Could only find URIs for {len(track_uris)} out of {len(sorted_ids)} tracks. Playlist will be updated with available tracks.")

        logging.info(f"Updating Spotify playlist '{self.playlist_name}' with {len(track_uris)} tracks.")

        try:
            self.sp.playlist_replace_items(self.playlist_id, track_uris[:100])
            logging.info(f"Replaced/set first {min(len(track_uris), 100)} tracks.")

            for i in range(100, len(track_uris), 100):
                batch = track_uris[i:i+100]
                self.sp.playlist_add_items(self.playlist_id, batch)
                logging.info(f"Added batch of {len(batch)} tracks (starting index {i}).")
                time.sleep(1)

            logging.info(f"Successfully updated playlist '{self.playlist_name}' order on Spotify!")

        except Exception as e:
            logging.error(f"Failed to update Spotify playlist: {e}")
            logging.error("Check API permissions (scope), rate limits, and playlist ownership.")

    def print_transition_analysis(self, sorted_ids: List[str]):
        """Print analysis of the transitions in the sorted playlist."""
        if self.tracks_data is None or self.tracks_data.empty:
             logging.warning("No track data to analyze transitions.")
             return

        print("\nTransition Analysis:")
        print("-" * 80)

        if len(sorted_ids) < 2:
             print("Not enough tracks for transition analysis.")
             return

        track_map = self.tracks_data.set_index('id').to_dict('index')

        total_score = 0
        valid_transitions = 0

        for i in range(len(sorted_ids) - 1):
            track1_id = sorted_ids[i]
            track2_id = sorted_ids[i+1]

            track1_data = track_map.get(track1_id)
            track2_data = track_map.get(track2_id)

            if not track1_data or not track2_data:
                 print(f"\nSkipping transition {i+1}: Track data missing in final map for {track1_id or 'N/A'} or {track2_id or 'N/A'}")
                 continue

            track1 = pd.Series(track1_data, name=track1_id)
            track2 = pd.Series(track2_data, name=track2_id)

            has_essential_data = not pd.isna(track1.get('Camelot')) and not pd.isna(track1.get('BPM')) and not pd.isna(track1.get('Energy')) and \
                                 not pd.isna(track2.get('Camelot')) and not pd.isna(track2.get('BPM')) and not pd.isna(track2.get('Energy'))

            print(f"\n{i+1}. {track1.get('Track', track1_id)} → {track2.get('Track', track2_id)}")

            if has_essential_data:
                score = self.calculate_transition_score(track1, track2)
                key_compatible = False
                key1_camelot = track1.get('Camelot')
                key2_camelot = track2.get('Camelot')
                if key1_camelot and key1_camelot in self.camelot_map:
                     key_compatible = key2_camelot in self.camelot_map[key1_camelot]

                bpm1 = track1.get('BPM', np.nan)
                bpm2 = track2.get('BPM', np.nan)
                energy1 = track1.get('Energy', np.nan)
                energy2 = track2.get('Energy', np.nan)

                print(f"   Camelot: {key1_camelot or 'N/A'} → {key2_camelot or 'N/A'} ({'✓ Compatible' if key_compatible else '✗ Incompatible'}) ({'Perfect Match' if key1_camelot == key2_camelot and key1_camelot else ''})")
                print(f"   BPM:     {int(bpm1) if pd.notna(bpm1) else 'N/A'} → {int(bpm2) if pd.notna(bpm2) else 'N/A'} (Δ{abs(int(bpm1) - int(bpm2)) if pd.notna(bpm1) and pd.notna(bpm2) else 'N/A'})")
                energy1_str = f"{energy1:.2f}" if pd.notna(energy1) else 'N/A',
                energy2_str = f"{energy2:.2f}" if pd.notna(energy2) else 'N/A',
                energy_diff = f"{energy2 - energy1:.2f}" if pd.notna(energy1) and pd.notna(energy2) else 'N/A',
                print(f"   Energy:  {energy1_str} → {energy2_str} (Δ{energy_diff})")
                print(f"   Score:   {score:.2f}")
                total_score += score
                valid_transitions += 1
            else:
                 print(f"   Camelot: {track1.get('Camelot', 'N/A')} → {track2.get('Camelot', 'N/A')}")
                 print(f"   BPM:     {track1.get('BPM', 'N/A')} → {track2.get('BPM', 'N/A')}")
                 print(f"   Energy:  {track1.get('Energy', 'N/A')} → {track2.get('Energy', 'N/A')}")
                 print("   (Skipping score: Missing essential data for one or both tracks)")

        if valid_transitions > 0:
             average_score = total_score / valid_transitions
             print("-" * 80)
             print(f"Average Transition Score (for {valid_transitions} scored transitions): {average_score:.2f}")
        else:
             print("-" * 80)
             print("No valid transitions could be scored (check scraped data).")
        print("-" * 80)

# %%
# --- Configuration ---
# Enter your playlist ID here
PLAYLIST_ID = "5yivZ4ZtnHZv2lyTsnSt0d" # <--- Use your actual Playlist ID

# --- Create Sorter Instance ---
sorter = SpotifyPlaylistSorter(PLAYLIST_ID)

# --- Load Playlist Data (now uses scraping) ---
print("Loading playlist name from Spotify and scraping track data from songdata.io...")
print("\nDisclaimer: This process relies on scraping songdata.io.")
print("If the website structure changes, this script may fail to retrieve data.")

tracks_df = sorter.load_playlist()

if tracks_df is None or tracks_df.empty:
    print("\nFailed to load or scrape track data. Exiting.")
    print("Please check: Playlist ID, Spotify authentication, internet connection, and potential changes to songdata.io.")
    # exit() # Uncomment to stop execution on failure
else:
    print(f"\nLoaded data for {len(tracks_df)} tracks for playlist: {sorter.playlist_name}")
    print("\nSample tracks (with scraped features):")
    # Display relevant columns, handling potential missing ones
    display_cols = ['Track', 'Artist', 'Camelot', 'BPM', 'Energy', 'Popularity']
    display_df = tracks_df[display_cols].dropna(subset=display_cols)
    print(display_df.head(10))
# Out:
# INFO: Loading playlist metadata for: 5yivZ4ZtnHZv2lyTsnSt0d
# Loading playlist name from Spotify and scraping track data from songdata.io...
#
# Disclaimer: This process relies on scraping songdata.io.
# If the website structure changes, this script may fail to retrieve data.
# INFO: Playlist Name (from Spotify): 'Simply Bollywood (2000 - 2025)'
# INFO: Attempting to scrape data from: https://songdata.io/playlist/5yivZ4ZtnHZv2lyTsnSt0d
# INFO: Found 321 potential track rows in the table.
# WARNING: Detected Energy values > 1. Assuming 1-10 scale and normalizing to 0-1.
# INFO: Successfully scraped and parsed 321 tracks.
# INFO: Using original track order based on songdata.io table (321 tracks).
# Loaded data for 321 tracks for playlist: Simply Bollywood (2000 - 2025)
#
# Sample tracks (with scraped features):
#                                Track  \
# 0     Javeda Zindagi-Tose Naina Lage
# 1            Yaariyaan - Male Vocals
# 2                        Zaroori Tha
# 3  Ek Dil Ek Jaan (From "Padmaavat")
# 4                             Sajdaa
# 5                               Ravi
# 6                        Jiyein Kyun
# 7                      Shukran Allah
# 8     Ghodey Pe Sawaar (From "Qala")
# 9                      Labb Par Aaye
#
#                                               Artist Camelot  BPM  Energy  \
# 0                          Kshitij Tarey, Shilpa Rao     12A  130     0.6
# 1                                       Mohan Kannan      9B  130     0.8
# 2                               Rahat Fateh Ali Khan      1A  114     0.7
# 3               Shivam Pathak, Sanjay Leela Bhansali     10B   98     0.7
# 4  Shankar-Ehsaan-Loy, Rahat Fateh Ali Khan, Shan...      4B   80     0.7
# 5                                         Sajjad Ali      4B  128     0.6
# 6                                      Pritam, Papon     12B   71     0.6
# 7  Salim–Sulaiman, Sonu Nigam, Shreya Ghoshal, Sa...      3B   82     0.7
# 8  Amit Trivedi, Amitabh Bhattacharya, Sireesha B...      5B  102     0.5
# 9                      Shankar-Ehsaan-Loy, Javed Ali     10A  133     0.5
#
#    Popularity
# 0      0.0970
# 1      0.0386
# 2      0.1390
# 3      0.1210
# 4      0.0655
# 5      0.1200
# 6      0.1070
# 7      0.1530
# 8      0.2650
# 9      0.3770

# %%
# --- Ask User for Anchor Track ---
print("\n" + "="*30 + " Select Anchor Track " + "="*30)
print("Please choose the first track for your sorted playlist.")
print("Available Tracks (from scraped data):")

# Display tracks with index for easier selection
if not tracks_df.empty:
    # Create a numbered list of tracks
    print("\nTrack List:")
    print("-" * 100)
    print(f"{'#':<4} {'Track':<50} {'Artist':<40} {'ID':<30}")
    print("-" * 100)
    for idx, row in tracks_df.iterrows():
        print(f"{idx+1:<4} {row['Track'][:47]:<50} {row['Artist'][:37]:<40} {row['id']}")
    print("-" * 100)
else:
    print("(No tracks available after loading/filtering)")
    exit() # Exit if no tracks are available to select from

anchor_track_id = None
while True:
    try:
        selection = input("\nEnter the track number (1-{}) or ID of the track you want to start with: ".format(len(tracks_df))).strip()
        
        # Check if user entered a number
        if selection.isdigit():
            track_num = int(selection)
            if 1 <= track_num <= len(tracks_df):
                anchor_track_id = tracks_df.iloc[track_num-1]['id']
                break
            else:
                print(f"Please enter a number between 1 and {len(tracks_df)}.")
        # Check if user entered a track ID
        elif selection in tracks_df['id'].values:
            anchor_track_id = selection
            break
        else:
            print("Invalid selection. Please enter either a track number or a valid track ID.")
    except ValueError:
        print("Please enter a valid number or track ID.")

selected_track = tracks_df[tracks_df['id'] == anchor_track_id].iloc[0]
print(f"\nSelected '{selected_track['Track']}' by {selected_track['Artist']} as the anchor track.")
print("="*80)

# --- Sort the Playlist ---
print("\nSorting playlist based on transitions...")
sorted_ids = sorter.sort_playlist(start_track_id=anchor_track_id)

if not sorted_ids:
     print("Sorting failed. Please check logs for errors.")
     # exit()
else:
    # --- Print Transition Analysis ---
    sorter.print_transition_analysis(sorted_ids)
# Out:
# ============================== Select Anchor Track ==============================
# Please choose the first track for your sorted playlist.
# Available Tracks (from scraped data):
#
# Track List:
# ----------------------------------------------------------------------------------------------------
# #    Track                                              Artist                                   ID
# ----------------------------------------------------------------------------------------------------
# 1    Javeda Zindagi-Tose Naina Lage                     Kshitij Tarey, Shilpa Rao                04FnSzoogJD1iQbghug23K
# 2    Yaariyaan - Male Vocals                            Mohan Kannan                             0EiZCuVOP3E9MobSidssSC
# 3    Zaroori Tha                                        Rahat Fateh Ali Khan                     0JChw6k59cZxegh0SGceE1
# 4    Ek Dil Ek Jaan (From "Padmaavat")                  Shivam Pathak, Sanjay Leela Bhansali     0M9UxL5CebtmlijPMH6KfW
# 5    Sajdaa                                             Shankar-Ehsaan-Loy, Rahat Fateh Ali K    0Qa9pTZLUC95wJCHGYMIg4
# 6    Ravi                                               Sajjad Ali                               0sT56zcByY6pW1EQcNDCla
# 7    Jiyein Kyun                                        Pritam, Papon                            0up9rhm9qt2LW7cnoDFCMk
# 8    Shukran Allah                                      Salim–Sulaiman, Sonu Nigam, Shreya Gh    0voD3biKAPCQsWrg5jKDzz
# 9    Ghodey Pe Sawaar (From "Qala")                     Amit Trivedi, Amitabh Bhattacharya, S    1a8w8nlIyIhE2W1HIayKnl
# 10   Labb Par Aaye                                      Shankar-Ehsaan-Loy, Javed Ali            1H31HxfIHETvrQ02nWpsLO
# 11   Saware                                             Pritam, Arijit Singh                     1juJ3mwsFerctbngtK42G4
# 12   Phir Se Ud Chala                                   Mohit Chauhan                            1kcV2LJxt5v0s2cEGtEJ5i
# 13   Abhi Kuch Dino Se                                  Pritam, Mohit Chauhan                    1QufGJee7k9v4Cfp2NxXbv
# 14   Nazm Nazm                                          Arko                                     1tCduDqB3J8r90FAxprLzO
# 15   Tum Tak                                            A.R. Rahman, Javed Ali, KIRTI SAGATHI    1wnozUBSe7OMpmZiTPJC5j
# 16   Naina Da Kya Kasoor                                Amit Trivedi                             2g3o6I7YuKFEUn9OOfuAfP
# 17   Milne Hai Mujhse Aayi                              Arijit Singh                             2iGnFW7m517taq3AJIE6DK
# 18   Teri Deewani                                       Kailash Kher, Paresh Kamath, Naresh K    2iNqdCchlUZEgjJbQyZf8T
# 19   Tujh Mein Rab Dikhta Hai                           Roop Kumar Rathod                        2LcXJP95e4HKydTZ2mYfrx
# 20   Kaun Mera                                          Papon                                    2n40kGcCG499ckQwYNJnWp
# 21   Deewana Kar Raha Hai                               Javed Ali                                2tva3nN2kQhBjHMC7Zlty6
# 22   Haule Haule                                        Sukhwinder Singh                         2UKK9UEbKlykbmLVP1zWIQ
# 23   Hua Hain Aaj Pehli Baar                            Amaal Mallik, Armaan Malik, Palak Muc    2ygHwkk6BE4o1YKF2jhrFX
# 24   Teri Jhuki Nazar                                   Pritam, Shafqat Amanat Ali               3beYHVCFKzbdNjJqjKeYpM
# 25   Ay Hairathe                                        A.R. Rahman, Hariharan, Alka Yagnik,     3Bq7CnWgfvplEzGSVXUvOe
# 26   Bin Tere                                           Vishal-Shekhar, Shafqat Amanat Ali, S    3bZPdEskcnMdepwCaDSJRl
# 27   Manwa Laage                                        Shreya Ghoshal, Arijit Singh             3H43T5swYywvcdCBFiDgW6
# 28   Dil Ibaadat                                        Pritam, KK                               3Kl8p2PxVf8eAayLwTxOIm
# 29   Arziyan                                            Javed Ali, Kailash Kher                  3V80Iv04B9XAqGHbXdtRT1
# 30   Zehnaseeb                                          Vishal-Shekhar, Chinmayi Sripada, She    3xF15SqY32Mno3UUMBirhU
# 31   Abhi Abhi                                          KK, Shreya Ghoshal                       46wPnU9FUjYEm8vYLujq4i
# 32   Kabira                                             Pritam, Tochi Raina, Rekha Bhardwaj      4bD9z9qa4qg9BhryvYWB7c
# 33   Banjaara                                           Mohammed Irfan                           4eFnk661RcdOuH9ajiTO3j
# 34   Tere Bina                                          A.R. Rahman, Chinmayi, Murtuza Khan,     4FeczSomVWVyU4FW7xDeAI
# 35   Laal Ishq                                          Arijit Singh                             4hXHlAc9ZOJY5pGbdfuWsa
# 36   Kuchh Toh Hua Hai                                  Ankit Tiwari                             4S1o2eiP7oA70AJfrCVsBv
# 37   Pee Loon                                           Pritam, Mohit Chauhan, Irshad Kamil      52itZ0w0CydihB2JCZEIft
# 38   Piya O Re Piya                                     Atif Aslam, Shreya Ghoshal, Sachin-Ji    5a11x5PUFvJEadMRqtNtTr
# 39   Ali Maula                                          Salim–Sulaiman, Salim Merchant           5HpnLY6fuuYilWgbD5oIC1
# 40   Iktara                                             Amit Trivedi, Kavita Seth, Amitabh Bh    5HXYyYih9EhgJzvldwtvRp
# 41   Tu Hi Hai (Ali Zafar Version) [From "Dear Zinda    Amit Trivedi, Ali Zafar                  5m2MS952ftWD4N7Idcyh7c
# 42   Dekho Na                                           Jatin-Lalit, Sonu Nigam, Sunidhi Chau    5q0pLxhyHvZXnYxaygt2Az
# 43   Sab Tera                                           Armaan Malik, Shraddha Kapoor            5uUEytfFSWfTzu5EqZxQju
# 44   Rabba Main Toh Mar Gaya Oye                        Pritam, Rahat Fateh Ali Khan             5xRci5qoXzzJgR6ZwzXO2J
# 45   Bheegi Si Bhaagi Si                                Pritam, Mohit Chauhan, Antara Mitra      665b3Nss3OQmhTUdB5hBXw
# 46   Mera Pehla Pehla Pyaar                             KK                                       6fOrdTNuSAM219wGYwZMaO
# 47   Chale Aana (From "De De Pyaar De")                 Amaal Mallik, Armaan Malik               6vuMdb0E8buJeSHArN3dXk
# 48   Achha Lagta Hai                                    Shankar-Ehsaan-Loy, Mohit Chauhan, Sh    7dm80EBbK2JFHcQdGDvF1D
# 49   Har Kisi Ko                                        Arijit Singh, Neeti Mohan                7FPbxfwWa2gzB9ePX19I5z
# 50   Pasoori                                            Shae Gill, Ali Sethi                     7lvDsmTRXFE3dK4OjvRiWB
# 51   Aise Kyun - Ghazal Version                         Rekha Bhardwaj, Anurag Saikia, Raj Sh    02wf1NAQdIpe5S1NJYPwvB
# 52   Bulleya                                            Pritam, Amit Mishra, Shilpa Rao          0Bz7dfqPY4JOGZO3O1j8Wh
# 53   Nazar Na Lag Jaaye (From "Stree")                  Ash King, Sachin-Jigar                   0cWLJcdvM6QlOQ7UJdB4jb
# 54   Mar Jawaan                                         Shruti Pathak, Salim Merchant            0ErXZ1NMqOEFGJPQvU9OKF
# 55   Jab Se Tere Naina                                  Monty Sharma, Shaan                      0gRNu9dVzi5aC87AI1empZ
# 56   Tune Jo Na Kaha                                    Pritam, Mohit Chauhan, Sandeep Shriva    0pw3p4gf5homOkvOGOJulF
# 57   Yaaron                                             KK                                       0zFG3RWjka7dNRIRTWnXMN
# 58   Hai Rama                                           Hariharan, Swarnalatha                   0ZGicTeWpoIMpJax3NAuhn
# 59   Bahara                                             Vishal-Shekhar, Shreya Ghoshal, Sona     1gwO79MdYdumgIjxq8eCxB
# 60   Humdard                                            Arijit Singh                             1OEmd2iXU8pWG7CrKNpGUg
# 61   Kurbaan Hua                                        Salim–Sulaiman, Vishal Dadlani           1PH0yXNGtSZbL2eufpgFJ4
# 62   Sawaar Loon                                        Monali Thakur                            29YePgOxuPLfU7uZKxKf6w
# 63   Phir Mohabbat                                      Mohammed Irfan, Arijit Singh, Saim Bh    2b2HutIDmoeBnnKRWDLAtV
# 64   Ye Tune Kya Kiya                                   Pritam, Javed Bashir                     2cPUB8EOT6AfJ8oxhyoNXL
# 65   Jeena Jeena                                        Sachin-Jigar, Atif Aslam                 2GXXZFUxYg2LvG8SR0byOE
# 66   Aise Kyun                                          Anurag Saikia, Raghav Chaitanya, Raj     2sT0eosuhBEkw8dz6qFxUo
# 67   Thodi Jagah (From "Marjaavaan")                    Arijit Singh, Tanishk Bagchi             3f0wz6zcA7XkQiGm0qNF5r
# 68   Tere Bin                                           Sonu Nigam, Shreya Ghoshal               3f2iLcDhonNkn0QGeYWmK9
# 69   Bolna (From "Kapoor & Sons (Since 1921)")          Tanishk Bagchi, Arijit Singh, Asees K    3GrCQPpKqKzOcKfMAoqn82
# 70   Agar Tum Saath Ho                                  Alka Yagnik, Arijit Singh                3hkC9EHFZNQPXrtl8WPHnX
# 71   Aas Paas Khuda                                     Rahat Fateh Ali Khan                     3kuxr8U3QynLzyW82p5hYR
# 72   Naina                                              Sona Mohapatra, Armaan Malik             3SHopOL3KEJ8PFl3vJdfmF
# 73   Jeene Laga Hoon                                    Atif Aslam, Shreya Ghoshal, Sachin-Ji    3t3wsY5IdLVzB9WidegJSU
# 74   Tujhe Sochta Hoon                                  Pritam, KK                               47l2Dd3XPBLio3kjbEMyDJ
# 75   Dil Beparvah - The Dewarists, Season 5             Ankur Tewari, Prateek Kuhad, Dhruv Bh    4kXkT9HF9ZfDjuv3LIKcwJ
# 76   Tere Naina                                         Shankar-Ehsaan-Loy, Shafqat Amanat Al    4Qu8LlchmRCaPBKBArcNsA
# 77   Dil Cheez Tujhe Dedi (From "Airlift")              Ankit Tiwari, Arijit Singh               4r5KcqClOrWJupeOZYEbGx
# 78   Ae Zindagi Gale Laga Le - Take, 1                  Ilaiyaraaja, Amit Trivedi, Arijit Sin    4TkknEEgy9mpbDtSA9ZrKV
# 79   Shaayraana                                         Arijit Singh, Pritam                     4zrXk2Sj4PCJCOJ9azRZc3
# 80   Kaise Mujhe                                        Benny Dayal, Shreya Ghoshal              53DXM0bHfB7xkqJZYlksuh
# 81   Inn Lamhon Ke Daaman Mein                          A.R. Rahman, Sonu Nigam, Madhushree      53JA46jA1QroK2kQlyFlkM
# 82   Kitni Baatein                                      Shankar-Ehsaan-Loy, Sadhana Sargam, H    5933I3LO3dLvbaO1w640NV
# 83   Shubhaarambh                                       Amit Trivedi, Shruti Pathak, Divya Ku    5ckJAMv3Ixm6orTgfkmtbf
# 84   Matargashti                                        Mohit Chauhan                            5GeBgck1MU2tlIkMpsn8uT
# 85   Sunn Raha Hai                                      Ankit Tiwari                             5PvwPy5eRO8BPwpRzCHK3D
# 86   Lae Dooba                                          Sunidhi Chauhan                          5rpxVbgMMeCOLhhop1DVKj
# 87   Mann Kunto Maula                                   Sohail Sen, Shadab Faridi, Altamash F    5WZavoy8TYf5xajISfJgiZ
# 88   Pareshaan                                          Amit Trivedi, Shalmali Kholgade, Kaus    5XXJqs7f42R8PAY4Xcr0ax
# 89   Enna Sona                                          A.R. Rahman, Arijit Singh                6bdpj89aYEBjhpsenXAsmO
# 90   Phero Na Najariya                                  Amit Trivedi, Kausar Munir, Sireesha     6bngLYnL3AbtpXd7uPAMMd
# 91   Mora Saiyaan - Khamaaj                             Siddharth Slathia                        6RZlHCxxyLAEU6jXeg6Wms
# 92   Ek Din Teri Raahon                                 Javed Ali, Pritam                        6UEhNvccAc4OyEDJYB5brb
# 93   Kyun Main Jaagoon                                  Shafqat Amanat Ali                       6wsMVa2M6Ktea2UbnVoMvO
# 94   Bekhauff                                           Ram Sampath, Sona Mohapatra, Svati Ch    6ZuXwlpRARDcIrEUso25Xp
# 95   Main Dhoondne Ko Zamaane Mein                      Arijit Singh                             75p6BrziB5urmwPCeXl3y7
# 96   Raat Ke Dhai Baje                                  Suresh Wadkar, Rekha Bhardwaj, Sunidh    7F2wxrc0bHjCQbBvESQBXY
# 97   Kalank - Title Track                               Pritam, Arijit Singh                     7G5wpuR61ABrT7R1snos7C
# 98   Manmarziyan                                        Shilpa Rao, Amitabh Bhattacharya, Ami    7jVDWqBap4OmokUeCvFZo7
# 99   Kahani (From "Laal Singh Chaddha")                 Pritam, Mohan Kanan, Amitabh Bhattach    7Lcp4QlpR3RDngYejm4fmS
# 100  Aashiyan                                           Pritam, Shreya Ghoshal, Nikhil Paul G    7ttlemwytO21npSmLKqTBg
# 101  O Rangrez (From "Bhaag Milkha Bhaag")              Shankar-Ehsaan-Loy, Shreya Ghoshal, J    03Iuqy6uN1LfXBelHpgwvX
# 102  Disco Disco                                        Sachin-Jigar, Benny Dayal, Shirley Se    0bqmYMFgErHrS38mMkYZ6y
# 103  Falak Tak                                          Vishal-Shekhar, Udit Narayan, Mahalak    0IudGhdeJZwJ0Ps6ndtQDt
# 104  Main Agar Kahoon                                   Sonu Nigam, Shreya Ghoshal               0iXLwnLmLwn9y54JtBTNxY
# 105  Pardesi                                            Tochi Raina                              12cK3COq4z4MwaZyjc51zX
# 106  Jaan 'Nisaar                                       Arijit Singh                             17cYtwy8kdB6e6b2EBTn4M
# 107  Tum Mile                                           Pritam, Neeraj Shridhar                  1EjxJHY9A6LMOlvyZdwDly
# 108  Saanson Ko (From "Zid")                            Shaarib Toshi, Arijit Singh              1HzNbxPRn9onoxxeZByHYJ
# 109  Mera Mann Kehne Laga                               Falak Shabbir                            1niVgR76UPobOED5cXfADq
# 110  Hey Ya !                                           Clinton Cerejo, Shankar Mahadevan, Lo    1qTh7hzjd361hjuzeaMFWK
# 111  Maahi Ve                                           A.R. Rahman                              1sbW5E7w8tnqpYk0Frx8QG
# 112  O Saiyyan                                          Ajay-Atul, Roop Kumar Rathod             1sL8hnnZaB2Xzm1J66y4Tt
# 113  Abhi Abhi                                          KK                                       1tKhy83q8OsdcpZaX9N4Z2
# 114  Saudebazi (Encore)                                 Pritam, Javed Ali                        1tPPINau3vBP8Q89JTn0ER
# 115  Tu Hi Meri Shab Hai - From "Gangster"              Pritam, KK                               1ufeADg0jivKpOFiAv3PYg
# 116  Agar Main Kahoon                                   Shankar-Ehsaan-Loy, Alka Yagnik, Udit    2148snU4pEZT7CgankziXh
# 117  Suno- Na Sangemarmar (From "Youngistaan)           Arijit Singh                             2ESscisnKdryn50fPeHd7O
# 118  Kyun Dil Mera - From "Paharganj"                   Mohit Chauhan                            2GlZQur8CHidODl6OgMO3z
# 119  London Thumakda                                    Labh Janjua, Sonu Kakkar, Neha Kakkar    2qJAzSE6uC94oH2NRoPrGl
# 120  Kabhi Neem Neem                                    Madhushree, A.R. Rahman                  2saVO8vB4BX8kCHaZCuIIF
# 121  Tum Ko                                             Kavita Krishnamurthy                     2sf0cFFuJ8CWDft5NX0UR5
# 122  Jhoom                                              Ali Zafar                                2VR1z4g6haFyMoghNj46KB
# 123  Tere Pyaar Mein                                    Pritam, Arijit Singh, Amitabh Bhattac    2ZD4aIEepqZsdxPxLSuUhm
# 124  Teri Fariyad                                       Rekha Bhardwaj, Jagjit Singh             369oZK7hzwq2wHzRWzs9xh
# 125  Guzarish (From "Ghajini")                          Javed Ali                                39bHz64P8EIGXnoPfpYnUE
# 126  Pehli Baar                                         Sukriti Kakar, Siddharth Mahadevan       39GcR1iJpR2RX629O0zuW5
# 127  Sunn Raha Hai                                      Ankit Tiwari                             39niuc0zi6pYw2L4kLRNAh
# 128  Safar                                              Pritam, Arijit Singh                     3BpaZLc6j9cBUsvnh5kinR
# 129  Kahin To                                           Rashid Ali, Vasundhara Das               3E424W0IJS3ypZ4YOxE0Jn
# 130  Kaise Ab Kahein - From "Gutar Gu"                  Gaurav Chatterji, Aasa Singh, Hansika    3eSm4iAkLsn3BeggfiQOH9
# 131  Locha-E-Ulfat                                      Benny Dayal                              3V3QbgrOZKtFv5MXzAAdZr
# 132  Maula Mere Maula                                   Roop Kumar Rathod                        4CGBTtlrjZj7ydpV52cgB4
# 133  Yun Hi                                             Mohit Chauhan                            4EHa33GDXoVWGXYOO3cEGm
# 134  Yoon Shabnami                                      Monty Sharma, Parthiv Gohil              4GrzhbZQQc9SrU4Vo6J3WY
# 135  Sun Le Re (Reprise)                                Papon                                    4icX2FGsA6UolG5jtkKloB
# 136  Hoor                                               Atif Aslam, Sachin-Jigar                 4mjTMmz0j6Wl3GhODoPqTx
# 137  Ambarsariya                                        Sona Mohapatra                           4qRcjFkFqSpLBzcbLDt7HL
# 138  Luka Chuppi                                        A.R. Rahman, Lata Mangeshkar             500H9ENeR5AYbKU1ScK6ME
# 139  Ajab Si                                            KK                                       5FXMRdJjKq1BIX4e8Eg9mK
# 140  Tujhe Kitna Chahne Lage                            Arijit Singh                             5QtEFRYavs5S3GHtFEq7A4
# 141  Sajni (From "Laapataa Ladies")                     Ram Sampath, Arijit Singh, Prashant P    5zCnGtCl5Ac5zlFHXaZmhy
# 142  Duaa                                               Nandini Srikar, Arijit Singh             606dT4oMKQc9uDUv7ADy97
# 143  Afeemi (From "Meri Pyaari Bindu ")                 Sachin-Jigar, Sanah Moidutty, Kausar     6J31lR4ZqpRPAjOqzX5lCu
# 144  Agar Tum Saath Ho (From "Tamasha")                 Alka Yagnik, Arijit Singh                6kYoY0PhBelP64UMnhsEZx
# 145  Tadap Tadap                                        KK, Dominique                            6n6hEYHXBzWfdSzBX20ZRw
# 146  Shubhaarambh                                       Amit Trivedi, Shruti Pathak, Divya Ku    6qGCJLF0V7SuHTOOGUcDsv
# 147  Naina                                              Arijit Singh, Pritam                     6sKPX8s8UsjGYP6Wt1uwhZ
# 148  Tujhko Jo Paaya (From "Crook")                     Pritam, Mohit Chauhan                    6u3dJvZwQ9BBNUrKZ9btBW
# 149  Saibo                                              Sachin-Jigar, Shreya Ghoshal, Tochi R    6udC4b4jOSnHb9ItnXgKLR
# 150  Challa                                             A.R. Rahman, Rabbi, Gulzar               6wXPV6dNRAhFavrRaCdMXT
# 151  Tera Hone Laga Hoon                                Atif Aslam, Alisha Chinai, Pritam        0dLbrlAVPPjpPqnYfmJsWk
# 152  Bakhuda Tumhi Ho                                   Atif Aslam, Alka Yagnik, Pritam          0h73AwuEY2x44cBMOP58fO
# 153  Uff Teri Adaa                                      Shankar Mahadevan, Alyssa Mendonsa       0og9wKFGgFFNQnrBe7eisG
# 154  Behka                                              Karthik                                  0prCd0oIexRBiok6kBOeLp
# 155  Isq Risk                                           Sohail Sen, Rahat Fateh Ali Khan, Irs    0rxEPf4Y6uBmV3hkrV340a
# 156  Le Le Mazaa Le                                     Suzanne, Sowmya Raoh, Hrishikesh Kame    0V6i9XZ7NOfXQAygSaswnM
# 157  Tum Jo Aaye (From "Once Upon A Time In Mumbaai"    Rahat Fateh Ali Khan, Tulsi Kumar        0zqYmOjuMqpgUNOcO8wmKH
# 158  Raabta (Kehte Hain Khuda Ne)                       Pritam, Shreya Ghoshal, Arijit Singh     11PgL2XjsTBszhAPqttBJS
# 159  Darkhaast (feat. Arijit Singh, Sunidhi Chauhan)    Mithoon, Arijit Singh, Sunidhi Chauha    1awtp7rf6ajhGY9BgzCHeZ
# 160  Tu Hi Mera                                         Pritam, Shafqat Amanat Ali               1CVqr5LImdmJ1Upt4z08Pm
# 161  Ishq Bulaava                                       Vishal-Shekhar, Sanam Puri, Shipra Go    1fkjRQA8wXPPyxqYLbxuqy
# 162  Zaalima                                            Arijit Singh, Harshdeep Kaur             1J9vyEntJ79CppvgUxJs75
# 163  Saiyaara                                           Sohail Sen, Mohit Chauhan, Taraannum     1ocYa8PoVd5e2vPn0xHJcA
# 164  Gulabi                                             Sachin-Jigar, Priya Saraiya, Jaideep     22kRCQPyNXWZSQEcDvCmGD
# 165  Tu Har Lamha                                       Bobby-Imran, Arijit Singh                2EPOgSRhA90xWGVtNZwEv8
# 166  Laal Peeli Akhiyaan (From "Teri Baaton Mein Ais    Tanishk Bagchi, Romy, Neeraj Rajawat     2ibipg9GBEZ5YKOdskobJZ
# 167  Zaroorat                                           Mustafa Zahid                            32U1XMh3DKlm45uvpofhvY
# 168  Kabhi Kabhi Aditi                                  Rashid Ali                               3APdIdF8H0jsxSuGOqXedS
# 169  Ishq Shava                                         A.R. Rahman, Raghav, Shilpa Rao, Gulz    3RTL7zAwEu9vi5F4M9zeX1
# 170  Zindagi Do Pal Ki                                  KK                                       3s6H6UW7yPu2rsF8CGki60
# 171  Samjhawan (From "Humpty Sharma Ki Dulhania")       Jawad Ahmad, Shaarib Toshi, Arijit Si    3t3cbbcI1ktC6SjyO4NyR9
# 172  Mast Magan                                         Arijit Singh, Chinmayi                   3uL1IBFhg52VcQqOwAG01E
# 173  Te Amo (Duet)                                      Pritam, Ash King, Sunidhi Chauhan        3x55c9UVpbURc2T02DLfEM
# 174  Sanam Re (From "Sanam Re")                         Mithoon, Arijit Singh                    3XWBGyt7m2rZAjEj0awWnw
# 175  Tere Hawaale (From "Laal Singh Chaddha")           Pritam, Arijit Singh, Shilpa Rao         4blqlsA1uf2d2I40E90EUC
# 176  Wajah Tum Ho                                       Armaan Malik, Baman, Manoj Muntashir     4RzaXbufKNBwaFuzJhGur5
# 177  Noor E Khuda                                       Shankar-Ehsaan-Loy, Adnan Sami, Shank    4vvRbYRN13s4qRfxPnsNbc
# 178  Galliyan (From "Ek Villain")                       Ankit Tiwari                             517bz7zkWELmyL4eZzJ5R9
# 179  Wat Wat Wat                                        Arijit Singh, Shashwat Singh             56QlBs4D15jQWukc0hLCDI
# 180  Dooriyan                                           Mohit Chauhan, Pritam                    5F79ZdjOwGOhUKRHx94sr1
# 181  Khamoshiyan (From "Khamoshiyan")                   Jeet Gannguli, Arijit Singh              5Gy67YHzPZTk9Q0D73LAGH
# 182  Daaru Desi                                         Benny Dayal, Shalmali Kholgade           5pAo2q7eVt65OSkwYgqhHl
# 183  Ilahi (Reprise)                                    Pritam, Mohit Chauhan                    5wdkKS3kWXBU9bklLVsAFs
# 184  Masha-Allah                                        Monty Sharma, Kunal Ganjawala, Shreya    64kG1s7XzOpaWVwFRjvIV7
# 185  Sajna Ji Vaari Vaari                               Sunidhi Chauhan, Shekhar Ravjiani        66wEHvHkE7iz73PEob4Y98
# 186  Baarish                                            Mohammed Irfan, Gajendra Verma           6ABHr8kYCws5z6gC9Lwith
# 187  Rishte Naate - From "De Dana Dan"                  Rahat Fateh Ali Khan, Suzanne D'Mello    6alUOXeJ3T6vi8dkN8QSbi
# 188  Raabta                                             Pritam, Arijit Singh                     6FjbAnaPRPwiP3sciEYctO
# 189  Hale Dil                                           Harshit Saxena                           6GQK4G5o60E8YA18DGpAzv
# 190  O Meri Jaan                                        Pritam, KK                               6qMB7GsJd7L8sqEvQGWQl6
# 191  Zindagi Kuch Toh Bata (Reprise)                    Pritam, Jubin Nautiyal                   6TGX01ExmdHyOG72fqUU3Q
# 192  Sapna Jahan (From "Brothers")                      Ajay-Atul, Sonu Nigam, Neeti Mohan       6uQkoo1UGWThtEpNEYc6Ga
# 193  Kesariya (From "Brahmastra")                       Pritam, Arijit Singh, Amitabh Bhattac    6VBhH7CyP56BXjp8VsDFPZ
# 194  Soch Na Sake                                       Arijit Singh                             71rvcGbKcdAkbVJSrsAsh7
# 195  Itni Si Baat Hain (From "Azhar")                   Arijit Singh, Antara Mitra               7GviKiN4Ah440NQmENzPwN
# 196  Gallan Goodiyaan                                   Yashita Sharma, Manish Kumar Tipu, Fa    7hNYvX0qAKrxtVr1jGDmvR
# 197  Second Hand Jawaani                                Miss Pooja, Neha Kakkar, Nakash Aziz     7kz0NubU5M4k9kdARMBlFK
# 198  Baarish                                            Mohammed Irfan                           7pU3XDn2qRpUrn8FsBecTo
# 199  Galliyan                                           Ankit Tiwari                             7sjsqgy6gaTisiHf8LVwfS
# 200  Tu Jo Mila                                         Pritam, KK, Kausar Munir                 7txLCGOXyDlDXTjtR1Sk4v
# 201  Nashe Si Chadh Gayi                                Vishal-Shekhar, Arijit Singh, Jaideep    0biCSADTAblvLTLtJz4pXO
# 202  Is This Love                                       Mohit Chauhan, Shreya Ghoshal, Pritam    0GVPRo9LEjxjT4C4o8BGot
# 203  Beete Lamhein                                      KK                                       0zQa7QXLpUZfrrsWbgDZll
# 204  Piya Aaye Na                                       Tulsi Kumar, KK                          1ELMyeJLDHUz3cK3XTWgEi
# 205  Kya Karoon? (From "Wake Up Sid ")                  Shankar-Ehsaan-Loy, Clinton Cerejo, D    1FRcg84SSGxJTsIR16z4AU
# 206  Bairi Piya - Devdas / Soundtrack Version           Udit Narayan, Shreya Ghoshal             1lGomk0tsbt7orWGK8XoqA
# 207  Dekhte Dekhte                                      Rochak Kohli, Atif Aslam                 1scGwkyXNCl19wrBDhnAWg
# 208  Saathiyaa                                          Shreya Ghoshal, Ajay                     1sNCUR5bUvFSQVDYEvsHCU
# 209  Adhoore                                            Vishal Dadlani, Alyssa Mendonsa          298atiKYvG84VfbXNbZiX5
# 210  Kaise Mein Kahun Tujhse                            KK                                       2Cu77Qj7Hte67jMtoEfxZK
# 211  Sunn Raha Hai (Female)                             Shreya Ghoshal                           2kRzgmBlmhvFvCEgMHltWz
# 212  Guzarish                                           Javed Ali                                2MvCNH9ua0CeOgUQfZf56z
# 213  Jee Le Zaraa                                       Vishal Dadlani                           2r32XiAWtZbT3eLUvf4pag
# 214  Banjaara (From "Ek Villain")                       Mohammed Irfan                           2S6N9pbnkhQRyAx80HmF79
# 215  Bhare Naina                                        Nandini Srikar                           2UsYQNgpG5tjcDoq8Yg0Nl
# 216  Saiyyan                                            Kailash Kher, Paresh Kamath, Naresh K    2vR23BjIzpLMtzsyKrM6Mb
# 217  Khudaya Khair                                      Pritam, Soham Chakraborty, Akriti Kak    2XYyriLyJSuGj4FN7QoNmM
# 218  Dil To Bachcha Hai                                 Rahat Fateh Ali Khan                     3EFGRGsshk0NWidcXfhKvw
# 219  Laaree Chootee                                     Call                                     3juoXpZ1CRCbWHnWk5rVbV
# 220  Nazrein Milaana Nazrein Churaana                   Benny Dayal, Satish Chakravarthy, Say    3wnahgmj1q8YvjkoXTLG8c
# 221  Manchala                                           Vishal-Shekhar, Shafqat Amanat Ali, N    3zAXHUL5YcYOA41rruvjy4
# 222  Dekh Lena                                          Arijit Singh, Tulsi Kumar                4K7l6gzsSPKkB3mzokEDKQ
# 223  Pani Da Rang - Male Vocals                         Ayushmann Khurrana                       4kaLkst9lT3sQ5Crgxs3ic
# 224  Chaleya (From "Jawan")                             Anirudh Ravichander, Arijit Singh, Sh    4nc6XiUze2Yh7wFueGOPv7
# 225  Chan Kitthan (From "Chan Kitthan")                 Ayushmann Khurrana                       4OffmzjuxT6e9y8E6VDG2i
# 226  Banjaara                                           Mohammed Irfan, Shashaa Tirupati         4qUa1iYh6PTVuGqq9rfZzs
# 227  Mere Rashke Qamar                                  Nusrat Fateh Ali Khan, Rahat Fateh Al    4sNiMTu47WkUgW87qeUlWF
# 228  Saware (From "Phantom")                            Arijit Singh                             4TvWvoxuK9tULN4EQeFh6y
# 229  Pehli Baar Mohabbat                                Mohit Chauhan                            58xpZwxUpgrnJMTEmvkZMP
# 230  Kehna Hi Kya - From "Bombay"                       K. S. Chithra                            5j5vCuBjS1sFWywWUnkJqV
# 231  Heeriye (feat. Arijit Singh)                       Jasleen Royal, Arijit Singh, Harrykah    5PUXKVVVQ74C3gl5vKy9Li
# 232  Dil Kya Kare                                       Adnan Sami                               648GXyKI62FhbeBq0levWr
# 233  Hairat                                             Lucky Ali                                6512hyAQxOng8v4R71IV47
# 234  Haareya (From "Meri Pyaari Bindu ")                Sachin-Jigar, Arijit Singh, Priya Sar    678JJ0TF3KFkzw6bIFKcew
# 235  Bekhayali (Arijit Singh Version) [From "Kabir S    Arijit Singh, Sachet-Parampara           6aPMWbbdhDhiJHlknZb9Yx
# 236  Such Keh Raha Hai                                  KK                                       6CoEiaHC5OLIJGG9R0A0jp
# 237  Tumse Hi Tumse                                     Shekhar Ravjiani, Caralisa Monteiro      6qNyL8lZuqFmy9ginJRQOZ
# 238  Chahun Main Ya Naa                                 Palak Muchhal, Arijit Singh              6UgcN95w7vQxkR8sEFmwHG
# 239  In Dino                                            Pritam, Soham                            6YycppSAeGtSvwmu8qCcr2
# 240  Khamoshiyan                                        Jeet Gannguli, Arijit Singh              6zCQF5tu7HVwU9shhKqiuF
# 241  Bheegi Bheegi - From "Gangster"                    Pritam, James                            7127acu4Qui0XzfHrgE3HD
# 242  Sooraj Ki Baahon Mein                              Dominique Cerejo, Clinton Cerejo, Loy    723xQva0yBF7M6K3nDAG8R
# 243  Abhi Mujh Mein Kahin                               Ajay-Atul, Sonu Nigam                    73y649QhnXdcm6fRdvfraO
# 244  Dil Darbadar                                       Ankit Tiwari                             75lSwSGOwNhkavLyWNZI3Q
# 245  Alvida                                             Pritam, KK                               7EjatvVN2Y2GjpvKSyWJR4
# 246  Khabar Nahi                                        Vishal-Shekhar, Shreya Ghoshal, Amana    7Esjmr77c4SU5IlMtym7Ho
# 247  Phir Le Aya Dil - Reprise                          Pritam, Arijit Singh                     7fpWJr5shT90KiCHXKHxch
# 248  Tere Naina                                         Shankar Mahadevan, Shreya Ghoshal        7u5B4ptccyg8T7NPfByhE7
# 249  Moh Moh Ke Dhaage (Female)                         Anu Malik, Monali Thakur, Varun Grove    7uubRr0u9Zxc1Y84hEn7Xf
# 250  Zara Zara                                          Bombay Jayashri                          7wrYBASu0OoxoDErd4Edxd
# 251  Kaise Ab Kahein Acoustic                           Aasa Singh, Hansika Pareek               01rOtI7gfw5AkKy12gtdrC
# 252  O Bedardeya (From "Tu Jhoothi Main Makkaar")       Pritam, Arijit Singh, Amitabh Bhattac    0czcoKJbJt08NqKrvSbbz7
# 253  Chiraiyya                                          Swanand Kirkire, Ram Sampath             0hQNLwyf8qtVBXJiFeTkD8
# 254  Tu Jo Hain (From "Mr. X")                          Ankit Tiwari                             0RjEjs91p7SpYubEnEanBm
# 255  Humdard                                            Mithoon, Palak Muchhal                   0VSssckUc9buETVtJkj4fq
# 256  Dekha Hazaro Dafaa                                 Arijit Singh, Palak Muchhal, Manoj Mu    0Xsokp10GYOJrrf0Uviv2w
# 257  Roke Na Ruke Naina (From "Badrinath Ki Dulhania    Arijit Singh                             0ZyJDDqBjI0rDnn31qHgbg
# 258  Darmiyaan                                          Shafqat Amanat Ali, Clinton Cerejo       163jamCc6vC1HQKpbu2jxC
# 259  Moh Moh Ke Dhaage (Male)                           Anu Malik, Papon, Varun Grover           189DQylImZ1hGZaIpAQUzx
# 260  Hasi - Female Version                              Ami Mishra, Shreya Ghoshal, Kunaal Ve    1cmZbGkCEVVAck2MsWpPYQ
# 261  Kholo Kholo                                        Raman Mahadevan                          1IfhPnZpm0IZOoAM1PDjtw
# 262  Jashn-E-Bahaaraa                                   A.R. Rahman, Javed Ali                   1O5mTSQa0sCce9ghhDqIZl
# 263  Kyon                                               Pritam, Papon, Sunidhi Chauhan           1sYC1fG7s4p0pTykrJqmgW
# 264  Aye Khuda                                          Salim Merchant                           1vgVsR5rkXGP4NmUcoroJH
# 265  Humdard                                            Rahul Sathu                              1YFOt2k6VtRiqS3DEBzLGJ
# 266  Luteron Ka Lutera Version - Kalank Title - From    Arijit Singh, Pritam                     2cQFLuYKuWItMP2fdQRhAL
# 267  Halka Halka                                        Rahat Fateh Ali Khan, Rashmi Virag, A    2Hu0FRBMFDmEhajRzvNN6T
# 268  Piya O Re Piya - Sad Version                       Atif Aslam, Shreya Ghoshal               2VxNdbftyfLzV9dkLAJIrl
# 269  Khwahishein                                        Salim–Sulaiman, Shreya Ghoshal           31TxQlV1owDhlyFiJvMfuW
# 270  Lagan Laagi Re                                     Amit Trivedi, Shreya Ghoshal, Kavita     3bM0sCyyhglscs8EvsBZ36
# 271  I Am In Love                                       Pritam, KK, Dominique                    3FS3ItpUATpALLi90uvkde
# 272  Hawa Banke                                         Rito Riba, Neha Kakkar, Rajat Nagpal     3J2v56A4A8sYZk3qhTvB21
# 273  Jiyein Kyun                                        Papon                                    3tyEQOACloIoX0jbM8YWx2
# 274  In Dino - Refresh Version                          Mohammed Irfan                           44XwDsXhs41FcCiclo1SjS
# 275  Saawali Si Raat                                    Pritam, Arijit Singh                     4I5Xcdu5Hnki1aP0Uxbs4n
# 276  Soniyo                                             Raju Singh, Sonu Nigam, Shreya Ghosha    4J5OpeZUR2msDPfMsIeGSU
# 277  Saaiyaan                                           Salim–Sulaiman, Rahat Fateh Ali Khan     4lSs8Q2cYcrEy2aps8MPgx
# 278  Ye Tune Kya Kiya - Arijit Singh Version            Zayan                                    4m4rRbUF4Vv2yWrlPTPyYK
# 279  Tujhe Bhula Diya                                   Vishal-Shekhar, Mohit Chauhan, Shekha    4r8JqkhpTb5tzSKKHnVJIJ
# 280  Te Amo (Reprise)                                   Pritam, Mohit Chauhan                    548ajREPV0T2PtOntVtZZn
# 281  Chand Sifarish                                     Jatin-Lalit, Shaan, Kailash Kher, Pra    5EYZZvmNAH5VZCwuzYJqoA
# 282  Dil Diyan Gallan                                   Vishal-Shekhar, Atif Aslam, Irshad Ka    5MnAi6ZF7cE8pAz7wYr9Ta
# 283  Monta Re                                           Swanand Kirkire, Amitabh Bhattacharya    5UHvVfewZKxwoB6gdhSFtr
# 284  Aazaadiyan (Pairon Ki Bediyan)                     Amit Trivedi, Neuman Pinto, Nikhil D'    5VbZt5Tp8qUGFMRXctKdIi
# 285  Labon Ko                                           Pritam, KK                               5WncH5iZ5GFlnXm7jKEXVP
# 286  O Meri Jaan                                        Pritam, KK                               621NCDEU2Pfd5R1oCqnju8
# 287  Kaun Mera                                          Chaitra Ambadipudi                       68XHEoEibD28bHnO8mzdWG
# 288  Mehrama                                            Pritam, Darshan Raval, Antara Mitra      6cUOiOY5qh2FpIQWIYAd2h
# 289  Piyu Bole                                          Sonu Nigam, Shreya Ghoshal               6duBhpTnuZX7PkMICVcUH0
# 290  Be Intehaan                                        Atif Aslam, Sunidhi Chauhan, Pritam      6g0HHWLJwfe2PlbgHi8pBj
# 291  Pyaar Ke Pal                                       KK                                       6GWchpKWsKkwR6jcl0yG6V
# 292  Mora Saiyyan                                       Amit Thapliyal                           6mOvNImvOVgmuWa7LoEYW1
# 293  Tu Hi Re - Bombay / Soundtrack Version             Hariharan, Kavita Krishnamurthy          6nwRC0UkS1MdOOMjcJsrbX
# 294  Kanha - Unplugged                                  Ayushmann Khurrana                       6oiO6U7oqTzhHnexyjVO1w
# 295  Intezaar                                           Mithoon, Arijit Singh, Asees Kaur        6p2o4ep90wpkh0qzUmyFuO
# 296  O Saathi Re                                        Shreya Ghoshal, Vishal Bhardwaj          6sWB94omqQGg9yLsnUnnDL
# 297  Kali Kali Zulfon Ke - Extended Version             Madhur Sharma                            6U5bbb9CXg09H2MEwLW2td
# 298  Alvida                                             Nikhil D'Souza, Sukhwinder Singh, Shr    6WYgyoRKLFY6cBIoRlhA1b
# 299  Ae Re Sakhi                                        Namita Choudhary                         7h5jBU18CqXNhDUKRr6y7h
# 300  Ya Rabba (From "Salaam-E-Ishq")                    Kailash Kher                             7KKRPM4fUsfCkJnd1zPhHf
# 301  Ghungroo (From "War")                              Vishal-Shekhar, Arijit Singh, Shilpa     0WdbnNKO0Jt4BZACSDQh44
# 302  Maana Ke Hum Yaar Nahin                            Sachin-Jigar, Parineeti Chopra, Kausa    1O3WfEwaSpsgZ6tw8jNT8I
# 303  Jiya Re                                            A.R. Rahman, Neeti Mohan, Gulzar         21Af1fetSINZpmAS3si8DW
# 304  Tose Naina                                         Arijit Singh                             2dPUug9YiNL4ypu8UF8SnD
# 305  Rab Ka Shukrana                                    Pritam, Mohit Chauhan                    2VJIaxgWeyw9loL1sqKl7c
# 306  Mere Nishaan                                       Kailash Kher, Meet Bros Anjjan           3BBslCw87ODOwkfu7QMUug
# 307  Tu Hai                                             A.R. Rahman, Sanah Moidutty              3vjkllvtOIKpVvXSWsu1ta
# 308  Mann Mera                                          Gajendra Verma                           3yV2c3cYhkAwSsxAq6nRiv
# 309  Bawara Mann                                        Jubin Nautiyal, Neeti Mohan              43wLf5iwEFm65mp6K06kVy
# 310  Tu Hai Ki Nahi                                     Ankit Tiwari                             4brSaQIT3bnnE41D042fgL
# 311  Shukran Allah - MTV Unplugged Version              Salim–Sulaiman, Salim Merchant           4DMbkxDubBXK7jpq6576H3
# 312  Jag Ghoomeya                                       Vishal-Shekhar, Rahat Fateh Ali Khan,    4KCbZcshgibfJSCAkg87Lv
# 313  Tu Hi Hai                                          Amit Trivedi, Arijit Singh               5b9x5sRIzAgXQw0dhGORO1
# 314  Apna Bana Le                                       Sachin-Jigar, Arijit Singh               5bQ6oDLqvw8tywmnSmwEyL
# 315  O Re Piya (MTV Unplugged)                          Salim–Sulaiman, Rahat Fateh Ali Khan,    5XasCazsfBeMrrKdB2MFVm
# 316  Bandook Meri Laila (feat. Raftaar, Sidharth Mal    Ash King, Jigar Saraiya, Raftaar, Sid    5ZNWQ3GAz7ctU5rYmW81MV
# 317  Dil Kyun Yeh Mera (From "Kites")                   KK                                       66uMmK9uefgoflmaxbtQCL
# 318  O Saathi                                           Atif Aslam, Arko                         6fScgF2Y63ScU73nYju0ny
# 319  Tera Rastaa Chhodoon Na                            Amitabh Bhattacharya, Anusha Mani        7cLGKaJXLFpUU7Up34vVr1
# 320  Kun Faya Kun                                       A.R. Rahman, Javed Ali, Mohit Chauhan    7F8RNvTQlvbeBLeenycvN6
# 321  Sajde                                              Shankar-Ehsaan-Loy, Arijit Singh, Nih    7kiZ6Zf66oX6yMovt3gC1a
# ----------------------------------------------------------------------------------------------------
# INFO: Starting sort with anchor track ID: 5HXYyYih9EhgJzvldwtvRp
# Selected 'Iktara' by Amit Trivedi, Kavita Seth, Amitabh Bhattacharya as the anchor track.
# ================================================================================
#
# Sorting playlist based on transitions...
# INFO: Playlist sorting complete. Final track count: 321
# Transition Analysis:
# --------------------------------------------------------------------------------
#
# 1. Iktara → Teri Deewani
#    Camelot: 9B → 9A (✓ Compatible) ()
#    BPM:     80 → 80 (Δ0)
#    Energy:  ('0.50',) → ('0.60',) (Δ('0.10',))
#    Score:   1.62
#
# 2. Teri Deewani → Nazm Nazm
#    Camelot: 9A → 9B (✓ Compatible) ()
#    BPM:     80 → 82 (Δ2)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   1.55
#
# 3. Nazm Nazm → Piya Aaye Na
#    Camelot: 9B → 9A (✓ Compatible) ()
#    BPM:     82 → 82 (Δ0)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   1.65
#
# 4. Piya Aaye Na → Sunn Raha Hai (Female)
#    Camelot: 9A → 8A (✓ Compatible) ()
#    BPM:     82 → 82 (Δ0)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   1.65
#
# 5. Sunn Raha Hai (Female) → Kuchh Toh Hua Hai
#    Camelot: 8A → 9A (✓ Compatible) ()
#    BPM:     82 → 83 (Δ1)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   1.60
#
# 6. Kuchh Toh Hua Hai → Dekho Na
#    Camelot: 9A → 9B (✓ Compatible) ()
#    BPM:     83 → 83 (Δ0)
#    Energy:  ('0.60',) → ('0.70',) (Δ('0.10',))
#    Score:   1.62
#
# 7. Dekho Na → Alvida
#    Camelot: 9B → 10B (✓ Compatible) ()
#    BPM:     83 → 84 (Δ1)
#    Energy:  ('0.70',) → ('0.70',) (Δ('0.00',))
#    Score:   1.60
#
# 8. Alvida → Mast Magan
#    Camelot: 10B → 9B (✓ Compatible) ()
#    BPM:     84 → 83 (Δ1)
#    Energy:  ('0.70',) → ('0.80',) (Δ('0.10',))
#    Score:   1.57
#
# 9. Mast Magan → Manwa Laage
#    Camelot: 9B → 8B (✓ Compatible) ()
#    BPM:     83 → 81 (Δ2)
#    Energy:  ('0.80',) → ('0.70',) (Δ('-0.10',))
#    Score:   1.45
#
# 10. Manwa Laage → Aas Paas Khuda
#    Camelot: 8B → 7B (✓ Compatible) ()
#    BPM:     81 → 80 (Δ1)
#    Energy:  ('0.70',) → ('0.70',) (Δ('0.00',))
#    Score:   1.60
#
# 11. Aas Paas Khuda → Sunn Raha Hai
#    Camelot: 7B → 6B (✓ Compatible) ()
#    BPM:     80 → 83 (Δ3)
#    Energy:  ('0.70',) → ('0.60',) (Δ('-0.10',))
#    Score:   1.47
#
# 12. Sunn Raha Hai → Bahara
#    Camelot: 6B → 7B (✓ Compatible) ()
#    BPM:     83 → 86 (Δ3)
#    Energy:  ('0.60',) → ('0.70',) (Δ('0.10',))
#    Score:   1.47
#
# 13. Bahara → Bulleya
#    Camelot: 7B → 7A (✓ Compatible) ()
#    BPM:     86 → 87 (Δ1)
#    Energy:  ('0.70',) → ('0.80',) (Δ('0.10',))
#    Score:   1.57
#
# 14. Bulleya → Jeene Laga Hoon
#    Camelot: 7A → 6A (✓ Compatible) ()
#    BPM:     87 → 90 (Δ3)
#    Energy:  ('0.80',) → ('0.70',) (Δ('-0.10',))
#    Score:   1.40
#
# 15. Jeene Laga Hoon → Ek Din Teri Raahon
#    Camelot: 6A → 7A (✓ Compatible) ()
#    BPM:     90 → 92 (Δ2)
#    Energy:  ('0.70',) → ('0.90',) (Δ('0.20',))
#    Score:   1.49
#
# 16. Ek Din Teri Raahon → Laaree Chootee
#    Camelot: 7A → 8A (✓ Compatible) ()
#    BPM:     92 → 93 (Δ1)
#    Energy:  ('0.90',) → ('0.70',) (Δ('-0.20',))
#    Score:   1.40
#
# 17. Laaree Chootee → Tere Naina
#    Camelot: 8A → 8B (✓ Compatible) ()
#    BPM:     93 → 93 (Δ0)
#    Energy:  ('0.70',) → ('0.70',) (Δ('0.00',))
#    Score:   1.65
#
# 18. Tere Naina → Ye Tune Kya Kiya
#    Camelot: 8B → 9B (✓ Compatible) ()
#    BPM:     93 → 92 (Δ1)
#    Energy:  ('0.70',) → ('0.80',) (Δ('0.10',))
#    Score:   1.57
#
# 19. Ye Tune Kya Kiya → Chaleya (From "Jawan")
#    Camelot: 9B → 8B (✓ Compatible) ()
#    BPM:     92 → 95 (Δ3)
#    Energy:  ('0.80',) → ('0.80',) (Δ('0.00',))
#    Score:   1.50
#
# 20. Chaleya (From "Jawan") → Yoon Shabnami
#    Camelot: 8B → 7B (✓ Compatible) ()
#    BPM:     95 → 95 (Δ0)
#    Energy:  ('0.80',) → ('0.60',) (Δ('-0.20',))
#    Score:   1.45
#
# 21. Yoon Shabnami → Kesariya (From "Brahmastra")
#    Camelot: 7B → 8B (✓ Compatible) ()
#    BPM:     95 → 94 (Δ1)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   1.60
#
# 22. Kesariya (From "Brahmastra") → Dil Kya Kare
#    Camelot: 8B → 9B (✓ Compatible) ()
#    BPM:     94 → 95 (Δ1)
#    Energy:  ('0.60',) → ('0.50',) (Δ('-0.10',))
#    Score:   1.57
#
# 23. Dil Kya Kare → Kaun Mera
#    Camelot: 9B → 10B (✓ Compatible) ()
#    BPM:     95 → 96 (Δ1)
#    Energy:  ('0.50',) → ('0.40',) (Δ('-0.10',))
#    Score:   1.57
#
# 24. Kaun Mera → Apna Bana Le
#    Camelot: 10B → 11B (✓ Compatible) ()
#    BPM:     96 → 94 (Δ2)
#    Energy:  ('0.40',) → ('0.60',) (Δ('0.20',))
#    Score:   1.49
#
# 25. Apna Bana Le → Shaayraana
#    Camelot: 11B → 10B (✓ Compatible) ()
#    BPM:     94 → 94 (Δ0)
#    Energy:  ('0.60',) → ('0.70',) (Δ('0.10',))
#    Score:   1.62
#
# 26. Shaayraana → Pasoori
#    Camelot: 10B → 10A (✓ Compatible) ()
#    BPM:     94 → 92 (Δ2)
#    Energy:  ('0.70',) → ('0.60',) (Δ('-0.10',))
#    Score:   1.52
#
# 27. Pasoori → Saibo
#    Camelot: 10A → 10B (✓ Compatible) ()
#    BPM:     92 → 90 (Δ2)
#    Energy:  ('0.60',) → ('0.40',) (Δ('-0.20',))
#    Score:   1.35
#
# 28. Saibo → Afeemi (From "Meri Pyaari Bindu ")
#    Camelot: 10B → 9B (✓ Compatible) ()
#    BPM:     90 → 88 (Δ2)
#    Energy:  ('0.40',) → ('0.50',) (Δ('0.10',))
#    Score:   1.52
#
# 29. Afeemi (From "Meri Pyaari Bindu ") → Saathiyaa
#    Camelot: 9B → 10B (✓ Compatible) ()
#    BPM:     88 → 87 (Δ1)
#    Energy:  ('0.50',) → ('0.70',) (Δ('0.20',))
#    Score:   1.53
#
# 30. Saathiyaa → Rabba Main Toh Mar Gaya Oye
#    Camelot: 10B → 11B (✓ Compatible) ()
#    BPM:     87 → 88 (Δ1)
#    Energy:  ('0.70',) → ('0.80',) (Δ('0.10',))
#    Score:   1.57
#
# 31. Rabba Main Toh Mar Gaya Oye → Tum Jo Aaye (From "Once Upon A Time In Mumbaai")
#    Camelot: 11B → 12B (✓ Compatible) ()
#    BPM:     88 → 84 (Δ4)
#    Energy:  ('0.80',) → ('0.80',) (Δ('0.00',))
#    Score:   1.32
#
# 32. Tum Jo Aaye (From "Once Upon A Time In Mumbaai") → Phero Na Najariya
#    Camelot: 12B → 12A (✓ Compatible) ()
#    BPM:     84 → 85 (Δ1)
#    Energy:  ('0.80',) → ('0.80',) (Δ('0.00',))
#    Score:   1.60
#
# 33. Phero Na Najariya → Abhi Kuch Dino Se
#    Camelot: 12A → 12B (✓ Compatible) ()
#    BPM:     85 → 92 (Δ7)
#    Energy:  ('0.80',) → ('0.70',) (Δ('-0.10',))
#    Score:   1.09
#
# 34. Abhi Kuch Dino Se → Rishte Naate - From "De Dana Dan"
#    Camelot: 12B → 1B (✓ Compatible) ()
#    BPM:     92 → 92 (Δ0)
#    Energy:  ('0.70',) → ('0.80',) (Δ('0.10',))
#    Score:   1.62
#
# 35. Rishte Naate - From "De Dana Dan" → Saiyaara
#    Camelot: 1B → 1A (✓ Compatible) ()
#    BPM:     92 → 93 (Δ1)
#    Energy:  ('0.80',) → ('0.70',) (Δ('-0.10',))
#    Score:   1.50
#
# 36. Saiyaara → Zaroorat
#    Camelot: 1A → 2A (✓ Compatible) ()
#    BPM:     93 → 93 (Δ0)
#    Energy:  ('0.70',) → ('0.70',) (Δ('0.00',))
#    Score:   1.65
#
# 37. Zaroorat → Galliyan (From "Ek Villain")
#    Camelot: 2A → 3A (✓ Compatible) ()
#    BPM:     93 → 90 (Δ3)
#    Energy:  ('0.70',) → ('0.80',) (Δ('0.10',))
#    Score:   1.47
#
# 38. Galliyan (From "Ek Villain") → Haule Haule
#    Camelot: 3A → 4A (✓ Compatible) ()
#    BPM:     90 → 90 (Δ0)
#    Energy:  ('0.80',) → ('0.80',) (Δ('0.00',))
#    Score:   1.65
#
# 39. Haule Haule → Bheegi Si Bhaagi Si
#    Camelot: 4A → 4B (✓ Compatible) ()
#    BPM:     90 → 89 (Δ1)
#    Energy:  ('0.80',) → ('0.90',) (Δ('0.10',))
#    Score:   1.57
#
# 40. Bheegi Si Bhaagi Si → Kun Faya Kun
#    Camelot: 4B → 3B (✓ Compatible) ()
#    BPM:     89 → 88 (Δ1)
#    Energy:  ('0.90',) → ('0.40',) (Δ('-0.50',))
#    Score:   1.11
#
# 41. Kun Faya Kun → O Saathi
#    Camelot: 3B → 4B (✓ Compatible) ()
#    BPM:     88 → 90 (Δ2)
#    Energy:  ('0.40',) → ('0.50',) (Δ('0.10',))
#    Score:   1.52
#
# 42. O Saathi → Shukran Allah - MTV Unplugged Version
#    Camelot: 4B → 3B (✓ Compatible) ()
#    BPM:     90 → 85 (Δ5)
#    Energy:  ('0.50',) → ('0.50',) (Δ('0.00',))
#    Score:   1.27
#
# 43. Shukran Allah - MTV Unplugged Version → Bawara Mann
#    Camelot: 3B → 4B (✓ Compatible) ()
#    BPM:     85 → 85 (Δ0)
#    Energy:  ('0.50',) → ('0.50',) (Δ('0.00',))
#    Score:   1.65
#
# 44. Bawara Mann → Heeriye (feat. Arijit Singh)
#    Camelot: 4B → 3B (✓ Compatible) ()
#    BPM:     85 → 83 (Δ2)
#    Energy:  ('0.50',) → ('0.40',) (Δ('-0.10',))
#    Score:   1.52
#
# 45. Heeriye (feat. Arijit Singh) → Hai Rama
#    Camelot: 3B → 2B (✓ Compatible) ()
#    BPM:     83 → 85 (Δ2)
#    Energy:  ('0.40',) → ('0.40',) (Δ('0.00',))
#    Score:   1.55
#
# 46. Hai Rama → Jag Ghoomeya
#    Camelot: 2B → 1B (✓ Compatible) ()
#    BPM:     85 → 83 (Δ2)
#    Energy:  ('0.40',) → ('0.60',) (Δ('0.20',))
#    Score:   1.49
#
# 47. Jag Ghoomeya → Naina
#    Camelot: 1B → 2B (✓ Compatible) ()
#    BPM:     83 → 80 (Δ3)
#    Energy:  ('0.60',) → ('0.40',) (Δ('-0.20',))
#    Score:   1.30
#
# 48. Naina → Tu Hai
#    Camelot: 2B → 1B (✓ Compatible) ()
#    BPM:     80 → 81 (Δ1)
#    Energy:  ('0.40',) → ('0.50',) (Δ('0.10',))
#    Score:   1.57
#
# 49. Tu Hai → Mora Saiyyan
#    Camelot: 1B → 12B (✓ Compatible) ()
#    BPM:     81 → 81 (Δ0)
#    Energy:  ('0.50',) → ('0.30',) (Δ('-0.20',))
#    Score:   1.45
#
# 50. Mora Saiyyan → Roke Na Ruke Naina (From "Badrinath Ki Dulhania")
#    Camelot: 12B → 11B (✓ Compatible) ()
#    BPM:     81 → 81 (Δ0)
#    Energy:  ('0.30',) → ('0.40',) (Δ('0.10',))
#    Score:   1.62
#
# 51. Roke Na Ruke Naina (From "Badrinath Ki Dulhania") → Kabira
# ...
#    Score:   1.32
#
# 233. Humdard → Kaise Mujhe
#    Camelot: 7B → 6B (✓ Compatible) ()
#    BPM:     87 → 82 (Δ5)
#    Energy:  ('0.50',) → ('0.40',) (Δ('-0.10',))
#    Score:   1.24
#
# 234. Kaise Mujhe → Kabhi Kabhi Aditi
#    Camelot: 6B → 6A (✓ Compatible) ()
#    BPM:     82 → 95 (Δ13)
#    Energy:  ('0.40',) → ('0.60',) (Δ('0.20',))
#    Score:   0.86
#
# 235. Kabhi Kabhi Aditi → Sunn Raha Hai
#    Camelot: 6A → 5A (✓ Compatible) ()
#    BPM:     95 → 82 (Δ13)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   0.92
#
# 236. Sunn Raha Hai → Nazar Na Lag Jaaye (From "Stree")
#    Camelot: 5A → 6A (✓ Compatible) ()
#    BPM:     82 → 174 (Δ92)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   0.60
#
# 237. Nazar Na Lag Jaaye (From "Stree") → Behka
#    Camelot: 6A → 5A (✓ Compatible) ()
#    BPM:     174 → 192 (Δ18)
#    Energy:  ('0.60',) → ('0.50',) (Δ('-0.10',))
#    Score:   0.66
#
# 238. Behka → Masha-Allah
#    Camelot: 5A → 5B (✓ Compatible) ()
#    BPM:     192 → 150 (Δ42)
#    Energy:  ('0.50',) → ('0.50',) (Δ('0.00',))
#    Score:   0.60
#
# 239. Masha-Allah → Mar Jawaan
#    Camelot: 5B → 6B (✓ Compatible) ()
#    BPM:     150 → 150 (Δ0)
#    Energy:  ('0.50',) → ('0.70',) (Δ('0.20',))
#    Score:   1.58
#
# 240. Mar Jawaan → Aise Kyun - Ghazal Version
#    Camelot: 6B → 5B (✓ Compatible) ()
#    BPM:     150 → 152 (Δ2)
#    Energy:  ('0.70',) → ('0.40',) (Δ('-0.30',))
#    Score:   1.25
#
# 241. Aise Kyun - Ghazal Version → Kitni Baatein
#    Camelot: 5B → 4B (✓ Compatible) ()
#    BPM:     152 → 159 (Δ7)
#    Energy:  ('0.40',) → ('0.40',) (Δ('0.00',))
#    Score:   1.19
#
# 242. Kitni Baatein → Tere Pyaar Mein
#    Camelot: 4B → 3B (✓ Compatible) ()
#    BPM:     159 → 160 (Δ1)
#    Energy:  ('0.40',) → ('0.40',) (Δ('0.00',))
#    Score:   1.60
#
# 243. Tere Pyaar Mein → Humdard
#    Camelot: 3B → 2B (✓ Compatible) ()
#    BPM:     160 → 162 (Δ2)
#    Energy:  ('0.40',) → ('0.30',) (Δ('-0.10',))
#    Score:   1.45
#
# 244. Humdard → Kahani (From "Laal Singh Chaddha")
#    Camelot: 2B → 3B (✓ Compatible) ()
#    BPM:     162 → 150 (Δ12)
#    Energy:  ('0.30',) → ('0.30',) (Δ('0.00',))
#    Score:   0.96
#
# 245. Kahani (From "Laal Singh Chaddha") → Tu Hai Ki Nahi
#    Camelot: 3B → 3A (✓ Compatible) ()
#    BPM:     150 → 144 (Δ6)
#    Energy:  ('0.30',) → ('0.80',) (Δ('0.50',))
#    Score:   1.08
#
# 246. Tu Hai Ki Nahi → Main Agar Kahoon
#    Camelot: 3A → 4A (✓ Compatible) ()
#    BPM:     144 → 147 (Δ3)
#    Energy:  ('0.80',) → ('0.40',) (Δ('-0.40',))
#    Score:   1.11
#
# 247. Main Agar Kahoon → Yun Hi
#    Camelot: 4A → 4B (✓ Compatible) ()
#    BPM:     147 → 140 (Δ7)
#    Energy:  ('0.40',) → ('0.50',) (Δ('0.10',))
#    Score:   1.16
#
# 248. Yun Hi → Dil Beparvah - The Dewarists, Season 5
#    Camelot: 4B → 3B (✓ Compatible) ()
#    BPM:     140 → 138 (Δ2)
#    Energy:  ('0.50',) → ('0.40',) (Δ('-0.10',))
#    Score:   1.52
#
# 249. Dil Beparvah - The Dewarists, Season 5 → Kyun Main Jaagoon
#    Camelot: 3B → 4B (✓ Compatible) ()
#    BPM:     138 → 130 (Δ8)
#    Energy:  ('0.40',) → ('0.30',) (Δ('-0.10',))
#    Score:   1.05
#
# 250. Kyun Main Jaagoon → Pani Da Rang - Male Vocals
#    Camelot: 4B → 4A (✓ Compatible) ()
#    BPM:     130 → 135 (Δ5)
#    Energy:  ('0.30',) → ('0.30',) (Δ('0.00',))
#    Score:   1.27
#
# 251. Pani Da Rang - Male Vocals → Laal Peeli Akhiyaan (From "Teri Baaton Mein Aisa Uljha Jiya")
#    Camelot: 4A → 4B (✓ Compatible) ()
#    BPM:     135 → 130 (Δ5)
#    Energy:  ('0.30',) → ('0.80',) (Δ('0.50',))
#    Score:   1.12
#
# 252. Laal Peeli Akhiyaan (From "Teri Baaton Mein Aisa Uljha Jiya") → Duaa
#    Camelot: 4B → 4A (✓ Compatible) ()
#    BPM:     130 → 138 (Δ8)
#    Energy:  ('0.80',) → ('0.60',) (Δ('-0.20',))
#    Score:   0.96
#
# 253. Duaa → Ravi
#    Camelot: 4A → 4B (✓ Compatible) ()
#    BPM:     138 → 128 (Δ10)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   1.05
#
# 254. Ravi → Naina
#    Camelot: 4B → 5B (✓ Compatible) ()
#    BPM:     128 → 160 (Δ32)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   0.60
#
# 255. Naina → Tujh Mein Rab Dikhta Hai
#    Camelot: 5B → 4B (✓ Compatible) ()
#    BPM:     160 → 85 (Δ75)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   0.60
#
# 256. Tujh Mein Rab Dikhta Hai → Galliyan
#    Camelot: 4B → 8A (✗ Incompatible) ()
#    BPM:     85 → 85 (Δ0)
#    Energy:  ('0.60',) → ('0.50',) (Δ('-0.10',))
#    Score:   0.54
#
# 257. Galliyan → Khamoshiyan
#    Camelot: 8A → 7A (✓ Compatible) ()
#    BPM:     85 → 144 (Δ59)
#    Energy:  ('0.50',) → ('0.50',) (Δ('0.00',))
#    Score:   0.60
#
# 258. Khamoshiyan → Mora Saiyaan - Khamaaj
#    Camelot: 7A → 7B (✓ Compatible) ()
#    BPM:     144 → 112 (Δ32)
#    Energy:  ('0.50',) → ('0.50',) (Δ('0.00',))
#    Score:   0.60
#
# 259. Mora Saiyaan - Khamaaj → In Dino - Refresh Version
#    Camelot: 7B → 6B (✓ Compatible) ()
#    BPM:     112 → 106 (Δ6)
#    Energy:  ('0.50',) → ('0.30',) (Δ('-0.20',))
#    Score:   1.05
#
# 260. In Dino - Refresh Version → Jeena Jeena
#    Camelot: 6B → 7B (✓ Compatible) ()
#    BPM:     106 → 105 (Δ1)
#    Energy:  ('0.30',) → ('0.30',) (Δ('0.00',))
#    Score:   1.60
#
# 261. Jeena Jeena → Luteron Ka Lutera Version - Kalank Title - From "Kalank"
#    Camelot: 7B → 6B (✓ Compatible) ()
#    BPM:     105 → 118 (Δ13)
#    Energy:  ('0.30',) → ('0.20',) (Δ('-0.10',))
#    Score:   0.89
#
# 262. Luteron Ka Lutera Version - Kalank Title - From "Kalank" → Sawaar Loon
#    Camelot: 6B → 7B (✓ Compatible) ()
#    BPM:     118 → 112 (Δ6)
#    Energy:  ('0.20',) → ('0.60',) (Δ('0.40',))
#    Score:   1.11
#
# 263. Sawaar Loon → Dekh Lena
#    Camelot: 7B → 8B (✓ Compatible) ()
#    BPM:     112 → 152 (Δ40)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   0.60
#
# 264. Dekh Lena → Kali Kali Zulfon Ke - Extended Version
#    Camelot: 8B → 9B (✓ Compatible) ()
#    BPM:     152 → 154 (Δ2)
#    Energy:  ('0.60',) → ('0.40',) (Δ('-0.20',))
#    Score:   1.35
#
# 265. Kali Kali Zulfon Ke - Extended Version → Humdard
#    Camelot: 9B → 10B (✓ Compatible) ()
#    BPM:     154 → 149 (Δ5)
#    Energy:  ('0.40',) → ('0.30',) (Δ('-0.10',))
#    Score:   1.19
#
# 266. Humdard → Te Amo (Reprise)
#    Camelot: 10B → 9B (✓ Compatible) ()
#    BPM:     149 → 128 (Δ21)
#    Energy:  ('0.30',) → ('0.30',) (Δ('0.00',))
#    Score:   0.60
#
# 267. Te Amo (Reprise) → Moh Moh Ke Dhaage (Male)
#    Camelot: 9B → 10B (✓ Compatible) ()
#    BPM:     128 → 128 (Δ0)
#    Energy:  ('0.30',) → ('0.30',) (Δ('0.00',))
#    Score:   1.65
#
# 268. Moh Moh Ke Dhaage (Male) → Kaise Ab Kahein Acoustic
#    Camelot: 10B → 9B (✓ Compatible) ()
#    BPM:     128 → 120 (Δ8)
#    Energy:  ('0.30',) → ('0.20',) (Δ('-0.10',))
#    Score:   1.11
#
# 269. Kaise Ab Kahein Acoustic → Kyon
#    Camelot: 9B → 10B (✓ Compatible) ()
#    BPM:     120 → 122 (Δ2)
#    Energy:  ('0.20',) → ('0.70',) (Δ('0.50',))
#    Score:   1.39
#
# 270. Kyon → Naina Da Kya Kasoor
#    Camelot: 10B → 11B (✓ Compatible) ()
#    BPM:     122 → 63 (Δ59)
#    Energy:  ('0.70',) → ('0.70',) (Δ('0.00',))
#    Score:   0.60
#
# 271. Naina Da Kya Kasoor → Jiyein Kyun
#    Camelot: 11B → 12B (✓ Compatible) ()
#    BPM:     63 → 71 (Δ8)
#    Energy:  ('0.70',) → ('0.60',) (Δ('-0.10',))
#    Score:   1.11
#
# 272. Jiyein Kyun → Tujhe Kitna Chahne Lage
#    Camelot: 12B → 1B (✓ Compatible) ()
#    BPM:     71 → 70 (Δ1)
#    Energy:  ('0.60',) → ('0.40',) (Δ('-0.20',))
#    Score:   1.40
#
# 273. Tujhe Kitna Chahne Lage → Hoor
#    Camelot: 1B → 12B (✓ Compatible) ()
#    BPM:     70 → 150 (Δ80)
#    Energy:  ('0.40',) → ('0.40',) (Δ('0.00',))
#    Score:   0.60
#
# 274. Hoor → Pareshaan
#    Camelot: 12B → 7A (✗ Incompatible) ()
#    BPM:     150 → 150 (Δ0)
#    Energy:  ('0.40',) → ('0.40',) (Δ('0.00',))
#    Score:   0.55
#
# 275. Pareshaan → Enna Sona
#    Camelot: 7A → 6A (✓ Compatible) ()
#    BPM:     150 → 100 (Δ50)
#    Energy:  ('0.40',) → ('0.40',) (Δ('0.00',))
#    Score:   0.60
#
# 276. Enna Sona → Phir Mohabbat
#    Camelot: 6A → 5A (✓ Compatible) ()
#    BPM:     100 → 200 (Δ100)
#    Energy:  ('0.40',) → ('0.50',) (Δ('0.10',))
#    Score:   0.57
#
# 277. Phir Mohabbat → Sanam Re (From "Sanam Re")
#    Camelot: 5A → 6A (✓ Compatible) ()
#    BPM:     200 → 112 (Δ88)
#    Energy:  ('0.50',) → ('0.70',) (Δ('0.20',))
#    Score:   0.54
#
# 278. Sanam Re (From "Sanam Re") → Jab Se Tere Naina
#    Camelot: 6A → 5A (✓ Compatible) ()
#    BPM:     112 → 80 (Δ32)
#    Energy:  ('0.70',) → ('0.70',) (Δ('0.00',))
#    Score:   0.60
#
# 279. Jab Se Tere Naina → Tujhe Sochta Hoon
#    Camelot: 5A → 5A (✗ Incompatible) (Perfect Match)
#    BPM:     80 → 81 (Δ1)
#    Energy:  ('0.70',) → ('0.70',) (Δ('0.00',))
#    Score:   0.53
#
# 280. Tujhe Sochta Hoon → Phir Le Aya Dil - Reprise
#    Camelot: 5A → 9B (✗ Incompatible) ()
#    BPM:     81 → 78 (Δ3)
#    Energy:  ('0.70',) → ('0.50',) (Δ('-0.20',))
#    Score:   0.43
#
# 281. Phir Le Aya Dil - Reprise → Aazaadiyan (Pairon Ki Bediyan)
#    Camelot: 9B → 10B (✓ Compatible) ()
#    BPM:     78 → 100 (Δ22)
#    Energy:  ('0.50',) → ('0.50',) (Δ('0.00',))
#    Score:   0.60
#
# 282. Aazaadiyan (Pairon Ki Bediyan) → Khabar Nahi
#    Camelot: 10B → 9B (✓ Compatible) ()
#    BPM:     100 → 91 (Δ9)
#    Energy:  ('0.50',) → ('0.80',) (Δ('0.30',))
#    Score:   1.01
#
# 283. Khabar Nahi → Ek Dil Ek Jaan (From "Padmaavat")
#    Camelot: 9B → 10B (✓ Compatible) ()
#    BPM:     91 → 98 (Δ7)
#    Energy:  ('0.80',) → ('0.70',) (Δ('-0.10',))
#    Score:   1.09
#
# 284. Ek Dil Ek Jaan (From "Padmaavat") → Zaalima
#    Camelot: 10B → 11B (✓ Compatible) ()
#    BPM:     98 → 88 (Δ10)
#    Energy:  ('0.70',) → ('0.90',) (Δ('0.20',))
#    Score:   0.99
#
# 285. Zaalima → Bandook Meri Laila (feat. Raftaar, Sidharth Malhotra)
#    Camelot: 11B → 11A (✓ Compatible) ()
#    BPM:     88 → 99 (Δ11)
#    Energy:  ('0.90',) → ('0.80',) (Δ('-0.10',))
#    Score:   0.97
#
# 286. Bandook Meri Laila (feat. Raftaar, Sidharth Malhotra) → Mann Mera
#    Camelot: 11A → 12A (✓ Compatible) ()
#    BPM:     99 → 192 (Δ93)
#    Energy:  ('0.80',) → ('0.80',) (Δ('0.00',))
#    Score:   0.60
#
# 287. Mann Mera → Tu Hi Hai (Ali Zafar Version) [From "Dear Zindagi"]
#    Camelot: 12A → 12B (✓ Compatible) ()
#    BPM:     192 → 188 (Δ4)
#    Energy:  ('0.80',) → ('0.50',) (Δ('-0.30',))
#    Score:   1.05
#
# 288. Tu Hi Hai (Ali Zafar Version) [From "Dear Zindagi"] → Javeda Zindagi-Tose Naina Lage
#    Camelot: 12B → 12A (✓ Compatible) ()
#    BPM:     188 → 130 (Δ58)
#    Energy:  ('0.50',) → ('0.60',) (Δ('0.10',))
#    Score:   0.57
#
# 289. Javeda Zindagi-Tose Naina Lage → Gallan Goodiyaan
#    Camelot: 12A → 11A (✓ Compatible) ()
#    BPM:     130 → 120 (Δ10)
#    Energy:  ('0.60',) → ('0.90',) (Δ('0.30',))
#    Score:   0.96
#
# 290. Gallan Goodiyaan → Chand Sifarish
#    Camelot: 11A → 10B (✗ Incompatible) ()
#    BPM:     120 → 122 (Δ2)
#    Energy:  ('0.90',) → ('0.70',) (Δ('-0.20',))
#    Score:   0.45
#
# 291. Chand Sifarish → Rab Ka Shukrana
#    Camelot: 10B → 3A (✗ Incompatible) ()
#    BPM:     122 → 122 (Δ0)
#    Energy:  ('0.70',) → ('0.60',) (Δ('-0.10',))
#    Score:   0.54
#
# 292. Rab Ka Shukrana → Inn Lamhon Ke Daaman Mein
#    Camelot: 3A → 3B (✓ Compatible) ()
#    BPM:     122 → 149 (Δ27)
#    Energy:  ('0.60',) → ('0.40',) (Δ('-0.20',))
#    Score:   0.42
#
# 293. Inn Lamhon Ke Daaman Mein → O Saiyyan
#    Camelot: 3B → 2B (✓ Compatible) ()
#    BPM:     149 → 166 (Δ17)
#    Energy:  ('0.40',) → ('0.50',) (Δ('0.10',))
#    Score:   0.71
#
# 294. O Saiyyan → Tera Rastaa Chhodoon Na
#    Camelot: 2B → 12B (✗ Incompatible) ()
#    BPM:     166 → 170 (Δ4)
#    Energy:  ('0.50',) → ('0.70',) (Δ('0.20',))
#    Score:   0.42
#
# 295. Tera Rastaa Chhodoon Na → Le Le Mazaa Le
#    Camelot: 12B → 10B (✗ Incompatible) ()
#    BPM:     170 → 182 (Δ12)
#    Energy:  ('0.70',) → ('0.90',) (Δ('0.20',))
#    Score:   0.30
#
# 296. Le Le Mazaa Le → Tere Bin
#    Camelot: 10B → 8B (✗ Incompatible) ()
#    BPM:     182 → 180 (Δ2)
#    Energy:  ('0.90',) → ('0.30',) (Δ('-0.60',))
#    Score:   0.32
#
# 297. Tere Bin → Kehna Hi Kya - From "Bombay"
#    Camelot: 8B → 8A (✓ Compatible) ()
#    BPM:     180 → 127 (Δ53)
#    Energy:  ('0.30',) → ('0.30',) (Δ('0.00',))
#    Score:   0.60
#
# 298. Kehna Hi Kya - From "Bombay" → Lagan Laagi Re
#    Camelot: 8A → 8B (✓ Compatible) ()
#    BPM:     127 → 138 (Δ11)
#    Energy:  ('0.30',) → ('0.30',) (Δ('0.00',))
#    Score:   1.00
#
# 299. Lagan Laagi Re → O Bedardeya (From "Tu Jhoothi Main Makkaar")
#    Camelot: 8B → 7B (✓ Compatible) ()
#    BPM:     138 → 95 (Δ43)
#    Energy:  ('0.30',) → ('0.20',) (Δ('-0.10',))
#    Score:   0.57
#
# 300. O Bedardeya (From "Tu Jhoothi Main Makkaar") → Chan Kitthan (From "Chan Kitthan")
#    Camelot: 7B → 7B (✗ Incompatible) (Perfect Match)
#    BPM:     95 → 96 (Δ1)
#    Energy:  ('0.20',) → ('0.50',) (Δ('0.30',))
#    Score:   0.50
#
# 301. Chan Kitthan (From "Chan Kitthan") → Falak Tak
#    Camelot: 7B → 7A (✓ Compatible) ()
#    BPM:     96 → 144 (Δ48)
#    Energy:  ('0.50',) → ('0.70',) (Δ('0.20',))
#    Score:   0.54
#
# 302. Falak Tak → Abhi Abhi
#    Camelot: 7A → 10B (✗ Incompatible) ()
#    BPM:     144 → 144 (Δ0)
#    Energy:  ('0.70',) → ('0.60',) (Δ('-0.10',))
#    Score:   0.54
#
# 303. Abhi Abhi → Jiyein Kyun
#    Camelot: 10B → 10B (✗ Incompatible) (Perfect Match)
#    BPM:     144 → 144 (Δ0)
#    Energy:  ('0.60',) → ('0.60',) (Δ('0.00',))
#    Score:   0.55
#
# 304. Jiyein Kyun → Ishq Shava
#    Camelot: 10B → 11A (✗ Incompatible) ()
#    BPM:     144 → 144 (Δ0)
#    Energy:  ('0.60',) → ('0.90',) (Δ('0.30',))
#    Score:   0.52
#
# 305. Ishq Shava → Sajna Ji Vaari Vaari
#    Camelot: 11A → 8B (✗ Incompatible) ()
#    BPM:     144 → 144 (Δ0)
#    Energy:  ('0.90',) → ('0.90',) (Δ('0.00',))
#    Score:   0.55
#
# 306. Sajna Ji Vaari Vaari → Dil Ibaadat
#    Camelot: 8B → 7A (✗ Incompatible) ()
#    BPM:     144 → 150 (Δ6)
#    Energy:  ('0.90',) → ('0.90',) (Δ('0.00',))
#    Score:   0.41
#
# 307. Dil Ibaadat → Hua Hain Aaj Pehli Baar
#    Camelot: 7A → 11A (✗ Incompatible) ()
#    BPM:     150 → 156 (Δ6)
#    Energy:  ('0.90',) → ('0.70',) (Δ('-0.20',))
#    Score:   0.35
#
# 308. Hua Hain Aaj Pehli Baar → London Thumakda
#    Camelot: 11A → 8B (✗ Incompatible) ()
#    BPM:     156 → 140 (Δ16)
#    Energy:  ('0.70',) → ('0.70',) (Δ('0.00',))
#    Score:   0.26
#
# 309. London Thumakda → Kaise Ab Kahein - From "Gutar Gu"
#    Camelot: 8B → 7B (✓ Compatible) ()
#    BPM:     140 → 98 (Δ42)
#    Energy:  ('0.70',) → ('0.50',) (Δ('-0.20',))
#    Score:   0.42
#
# 310. Kaise Ab Kahein - From "Gutar Gu" → Kya Karoon? (From "Wake Up Sid ")
#    Camelot: 7B → 8A (✗ Incompatible) ()
#    BPM:     98 → 98 (Δ0)
#    Energy:  ('0.50',) → ('0.50',) (Δ('0.00',))
#    Score:   0.55
#
# 311. Kya Karoon? (From "Wake Up Sid ") → Tu Hi Hai
#    Camelot: 8A → 12B (✗ Incompatible) ()
#    BPM:     98 → 94 (Δ4)
#    Energy:  ('0.50',) → ('0.50',) (Δ('0.00',))
#    Score:   0.44
#
# 312. Tu Hi Hai → Maana Ke Hum Yaar Nahin
#    Camelot: 12B → 4B (✗ Incompatible) ()
#    BPM:     94 → 91 (Δ3)
#    Energy:  ('0.50',) → ('0.40',) (Δ('-0.10',))
#    Score:   0.49
#
# 313. Maana Ke Hum Yaar Nahin → Tu Hi Re - Bombay / Soundtrack Version
#    Camelot: 4B → 5B (✓ Compatible) ()
#    BPM:     91 → 100 (Δ9)
#    Energy:  ('0.40',) → ('0.20',) (Δ('-0.20',))
#    Score:   0.92
#
# 314. Tu Hi Re - Bombay / Soundtrack Version → Ajab Si
#    Camelot: 5B → 4B (✓ Compatible) ()
#    BPM:     100 → 118 (Δ18)
#    Energy:  ('0.20',) → ('0.40',) (Δ('0.20',))
#    Score:   0.63
#
# 315. Ajab Si → O Re Piya (MTV Unplugged)
#    Camelot: 4B → 3A (✗ Incompatible) ()
#    BPM:     118 → 110 (Δ8)
#    Energy:  ('0.40',) → ('0.50',) (Δ('0.10',))
#    Score:   0.37
#
# 316. O Re Piya (MTV Unplugged) → Chahun Main Ya Naa
#    Camelot: 3A → 8A (✗ Incompatible) ()
#    BPM:     110 → 107 (Δ3)
#    Energy:  ('0.50',) → ('0.50',) (Δ('0.00',))
#    Score:   0.50
#
# 317. Chahun Main Ya Naa → Luka Chuppi
#    Camelot: 8A → 12B (✗ Incompatible) ()
#    BPM:     107 → 104 (Δ3)
#    Energy:  ('0.50',) → ('0.40',) (Δ('-0.10',))
#    Score:   0.49
#
# 318. Luka Chuppi → Kaun Mera
#    Camelot: 12B → 10B (✗ Incompatible) ()
#    BPM:     104 → 101 (Δ3)
#    Energy:  ('0.40',) → ('0.20',) (Δ('-0.20',))
#    Score:   0.43
#
# 319. Kaun Mera → Kaise Mein Kahun Tujhse
#    Camelot: 10B → 8A (✗ Incompatible) ()
#    BPM:     101 → 86 (Δ15)
#    Energy:  ('0.20',) → ('0.10',) (Δ('-0.10',))
#    Score:   0.27
#
# 320. Kaise Mein Kahun Tujhse → Moh Moh Ke Dhaage (Female)
#    Camelot: 8A → 10B (✗ Incompatible) ()
#    BPM:     86 → 128 (Δ42)
#    Energy:  ('0.10',) → ('0.40',) (Δ('0.30',))
#    Score:   0.17
# --------------------------------------------------------------------------------
# Average Transition Score (for 320 scored transitions): 1.25
# --------------------------------------------------------------------------------

# %%
# --- Compare and Display Changes ---
print("\nComparing original (scraped order) and sorted playlists...")
original_df, sorted_df = sorter.compare_playlists(sorted_ids)

if not original_df.empty and not sorted_df.empty:
    # Display original playlist
    print(f"\n\nORIGINAL PLAYLIST ORDER (Scraped from songdata.io): {sorter.playlist_name}")
    print("-" * 90)
    cols_orig = ['Position', 'Track', 'Artist', 'Camelot', 'BPM', 'Energy']
    print(original_df[[c for c in cols_orig if c in original_df.columns]].to_string(index=False, max_colwidth=40))
    print("-" * 90)

    # Display sorted playlist with position changes
    print(f"\n\nPROPOSED SORTED PLAYLIST: {sorter.playlist_name}")
    print("-" * 100)
    cols_sorted = ['Position', 'Track', 'Artist', 'Camelot', 'BPM', 'Energy', 'Original Position', 'Position Change']
    # Format Position Change nicely
    if 'Position Change' in sorted_df.columns:
         sorted_df['Position Change Str'] = sorted_df['Position Change'].apply(
             lambda x: f"{'+' if pd.notna(x) and x > 0 else ''}{int(x)}" if pd.notna(x) else 'N/A'
         )
         # Ensure Original Position is displayed before the formatted change string
         cols_sorted_display = ['Position', 'Track', 'Artist', 'Camelot', 'BPM', 'Energy', 'Original Position', 'Position Change Str']
    else:
         cols_sorted_display = ['Position', 'Track', 'Artist', 'Camelot', 'BPM', 'Energy', 'Original Position']

    print(sorted_df[[c for c in cols_sorted_display if c in sorted_df.columns]].to_string(index=False, max_colwidth=40))
    print("-" * 100)

    # Highlight significant changes
    if 'Position Change' in sorted_df.columns and pd.api.types.is_numeric_dtype(sorted_df['Position Change']):
        big_movers = sorted_df.dropna(subset=['Position Change'])
        big_movers = big_movers[abs(big_movers['Position Change']) > 10] # Example threshold

        if not big_movers.empty:
            print("\n\nTracks with significant position changes (>10 positions):")
            print("-" * 80)
            for _, row in big_movers.iterrows():
                change = int(row['Position Change'])
                direction = "up" if change > 0 else "down"
                orig_pos = int(row['Original Position']) if pd.notna(row['Original Position']) else 'N/A'
                print(f"{row.get('Track', 'N/A')} by {row.get('Artist', 'N/A')}: Moved {direction} {abs(change)} positions (Original: {orig_pos}, New: {row.get('Position', 'N/A')})")
    else:
        print("\nCould not calculate significant position changes (Position Change data missing or non-numeric).")

else:
    print("\nCould not generate comparison dataframes.")
# Out:
# Comparing original (scraped order) and sorted playlists...
#
#
# ORIGINAL PLAYLIST ORDER (Scraped from songdata.io): Simply Bollywood (2000 - 2025)
# ------------------------------------------------------------------------------------------
#  Position                                    Track                                   Artist Camelot  BPM  Energy
#         1           Javeda Zindagi-Tose Naina Lage                Kshitij Tarey, Shilpa Rao     12A  130     0.6
#         2                  Yaariyaan - Male Vocals                             Mohan Kannan      9B  130     0.8
#         3                              Zaroori Tha                     Rahat Fateh Ali Khan      1A  114     0.7
#         4        Ek Dil Ek Jaan (From "Padmaavat")     Shivam Pathak, Sanjay Leela Bhansali     10B   98     0.7
#         5                                   Sajdaa Shankar-Ehsaan-Loy, Rahat Fateh Ali K...      4B   80     0.7
#         6                                     Ravi                               Sajjad Ali      4B  128     0.6
#         7                              Jiyein Kyun                            Pritam, Papon     12B   71     0.6
#         8                            Shukran Allah Salim–Sulaiman, Sonu Nigam, Shreya Gh...      3B   82     0.7
#         9           Ghodey Pe Sawaar (From "Qala") Amit Trivedi, Amitabh Bhattacharya, S...      5B  102     0.5
#        10                            Labb Par Aaye            Shankar-Ehsaan-Loy, Javed Ali     10A  133     0.5
#        11                                   Saware                     Pritam, Arijit Singh     11A  135     0.7
#        12                         Phir Se Ud Chala                            Mohit Chauhan      1B  120     0.7
#        13                        Abhi Kuch Dino Se                    Pritam, Mohit Chauhan     12B   92     0.7
#        14                                Nazm Nazm                                     Arko      9B   82     0.6
#        15                                  Tum Tak A.R. Rahman, Javed Ali, KIRTI SAGATHI...     10B  115     0.6
#        16                      Naina Da Kya Kasoor                             Amit Trivedi     11B   63     0.7
#        17                    Milne Hai Mujhse Aayi                             Arijit Singh     10A  144     0.7
#        18                             Teri Deewani Kailash Kher, Paresh Kamath, Naresh K...      9A   80     0.6
#        19                 Tujh Mein Rab Dikhta Hai                        Roop Kumar Rathod      4B   85     0.6
#        20                                Kaun Mera                                    Papon     10B   96     0.4
#        21                     Deewana Kar Raha Hai                                Javed Ali     10A  148     0.7
#        22                              Haule Haule                         Sukhwinder Singh      4A   90     0.8
#        23                  Hua Hain Aaj Pehli Baar Amaal Mallik, Armaan Malik, Palak Muc...     11A  156     0.7
#        24                         Teri Jhuki Nazar               Pritam, Shafqat Amanat Ali      1B  124     0.8
#        25                              Ay Hairathe A.R. Rahman, Hariharan, Alka Yagnik, ...     10B  122     0.4
#        26                                 Bin Tere Vishal-Shekhar, Shafqat Amanat Ali, S...     11B  140     0.7
#        27                              Manwa Laage             Shreya Ghoshal, Arijit Singh      8B   81     0.7
#        28                              Dil Ibaadat                               Pritam, KK      7A  150     0.9
#        29                                  Arziyan                  Javed Ali, Kailash Kher     11B  140     0.6
#        30                                Zehnaseeb Vishal-Shekhar, Chinmayi Sripada, She...      9B   78     0.6
#        31                                Abhi Abhi                       KK, Shreya Ghoshal     10B  144     0.6
#        32                                   Kabira      Pritam, Tochi Raina, Rekha Bhardwaj     10B   84     0.6
#        33                                 Banjaara                           Mohammed Irfan     12A  116     0.5
#        34                                Tere Bina A.R. Rahman, Chinmayi, Murtuza Khan, ...     10B  144     0.7
#        35                                Laal Ishq                             Arijit Singh      5B  106     0.7
#        36                        Kuchh Toh Hua Hai                             Ankit Tiwari      9A   83     0.6
#        37                                 Pee Loon      Pritam, Mohit Chauhan, Irshad Kamil     10B  110     0.8
#        38                           Piya O Re Piya Atif Aslam, Shreya Ghoshal, Sachin-Jigar     10B  168     0.6
#        39                                Ali Maula           Salim–Sulaiman, Salim Merchant     10B  130     0.5
#        40                                   Iktara Amit Trivedi, Kavita Seth, Amitabh Bh...      9B   80     0.5
#        41 Tu Hi Hai (Ali Zafar Version) [From "...                  Amit Trivedi, Ali Zafar     12B  188     0.5
#        42                                 Dekho Na Jatin-Lalit, Sonu Nigam, Sunidhi Chau...      9B   83     0.7
#        43                                 Sab Tera            Armaan Malik, Shraddha Kapoor      9B  160     0.6
#        44              Rabba Main Toh Mar Gaya Oye             Pritam, Rahat Fateh Ali Khan     11B   88     0.8
#        45                      Bheegi Si Bhaagi Si      Pritam, Mohit Chauhan, Antara Mitra      4B   89     0.9
#        46                   Mera Pehla Pehla Pyaar                                       KK     10B   76     0.5
#        47       Chale Aana (From "De De Pyaar De")               Amaal Mallik, Armaan Malik     11A  144     0.6
#        48                          Achha Lagta Hai Shankar-Ehsaan-Loy, Mohit Chauhan, Sh...      4B  102     0.6
#        49                              Har Kisi Ko                Arijit Singh, Neeti Mohan      5B   95     0.7
#        50                                  Pasoori                     Shae Gill, Ali Sethi     10A   92     0.6
#        51               Aise Kyun - Ghazal Version Rekha Bhardwaj, Anurag Saikia, Raj Sh...      5B  152     0.4
#        52                                  Bulleya          Pritam, Amit Mishra, Shilpa Rao      7A   87     0.8
#        53        Nazar Na Lag Jaaye (From "Stree")                   Ash King, Sachin-Jigar      6A  174     0.6
#        54                               Mar Jawaan            Shruti Pathak, Salim Merchant      6B  150     0.7
#        55                        Jab Se Tere Naina                      Monty Sharma, Shaan      5A   80     0.7
#        56                          Tune Jo Na Kaha Pritam, Mohit Chauhan, Sandeep Shriva...      7B   79     0.5
#        57                                   Yaaron                                       KK      7B  114     0.5
#        58                                 Hai Rama                   Hariharan, Swarnalatha      2B   85     0.4
#        59                                   Bahara Vishal-Shekhar, Shreya Ghoshal, Sona ...      7B   86     0.7
#        60                                  Humdard                             Arijit Singh      7B   87     0.5
#        61                              Kurbaan Hua           Salim–Sulaiman, Vishal Dadlani      7A  166     0.7
#        62                              Sawaar Loon                            Monali Thakur      7B  112     0.6
#        63                            Phir Mohabbat  Mohammed Irfan, Arijit Singh, Saim Bhat      5A  200     0.5
#        64                         Ye Tune Kya Kiya                     Pritam, Javed Bashir      9B   92     0.8
#        65                              Jeena Jeena                 Sachin-Jigar, Atif Aslam      7B  105     0.3
#        66                                Aise Kyun Anurag Saikia, Raghav Chaitanya, Raj ...      7B  172     0.4
#        67          Thodi Jagah (From "Marjaavaan")             Arijit Singh, Tanishk Bagchi      5A  107     0.5
#        68                                 Tere Bin               Sonu Nigam, Shreya Ghoshal      8B  180     0.3
#        69 Bolna (From "Kapoor & Sons (Since 192... Tanishk Bagchi, Arijit Singh, Asees Kaur      7B  131     0.4
#        70                        Agar Tum Saath Ho                Alka Yagnik, Arijit Singh      5B  123     0.5
#        71                           Aas Paas Khuda                     Rahat Fateh Ali Khan      7B   80     0.7
#        72                                    Naina             Sona Mohapatra, Armaan Malik      5B  160     0.6
#        73                          Jeene Laga Hoon Atif Aslam, Shreya Ghoshal, Sachin-Jigar      6A   90     0.7
#        74                        Tujhe Sochta Hoon                               Pritam, KK      5A   81     0.7
#        75   Dil Beparvah - The Dewarists, Season 5 Ankur Tewari, Prateek Kuhad, Dhruv Bh...      3B  138     0.4
#        76                               Tere Naina   Shankar-Ehsaan-Loy, Shafqat Amanat Ali      8B   93     0.7
#        77    Dil Cheez Tujhe Dedi (From "Airlift")               Ankit Tiwari, Arijit Singh      7A  105     0.7
#        78        Ae Zindagi Gale Laga Le - Take, 1  Ilaiyaraaja, Amit Trivedi, Arijit Singh      7A  156     0.7
#        79                               Shaayraana                     Arijit Singh, Pritam     10B   94     0.7
#        80                              Kaise Mujhe              Benny Dayal, Shreya Ghoshal      6B   82     0.4
#        81                Inn Lamhon Ke Daaman Mein      A.R. Rahman, Sonu Nigam, Madhushree      3B  149     0.4
#        82                            Kitni Baatein Shankar-Ehsaan-Loy, Sadhana Sargam, H...      4B  159     0.4
#        83                             Shubhaarambh Amit Trivedi, Shruti Pathak, Divya Kumar      6B  115     0.5
#        84                              Matargashti                            Mohit Chauhan      8B  100     0.6
#        85                            Sunn Raha Hai                             Ankit Tiwari      5A   82     0.6
#        86                                Lae Dooba                          Sunidhi Chauhan      2B   90     0.3
#        87                         Mann Kunto Maula Sohail Sen, Shadab Faridi, Altamash F...      7B   90     0.7
#        88                                Pareshaan Amit Trivedi, Shalmali Kholgade, Kaus...      7A  150     0.4
#        89                                Enna Sona                A.R. Rahman, Arijit Singh      6A  100     0.4
#        90                        Phero Na Najariya Amit Trivedi, Kausar Munir, Sireesha ...     12A   85     0.8
#        91                   Mora Saiyaan - Khamaaj                        Siddharth Slathia      7B  112     0.5
#        92                       Ek Din Teri Raahon                        Javed Ali, Pritam      7A   92     0.9
#        93                        Kyun Main Jaagoon                       Shafqat Amanat Ali      4B  130     0.3
#        94                                 Bekhauff Ram Sampath, Sona Mohapatra, Svati Ch...      7B  140     0.5
#        95            Main Dhoondne Ko Zamaane Mein                             Arijit Singh      7A   80     0.4
#        96                        Raat Ke Dhai Baje Suresh Wadkar, Rekha Bhardwaj, Sunidh...      9B  100     0.7
#        97                     Kalank - Title Track                     Pritam, Arijit Singh      6B  118     0.7
#        98                              Manmarziyan Shilpa Rao, Amitabh Bhattacharya, Ami...      2B  100     0.3
#        99       Kahani (From "Laal Singh Chaddha") Pritam, Mohan Kanan, Amitabh Bhattach...      3B  150     0.3
#       100                                 Aashiyan Pritam, Shreya Ghoshal, Nikhil Paul G...      6B  132     0.6
#       101    O Rangrez (From "Bhaag Milkha Bhaag") Shankar-Ehsaan-Loy, Shreya Ghoshal, J...      7B  126     0.5
#       102                              Disco Disco Sachin-Jigar, Benny Dayal, Shirley Setia      9A  117     0.8
#       103                                Falak Tak Vishal-Shekhar, Udit Narayan, Mahalak...      7A  144     0.7
#       104                         Main Agar Kahoon               Sonu Nigam, Shreya Ghoshal      4A  147     0.4
#       105                                  Pardesi                              Tochi Raina      7B  124     0.8
#       106                             Jaan 'Nisaar                             Arijit Singh      6B   92     0.4
#       107                                 Tum Mile                  Pritam, Neeraj Shridhar      8B  123     0.8
#       108                  Saanson Ko (From "Zid")              Shaarib Toshi, Arijit Singh      7A  140     0.7
#       109                     Mera Mann Kehne Laga                            Falak Shabbir      9B   75     0.4
#       110                                 Hey Ya ! Clinton Cerejo, Shankar Mahadevan, Lo...      6A  115     0.6
#       111                                 Maahi Ve                              A.R. Rahman      7B  131     0.7
#       112                                O Saiyyan             Ajay-Atul, Roop Kumar Rathod      2B  166     0.5
#       113                                Abhi Abhi                                       KK     10B  144     0.6
#       114                       Saudebazi (Encore)                        Pritam, Javed Ali      7B  114     0.7
#       115    Tu Hi Meri Shab Hai - From "Gangster"                               Pritam, KK      8A  119     0.8
#       116                         Agar Main Kahoon Shankar-Ehsaan-Loy, Alka Yagnik, Udit...      8A  102     0.7
#       117 Suno- Na Sangemarmar (From "Youngistaan)                             Arijit Singh      5A  120     0.6
#       118         Kyun Dil Mera - From "Paharganj"                            Mohit Chauhan     11B  136     0.4
#       119                          London Thumakda    Labh Janjua, Sonu Kakkar, Neha Kakkar      8B  140     0.7
#       120                          Kabhi Neem Neem                  Madhushree, A.R. Rahman      8B  176     0.4
#       121                                   Tum Ko                     Kavita Krishnamurthy     10B  172     0.4
#       122                                    Jhoom                                Ali Zafar      8B  128     0.5
#       123                          Tere Pyaar Mein Pritam, Arijit Singh, Amitabh Bhattac...      3B  160     0.4
#       124                             Teri Fariyad             Rekha Bhardwaj, Jagjit Singh      8A   85     0.4
#       125                Guzarish (From "Ghajini")                                Javed Ali      8A  170     0.6
#       126                               Pehli Baar       Sukriti Kakar, Siddharth Mahadevan      8A  126     0.7
#       127                            Sunn Raha Hai                             Ankit Tiwari      6B   83     0.6
#       128                                    Safar                     Pritam, Arijit Singh      9B   86     0.6
#       129                                 Kahin To               Rashid Ali, Vasundhara Das      6B   91     0.5
#       130        Kaise Ab Kahein - From "Gutar Gu" Gaurav Chatterji, Aasa Singh, Hansika...      7B   98     0.5
#       131                            Locha-E-Ulfat                              Benny Dayal      8B  107     0.7
#       132                         Maula Mere Maula                        Roop Kumar Rathod      8B  120     0.7
#       133                                   Yun Hi                            Mohit Chauhan      4B  140     0.5
#       134                            Yoon Shabnami              Monty Sharma, Parthiv Gohil      7B   95     0.6
#       135                      Sun Le Re (Reprise)                                    Papon     10B  136     0.7
#       136                                     Hoor                 Atif Aslam, Sachin-Jigar     12B  150     0.4
#       137                              Ambarsariya                           Sona Mohapatra      9A  180     0.5
#       138                              Luka Chuppi             A.R. Rahman, Lata Mangeshkar     12B  104     0.4
#       139                                  Ajab Si                                       KK      4B  118     0.4
#       140                  Tujhe Kitna Chahne Lage                             Arijit Singh      1B   70     0.4
#       141           Sajni (From "Laapataa Ladies") Ram Sampath, Arijit Singh, Prashant P...      8B   80     0.4
#       142                                     Duaa             Nandini Srikar, Arijit Singh      4A  138     0.6
#       143       Afeemi (From "Meri Pyaari Bindu ") Sachin-Jigar, Sanah Moidutty, Kausar ...      9B   88     0.5
#       144       Agar Tum Saath Ho (From "Tamasha")                Alka Yagnik, Arijit Singh      5B  123     0.5
#       145                              Tadap Tadap                            KK, Dominique     10B  160     0.5
#       146                             Shubhaarambh Amit Trivedi, Shruti Pathak, Divya Kumar      6B  115     0.6
#       147                                    Naina                     Arijit Singh, Pritam      2B   80     0.4
#       148           Tujhko Jo Paaya (From "Crook")                    Pritam, Mohit Chauhan     11B  150     0.2
#       149                                    Saibo Sachin-Jigar, Shreya Ghoshal, Tochi R...     10B   90     0.4
#       150                                   Challa               A.R. Rahman, Rabbi, Gulzar      8B  118     0.8
#       151                      Tera Hone Laga Hoon        Atif Aslam, Alisha Chinai, Pritam      4B  120     0.8
#       152                         Bakhuda Tumhi Ho          Atif Aslam, Alka Yagnik, Pritam     10B  127     0.8
#       153                            Uff Teri Adaa       Shankar Mahadevan, Alyssa Mendonsa     10B  132     0.8
#       154                                    Behka                                  Karthik      5A  192     0.5
#       155                                 Isq Risk Sohail Sen, Rahat Fateh Ali Khan, Irs...      3A  105     0.6
#       156                           Le Le Mazaa Le Suzanne, Sowmya Raoh, Hrishikesh Kame...     10B  182     0.9
#       157 Tum Jo Aaye (From "Once Upon A Time I...        Rahat Fateh Ali Khan, Tulsi Kumar     12B   84     0.8
#       158             Raabta (Kehte Hain Khuda Ne)     Pritam, Shreya Ghoshal, Arijit Singh     12B  111     0.4
#       159 Darkhaast (feat. Arijit Singh, Sunidh...   Mithoon, Arijit Singh, Sunidhi Chauhan      9B  112     0.6
#       160                               Tu Hi Mera               Pritam, Shafqat Amanat Ali      1B   90     0.9
#       161                             Ishq Bulaava Vishal-Shekhar, Sanam Puri, Shipra Goyal      9B  160     0.7
#       162                                  Zaalima             Arijit Singh, Harshdeep Kaur     11B   88     0.9
#       163                                 Saiyaara Sohail Sen, Mohit Chauhan, Taraannum ...      1A   93     0.7
#       164                                   Gulabi Sachin-Jigar, Priya Saraiya, Jaideep ...     12B  124     0.7
#       165                             Tu Har Lamha                Bobby-Imran, Arijit Singh      7A  137     0.5
#       166 Laal Peeli Akhiyaan (From "Teri Baato...     Tanishk Bagchi, Romy, Neeraj Rajawat      4B  130     0.8
#       167                                 Zaroorat                            Mustafa Zahid      2A   93     0.7
#       168                        Kabhi Kabhi Aditi                               Rashid Ali      6A   95     0.6
#       169                               Ishq Shava  A.R. Rahman, Raghav, Shilpa Rao, Gulzar     11A  144     0.9
#       170                        Zindagi Do Pal Ki                                       KK      2B  106     0.8
#       171 Samjhawan (From "Humpty Sharma Ki Dul... Jawad Ahmad, Shaarib Toshi, Arijit Si...     12B  107     0.5
#       172                               Mast Magan                   Arijit Singh, Chinmayi      9B   83     0.8
#       173                            Te Amo (Duet)        Pritam, Ash King, Sunidhi Chauhan      1B  128     0.8
#       174               Sanam Re (From "Sanam Re")                    Mithoon, Arijit Singh      6A  112     0.7
#       175 Tere Hawaale (From "Laal Singh Chaddha")         Pritam, Arijit Singh, Shilpa Rao     11B  109     0.5
#       176                             Wajah Tum Ho     Armaan Malik, Baman, Manoj Muntashir      4A  104     0.7
#       177                             Noor E Khuda Shankar-Ehsaan-Loy, Adnan Sami, Shank...     10B  115     0.5
#       178             Galliyan (From "Ek Villain")                             Ankit Tiwari      3A   90     0.8
#       179                              Wat Wat Wat             Arijit Singh, Shashwat Singh     10B  150     0.9
#       180                                 Dooriyan                    Mohit Chauhan, Pritam      6A  123     0.7
#       181         Khamoshiyan (From "Khamoshiyan")              Jeet Gannguli, Arijit Singh      7A  144     0.5
#       182                               Daaru Desi           Benny Dayal, Shalmali Kholgade      7B  139     0.6
#       183                          Ilahi (Reprise)                    Pritam, Mohit Chauhan     11B  132     0.9
#       184                              Masha-Allah Monty Sharma, Kunal Ganjawala, Shreya...      5B  150     0.5
#       185                     Sajna Ji Vaari Vaari        Sunidhi Chauhan, Shekhar Ravjiani      8B  144     0.9
#       186                                  Baarish           Mohammed Irfan, Gajendra Verma      6A  127     0.4
#       187        Rishte Naate - From "De Dana Dan"    Rahat Fateh Ali Khan, Suzanne D'Mello      1B   92     0.8
#       188                                   Raabta                     Pritam, Arijit Singh      8B  118     0.6
#       189                                 Hale Dil                           Harshit Saxena     10A   80     0.9
#       190                              O Meri Jaan                               Pritam, KK      9B  150     0.8
#       191          Zindagi Kuch Toh Bata (Reprise)                   Pritam, Jubin Nautiyal      7B  124     0.6
#       192            Sapna Jahan (From "Brothers")       Ajay-Atul, Sonu Nigam, Neeti Mohan      5A  126     0.3
#       193             Kesariya (From "Brahmastra") Pritam, Arijit Singh, Amitabh Bhattac...      8B   94     0.6
#       194                             Soch Na Sake                             Arijit Singh     11B   76     0.6
#       195         Itni Si Baat Hain (From "Azhar")               Arijit Singh, Antara Mitra     10B  156     0.8
#       196                         Gallan Goodiyaan Yashita Sharma, Manish Kumar Tipu, Fa...     11A  120     0.9
#       197                      Second Hand Jawaani     Miss Pooja, Neha Kakkar, Nakash Aziz      9B  130     0.8
#       198                                  Baarish                           Mohammed Irfan      6A  142     0.5
#       199                                 Galliyan                             Ankit Tiwari      8A   85     0.5
#       200                               Tu Jo Mila                 Pritam, KK, Kausar Munir      8B  124     0.6
#       201                      Nashe Si Chadh Gayi Vishal-Shekhar, Arijit Singh, Jaideep...      9A   97     0.8
#       202                             Is This Love    Mohit Chauhan, Shreya Ghoshal, Pritam      9B  120     0.8
#       203                            Beete Lamhein                                       KK      9B  160     0.6
#       204                             Piya Aaye Na                          Tulsi Kumar, KK      9A   82     0.6
#       205        Kya Karoon? (From "Wake Up Sid ") Shankar-Ehsaan-Loy, Clinton Cerejo, D...      8A   98     0.5
#       206 Bairi Piya - Devdas / Soundtrack Version             Udit Narayan, Shreya Ghoshal      8B  138     0.6
#       207                            Dekhte Dekhte                 Rochak Kohli, Atif Aslam      8A  105     0.8
#       208                                Saathiyaa                     Shreya Ghoshal, Ajay     10B   87     0.7
#       209                                  Adhoore          Vishal Dadlani, Alyssa Mendonsa      8B  108     0.5
#       210                  Kaise Mein Kahun Tujhse                                       KK      8A   86     0.1
#       211                   Sunn Raha Hai (Female)                           Shreya Ghoshal      8A   82     0.6
#       212                                 Guzarish                                Javed Ali      8A  170     0.6
#       213                             Jee Le Zaraa                           Vishal Dadlani      9A   80     0.7
#       214             Banjaara (From "Ek Villain")                           Mohammed Irfan     12A  116     0.5
#       215                              Bhare Naina                           Nandini Srikar     12A  147     0.5
#       216                                  Saiyyan Kailash Kher, Paresh Kamath, Naresh K...      8B   75     0.6
#       217                            Khudaya Khair Pritam, Soham Chakraborty, Akriti Kak...      9B  172     0.7
#       218                       Dil To Bachcha Hai                     Rahat Fateh Ali Khan     11A   75     0.4
#       219                           Laaree Chootee                                     Call      8A   93     0.7
#       220         Nazrein Milaana Nazrein Churaana Benny Dayal, Satish Chakravarthy, Say...     11B  110     0.5
#       221                                 Manchala Vishal-Shekhar, Shafqat Amanat Ali, N...     10A   78     0.6
#       222                                Dekh Lena                Arijit Singh, Tulsi Kumar      8B  152     0.6
#       223               Pani Da Rang - Male Vocals                       Ayushmann Khurrana      4A  135     0.3
#       224                   Chaleya (From "Jawan") Anirudh Ravichander, Arijit Singh, Sh...      8B   95     0.8
#       225       Chan Kitthan (From "Chan Kitthan")                       Ayushmann Khurrana      7B   96     0.5
#       226                                 Banjaara         Mohammed Irfan, Shashaa Tirupati     12A  132     0.5
#       227                        Mere Rashke Qamar Nusrat Fateh Ali Khan, Rahat Fateh Al...      9A  105     0.8
#       228                  Saware (From "Phantom")                             Arijit Singh     11A  135     0.7
#       229                      Pehli Baar Mohabbat                            Mohit Chauhan      8A  160     0.5
#       230             Kehna Hi Kya - From "Bombay"                            K. S. Chithra      8A  127     0.3
#       231             Heeriye (feat. Arijit Singh) Jasleen Royal, Arijit Singh, Harrykah...      3B   83     0.4
#       232                             Dil Kya Kare                               Adnan Sami      9B   95     0.5
#       233                                   Hairat                                Lucky Ali      8A  104     0.8
#       234      Haareya (From "Meri Pyaari Bindu ") Sachin-Jigar, Arijit Singh, Priya Sar...      9A  124     0.4
#       235 Bekhayali (Arijit Singh Version) [Fro...           Arijit Singh, Sachet-Parampara      8A  172     0.6
#       236                        Such Keh Raha Hai                                       KK      9B  110     0.7
#       237                           Tumse Hi Tumse      Shekhar Ravjiani, Caralisa Monteiro      8B   92     0.5
#       238                       Chahun Main Ya Naa              Palak Muchhal, Arijit Singh      8A  107     0.5
#       239                                  In Dino                            Pritam, Soham      8B  101     0.6
#       240                              Khamoshiyan              Jeet Gannguli, Arijit Singh      7A  144     0.5
#       241          Bheegi Bheegi - From "Gangster"                            Pritam, James      8B  152     0.7
#       242                    Sooraj Ki Baahon Mein Dominique Cerejo, Clinton Cerejo, Loy...      1B  125     0.6
#       243                     Abhi Mujh Mein Kahin                    Ajay-Atul, Sonu Nigam     10B  130     0.4
#       244                             Dil Darbadar                             Ankit Tiwari      8A   90     0.5
#       245                                   Alvida                               Pritam, KK     10B   84     0.7
#       246                              Khabar Nahi Vishal-Shekhar, Shreya Ghoshal, Amana...      9B   91     0.8
#       247                Phir Le Aya Dil - Reprise                     Pritam, Arijit Singh      9B   78     0.5
#       248                               Tere Naina        Shankar Mahadevan, Shreya Ghoshal     11A  140     0.4
#       249               Moh Moh Ke Dhaage (Female)   Anu Malik, Monali Thakur, Varun Grover     10B  128     0.4
#       250                                Zara Zara                          Bombay Jayashri     10A  144     0.3
#       251                 Kaise Ab Kahein Acoustic               Aasa Singh, Hansika Pareek      9B  120     0.2
#       252 O Bedardeya (From "Tu Jhoothi Main Ma... Pritam, Arijit Singh, Amitabh Bhattac...      7B   95     0.2
#       253                                Chiraiyya             Swanand Kirkire, Ram Sampath      9B  120     0.3
#       254                Tu Jo Hain (From "Mr. X")                             Ankit Tiwari     10A  114     0.5
#       255                                  Humdard                   Mithoon, Palak Muchhal     10B  149     0.3
#       256                       Dekha Hazaro Dafaa Arijit Singh, Palak Muchhal, Manoj Mu...     12A  136     1.0
#       257 Roke Na Ruke Naina (From "Badrinath K...                             Arijit Singh     11B   81     0.4
#       258                                Darmiyaan       Shafqat Amanat Ali, Clinton Cerejo      9B  144     0.4
#       259                 Moh Moh Ke Dhaage (Male)           Anu Malik, Papon, Varun Grover     10B  128     0.3
#       260                    Hasi - Female Version Ami Mishra, Shreya Ghoshal, Kunaal Ve...      9A  144     0.5
#       261                              Kholo Kholo                          Raman Mahadevan     10A  170     0.3
#       262                         Jashn-E-Bahaaraa                   A.R. Rahman, Javed Ali     10B  138     0.3
#       263                                     Kyon           Pritam, Papon, Sunidhi Chauhan     10B  122     0.7
#       264                                Aye Khuda                           Salim Merchant      4B  109     0.9
#       265                                  Humdard                              Rahul Sathu      2B  162     0.3
#       266 Luteron Ka Lutera Version - Kalank Ti...                     Arijit Singh, Pritam      6B  118     0.2
#       267                              Halka Halka Rahat Fateh Ali Khan, Rashmi Virag, A...     10B  115     0.7
#       268             Piya O Re Piya - Sad Version               Atif Aslam, Shreya Ghoshal     10B   75     0.3
#       269                              Khwahishein           Salim–Sulaiman, Shreya Ghoshal     10A  145     0.5
#       270                           Lagan Laagi Re Amit Trivedi, Shreya Ghoshal, Kavita ...      8B  138     0.3
#       271                             I Am In Love                    Pritam, KK, Dominique     10B  130     0.7
#       272                               Hawa Banke     Rito Riba, Neha Kakkar, Rajat Nagpal     10B  150     0.3
#       273                              Jiyein Kyun                                    Papon     10B  144     0.6
#       274                In Dino - Refresh Version                           Mohammed Irfan      6B  106     0.3
#       275                          Saawali Si Raat                     Pritam, Arijit Singh     11B  140     0.3
#       276                                   Soniyo   Raju Singh, Sonu Nigam, Shreya Ghoshal     11B  120     0.6
#       277                                 Saaiyaan     Salim–Sulaiman, Rahat Fateh Ali Khan      7B  100     0.6
#       278  Ye Tune Kya Kiya - Arijit Singh Version                                    Zayan      9B  123     0.3
#       279                         Tujhe Bhula Diya Vishal-Shekhar, Mohit Chauhan, Shekha...     10A  132     0.4
#       280                         Te Amo (Reprise)                    Pritam, Mohit Chauhan      9B  128     0.3
#       281                           Chand Sifarish Jatin-Lalit, Shaan, Kailash Kher, Pra...     10B  122     0.7
#       282                         Dil Diyan Gallan Vishal-Shekhar, Atif Aslam, Irshad Kamil     10B  105     0.6
#       283                                 Monta Re Swanand Kirkire, Amitabh Bhattacharya...     12B  150     0.3
#       284           Aazaadiyan (Pairon Ki Bediyan) Amit Trivedi, Neuman Pinto, Nikhil D'...     10B  100     0.5
#       285                                 Labon Ko                               Pritam, KK      8A  108     0.8
#       286                              O Meri Jaan                               Pritam, KK      7A  134     0.6
#       287                                Kaun Mera                       Chaitra Ambadipudi     10B  101     0.2
#       288                                  Mehrama      Pritam, Darshan Raval, Antara Mitra      9B  108     0.6
#       289                                Piyu Bole               Sonu Nigam, Shreya Ghoshal     12B  114     0.3
#       290                              Be Intehaan      Atif Aslam, Sunidhi Chauhan, Pritam      9B  129     0.7
#       291                             Pyaar Ke Pal                                       KK     12B  122     0.1
#       292                             Mora Saiyyan                           Amit Thapliyal     12B   81     0.3
#       293   Tu Hi Re - Bombay / Soundtrack Version          Hariharan, Kavita Krishnamurthy      5B  100     0.2
#       294                        Kanha - Unplugged                       Ayushmann Khurrana      9B  120     0.3
#       295                                 Intezaar        Mithoon, Arijit Singh, Asees Kaur     10B  119     0.5
#       296                              O Saathi Re          Shreya Ghoshal, Vishal Bhardwaj      7A  168     0.3
#       297   Kali Kali Zulfon Ke - Extended Version                            Madhur Sharma      9B  154     0.4
#       298                                   Alvida Nikhil D'Souza, Sukhwinder Singh, Shr...     11B  150     0.2
#       299                              Ae Re Sakhi                         Namita Choudhary     10B  146     0.3
#       300          Ya Rabba (From "Salaam-E-Ishq")                             Kailash Kher     10B  144     0.4
#       301                    Ghungroo (From "War") Vishal-Shekhar, Arijit Singh, Shilpa ...     11A  118     0.7
#       302                  Maana Ke Hum Yaar Nahin Sachin-Jigar, Parineeti Chopra, Kausa...      4B   91     0.4
#       303                                  Jiya Re         A.R. Rahman, Neeti Mohan, Gulzar     10A  106     0.7
#       304                               Tose Naina                             Arijit Singh     12B  140     0.6
#       305                          Rab Ka Shukrana                    Pritam, Mohit Chauhan      3A  122     0.6
#       306                             Mere Nishaan           Kailash Kher, Meet Bros Anjjan      3B   98     0.5
#       307                                   Tu Hai              A.R. Rahman, Sanah Moidutty      1B   81     0.5
#       308                                Mann Mera                           Gajendra Verma     12A  192     0.8
#       309                              Bawara Mann              Jubin Nautiyal, Neeti Mohan      4B   85     0.5
#       310                           Tu Hai Ki Nahi                             Ankit Tiwari      3A  144     0.8
#       311    Shukran Allah - MTV Unplugged Version           Salim–Sulaiman, Salim Merchant      3B   85     0.5
#       312                             Jag Ghoomeya Vishal-Shekhar, Rahat Fateh Ali Khan,...      1B   83     0.6
#       313                                Tu Hi Hai               Amit Trivedi, Arijit Singh     12B   94     0.5
#       314                             Apna Bana Le               Sachin-Jigar, Arijit Singh     11B   94     0.6
#       315                O Re Piya (MTV Unplugged) Salim–Sulaiman, Rahat Fateh Ali Khan,...      3A  110     0.5
#       316 Bandook Meri Laila (feat. Raftaar, Si... Ash King, Jigar Saraiya, Raftaar, Sid...     11A   99     0.8
#       317         Dil Kyun Yeh Mera (From "Kites")                                       KK      2B  126     0.4
#       318                                 O Saathi                         Atif Aslam, Arko      4B   90     0.5
#       319                  Tera Rastaa Chhodoon Na        Amitabh Bhattacharya, Anusha Mani     12B  170     0.7
#       320                             Kun Faya Kun    A.R. Rahman, Javed Ali, Mohit Chauhan      3B   88     0.4
#       321                                    Sajde Shankar-Ehsaan-Loy, Arijit Singh, Nih...      3B  100     0.5
# ------------------------------------------------------------------------------------------
#
#
# PROPOSED SORTED PLAYLIST: Simply Bollywood (2000 - 2025)
# ----------------------------------------------------------------------------------------------------
#  Position                                    Track                                   Artist Camelot  BPM  Energy  Original Position Position Change Str
#         1                                   Iktara Amit Trivedi, Kavita Seth, Amitabh Bh...      9B   80     0.5                 40                 +39
#         2                             Teri Deewani Kailash Kher, Paresh Kamath, Naresh K...      9A   80     0.6                 18                 +16
#         3                                Nazm Nazm                                     Arko      9B   82     0.6                 14                 +11
#         4                             Piya Aaye Na                          Tulsi Kumar, KK      9A   82     0.6                204                +200
#         5                   Sunn Raha Hai (Female)                           Shreya Ghoshal      8A   82     0.6                211                +206
#         6                        Kuchh Toh Hua Hai                             Ankit Tiwari      9A   83     0.6                 36                 +30
#         7                                 Dekho Na Jatin-Lalit, Sonu Nigam, Sunidhi Chau...      9B   83     0.7                 42                 +35
#         8                                   Alvida                               Pritam, KK     10B   84     0.7                245                +237
#         9                               Mast Magan                   Arijit Singh, Chinmayi      9B   83     0.8                172                +163
#        10                              Manwa Laage             Shreya Ghoshal, Arijit Singh      8B   81     0.7                 27                 +17
#        11                           Aas Paas Khuda                     Rahat Fateh Ali Khan      7B   80     0.7                 71                 +60
#        12                            Sunn Raha Hai                             Ankit Tiwari      6B   83     0.6                127                +115
#        13                                   Bahara Vishal-Shekhar, Shreya Ghoshal, Sona ...      7B   86     0.7                 59                 +46
#        14                                  Bulleya          Pritam, Amit Mishra, Shilpa Rao      7A   87     0.8                 52                 +38
#        15                          Jeene Laga Hoon Atif Aslam, Shreya Ghoshal, Sachin-Jigar      6A   90     0.7                 73                 +58
#        16                       Ek Din Teri Raahon                        Javed Ali, Pritam      7A   92     0.9                 92                 +76
#        17                           Laaree Chootee                                     Call      8A   93     0.7                219                +202
#        18                               Tere Naina   Shankar-Ehsaan-Loy, Shafqat Amanat Ali      8B   93     0.7                 76                 +58
#        19                         Ye Tune Kya Kiya                     Pritam, Javed Bashir      9B   92     0.8                 64                 +45
#        20                   Chaleya (From "Jawan") Anirudh Ravichander, Arijit Singh, Sh...      8B   95     0.8                224                +204
#        21                            Yoon Shabnami              Monty Sharma, Parthiv Gohil      7B   95     0.6                134                +113
#        22             Kesariya (From "Brahmastra") Pritam, Arijit Singh, Amitabh Bhattac...      8B   94     0.6                193                +171
#        23                             Dil Kya Kare                               Adnan Sami      9B   95     0.5                232                +209
#        24                                Kaun Mera                                    Papon     10B   96     0.4                 20                  -4
#        25                             Apna Bana Le               Sachin-Jigar, Arijit Singh     11B   94     0.6                314                +289
#        26                               Shaayraana                     Arijit Singh, Pritam     10B   94     0.7                 79                 +53
#        27                                  Pasoori                     Shae Gill, Ali Sethi     10A   92     0.6                 50                 +23
#        28                                    Saibo Sachin-Jigar, Shreya Ghoshal, Tochi R...     10B   90     0.4                149                +121
#        29       Afeemi (From "Meri Pyaari Bindu ") Sachin-Jigar, Sanah Moidutty, Kausar ...      9B   88     0.5                143                +114
#        30                                Saathiyaa                     Shreya Ghoshal, Ajay     10B   87     0.7                208                +178
#        31              Rabba Main Toh Mar Gaya Oye             Pritam, Rahat Fateh Ali Khan     11B   88     0.8                 44                 +13
#        32 Tum Jo Aaye (From "Once Upon A Time I...        Rahat Fateh Ali Khan, Tulsi Kumar     12B   84     0.8                157                +125
#        33                        Phero Na Najariya Amit Trivedi, Kausar Munir, Sireesha ...     12A   85     0.8                 90                 +57
#        34                        Abhi Kuch Dino Se                    Pritam, Mohit Chauhan     12B   92     0.7                 13                 -21
#        35        Rishte Naate - From "De Dana Dan"    Rahat Fateh Ali Khan, Suzanne D'Mello      1B   92     0.8                187                +152
#        36                                 Saiyaara Sohail Sen, Mohit Chauhan, Taraannum ...      1A   93     0.7                163                +127
#        37                                 Zaroorat                            Mustafa Zahid      2A   93     0.7                167                +130
#        38             Galliyan (From "Ek Villain")                             Ankit Tiwari      3A   90     0.8                178                +140
#        39                              Haule Haule                         Sukhwinder Singh      4A   90     0.8                 22                 -17
#        40                      Bheegi Si Bhaagi Si      Pritam, Mohit Chauhan, Antara Mitra      4B   89     0.9                 45                  +5
#        41                             Kun Faya Kun    A.R. Rahman, Javed Ali, Mohit Chauhan      3B   88     0.4                320                +279
#        42                                 O Saathi                         Atif Aslam, Arko      4B   90     0.5                318                +276
#        43    Shukran Allah - MTV Unplugged Version           Salim–Sulaiman, Salim Merchant      3B   85     0.5                311                +268
#        44                              Bawara Mann              Jubin Nautiyal, Neeti Mohan      4B   85     0.5                309                +265
#        45             Heeriye (feat. Arijit Singh) Jasleen Royal, Arijit Singh, Harrykah...      3B   83     0.4                231                +186
#        46                                 Hai Rama                   Hariharan, Swarnalatha      2B   85     0.4                 58                 +12
#        47                             Jag Ghoomeya Vishal-Shekhar, Rahat Fateh Ali Khan,...      1B   83     0.6                312                +265
#        48                                    Naina                     Arijit Singh, Pritam      2B   80     0.4                147                 +99
#        49                                   Tu Hai              A.R. Rahman, Sanah Moidutty      1B   81     0.5                307                +258
#        50                             Mora Saiyyan                           Amit Thapliyal     12B   81     0.3                292                +242
#        51 Roke Na Ruke Naina (From "Badrinath K...                             Arijit Singh     11B   81     0.4                257                +206
#        52                                   Kabira      Pritam, Tochi Raina, Rekha Bhardwaj     10B   84     0.6                 32                 -20
#        53                                    Safar                     Pritam, Arijit Singh      9B   86     0.6                128                 +75
#        54                             Jee Le Zaraa                           Vishal Dadlani      9A   80     0.7                213                +159
#        55                                 Hale Dil                           Harshit Saxena     10A   80     0.9                189                +134
#        56                   Mera Pehla Pehla Pyaar                                       KK     10B   76     0.5                 46                 -10
#        57                             Soch Na Sake                             Arijit Singh     11B   76     0.6                194                +137
#        58                       Dil To Bachcha Hai                     Rahat Fateh Ali Khan     11A   75     0.4                218                +160
#        59                                 Manchala Vishal-Shekhar, Shafqat Amanat Ali, N...     10A   78     0.6                221                +162
#        60             Piya O Re Piya - Sad Version               Atif Aslam, Shreya Ghoshal     10B   75     0.3                268                +208
#        61                     Mera Mann Kehne Laga                            Falak Shabbir      9B   75     0.4                109                 +48
#        62                                  Saiyyan Kailash Kher, Paresh Kamath, Naresh K...      8B   75     0.6                216                +154
#        63                                Zehnaseeb Vishal-Shekhar, Chinmayi Sripada, She...      9B   78     0.6                 30                 -33
#        64           Sajni (From "Laapataa Ladies") Ram Sampath, Arijit Singh, Prashant P...      8B   80     0.4                141                 +77
#        65                          Tune Jo Na Kaha Pritam, Mohit Chauhan, Sandeep Shriva...      7B   79     0.5                 56                  -9
#        66            Main Dhoondne Ko Zamaane Mein                             Arijit Singh      7A   80     0.4                 95                 +29
#        67                             Teri Fariyad             Rekha Bhardwaj, Jagjit Singh      8A   85     0.4                124                 +57
#        68                           Tumse Hi Tumse      Shekhar Ravjiani, Caralisa Monteiro      8B   92     0.5                237                +169
#        69                             Dil Darbadar                             Ankit Tiwari      8A   90     0.5                244                +175
#        70                      Nashe Si Chadh Gayi Vishal-Shekhar, Arijit Singh, Jaideep...      9A   97     0.8                201                +131
#        71                        Raat Ke Dhai Baje Suresh Wadkar, Rekha Bhardwaj, Sunidh...      9B  100     0.7                 96                 +25
#        72                              Matargashti                            Mohit Chauhan      8B  100     0.6                 84                 +12
# ...
# Ambarsariya by Sona Mohapatra: Moved down 17 positions (Original: 137, New: 154)
# Khudaya Khair by Pritam, Soham Chakraborty, Akriti Kakar, Monali Thakur: Moved up 62 positions (Original: 217, New: 155)
# Tum Ko by Kavita Krishnamurthy: Moved down 35 positions (Original: 121, New: 156)
# Kholo Kholo by Raman Mahadevan: Moved up 104 positions (Original: 261, New: 157)
# Piya O Re Piya by Atif Aslam, Shreya Ghoshal, Sachin-Jigar: Moved down 120 positions (Original: 38, New: 158)
# Sab Tera by Armaan Malik, Shraddha Kapoor: Moved down 116 positions (Original: 43, New: 159)
# Tadap Tadap by KK, Dominique: Moved down 15 positions (Original: 145, New: 160)
# Beete Lamhein by KK: Moved up 42 positions (Original: 203, New: 161)
# Itni Si Baat Hain (From "Azhar") by Arijit Singh, Antara Mitra: Moved up 33 positions (Original: 195, New: 162)
# Bheegi Bheegi - From "Gangster" by Pritam, James: Moved up 77 positions (Original: 241, New: 164)
# O Meri Jaan by Pritam, KK: Moved up 25 positions (Original: 190, New: 165)
# Wat Wat Wat by Arijit Singh, Shashwat Singh: Moved up 13 positions (Original: 179, New: 166)
# Deewana Kar Raha Hai by Javed Ali: Moved down 146 positions (Original: 21, New: 167)
# Tere Bina by A.R. Rahman, Chinmayi, Murtuza Khan, Qadir Khan: Moved down 134 positions (Original: 34, New: 168)
# Milne Hai Mujhse Aayi by Arijit Singh: Moved down 152 positions (Original: 17, New: 169)
# Abhi Abhi by KK, Shreya Ghoshal: Moved down 139 positions (Original: 31, New: 170)
# Khwahishein by Salim–Sulaiman, Shreya Ghoshal: Moved up 98 positions (Original: 269, New: 171)
# Hasi - Female Version by Ami Mishra, Shreya Ghoshal, Kunaal Vermaa: Moved up 88 positions (Original: 260, New: 172)
# Darmiyaan by Shafqat Amanat Ali, Clinton Cerejo: Moved up 85 positions (Original: 258, New: 173)
# Ya Rabba (From "Salaam-E-Ishq") by Kailash Kher: Moved up 126 positions (Original: 300, New: 174)
# Zara Zara by Bombay Jayashri: Moved up 75 positions (Original: 250, New: 175)
# Ae Re Sakhi by Namita Choudhary: Moved up 123 positions (Original: 299, New: 176)
# Tujhko Jo Paaya (From "Crook") by Pritam, Mohit Chauhan: Moved down 29 positions (Original: 148, New: 177)
# Hawa Banke by Rito Riba, Neha Kakkar, Rajat Nagpal: Moved up 94 positions (Original: 272, New: 178)
# Alvida by Nikhil D'Souza, Sukhwinder Singh, Shruti Haasan, Loy Mendonsa: Moved up 119 positions (Original: 298, New: 179)
# Monta Re by Swanand Kirkire, Amitabh Bhattacharya, Amit Trivedi: Moved up 103 positions (Original: 283, New: 180)
# Bhare Naina by Nandini Srikar: Moved up 34 positions (Original: 215, New: 181)
# Chale Aana (From "De De Pyaar De") by Amaal Mallik, Armaan Malik: Moved down 135 positions (Original: 47, New: 182)
# Arziyan by Javed Ali, Kailash Kher: Moved down 154 positions (Original: 29, New: 183)
# Tose Naina by Arijit Singh: Moved up 120 positions (Original: 304, New: 184)
# Bin Tere by Vishal-Shekhar, Shafqat Amanat Ali, Sunidhi Chauhan: Moved down 159 positions (Original: 26, New: 185)
# Tere Naina by Shankar Mahadevan, Shreya Ghoshal: Moved up 62 positions (Original: 248, New: 186)
# Saawali Si Raat by Pritam, Arijit Singh: Moved up 88 positions (Original: 275, New: 187)
# Jashn-E-Bahaaraa by A.R. Rahman, Javed Ali: Moved up 74 positions (Original: 262, New: 188)
# Kyun Dil Mera - From "Paharganj" by Mohit Chauhan: Moved down 71 positions (Original: 118, New: 189)
# Sun Le Re (Reprise) by Papon: Moved down 55 positions (Original: 135, New: 190)
# Labb Par Aaye by Shankar-Ehsaan-Loy, Javed Ali: Moved down 181 positions (Original: 10, New: 191)
# Ali Maula by Salim–Sulaiman, Salim Merchant: Moved down 153 positions (Original: 39, New: 192)
# Yaariyaan - Male Vocals by Mohan Kannan: Moved down 191 positions (Original: 2, New: 193)
# Uff Teri Adaa by Shankar Mahadevan, Alyssa Mendonsa: Moved down 41 positions (Original: 153, New: 194)
# Ilahi (Reprise) by Pritam, Mohit Chauhan: Moved down 12 positions (Original: 183, New: 195)
# I Am In Love by Pritam, KK, Dominique: Moved up 75 positions (Original: 271, New: 196)
# Bakhuda Tumhi Ho by Atif Aslam, Alka Yagnik, Pritam: Moved down 46 positions (Original: 152, New: 198)
# Be Intehaan by Atif Aslam, Sunidhi Chauhan, Pritam: Moved up 91 positions (Original: 290, New: 199)
# Abhi Mujh Mein Kahin by Ajay-Atul, Sonu Nigam: Moved up 43 positions (Original: 243, New: 200)
# Tujhe Bhula Diya by Vishal-Shekhar, Mohit Chauhan, Shekhar Ravjiani, Shruti Pathak: Moved up 78 positions (Original: 279, New: 201)
# Saware by Pritam, Arijit Singh: Moved down 191 positions (Original: 11, New: 202)
# Dekha Hazaro Dafaa by Arijit Singh, Palak Muchhal, Manoj Muntashir: Moved up 53 positions (Original: 256, New: 203)
# Saware (From "Phantom") by Arijit Singh: Moved up 24 positions (Original: 228, New: 204)
# Banjaara by Mohammed Irfan, Shashaa Tirupati: Moved up 21 positions (Original: 226, New: 205)
# Gulabi by Sachin-Jigar, Priya Saraiya, Jaideep Sahni: Moved down 42 positions (Original: 164, New: 206)
# Teri Jhuki Nazar by Pritam, Shafqat Amanat Ali: Moved down 183 positions (Original: 24, New: 207)
# Dil Kyun Yeh Mera (From "Kites") by KK: Moved up 109 positions (Original: 317, New: 208)
# Sooraj Ki Baahon Mein by Dominique Cerejo, Clinton Cerejo, Loy Mendonsa: Moved up 33 positions (Original: 242, New: 209)
# Pyaar Ke Pal by KK: Moved up 81 positions (Original: 291, New: 210)
# Phir Se Ud Chala by Mohit Chauhan: Moved down 199 positions (Original: 12, New: 211)
# Piyu Bole by Sonu Nigam, Shreya Ghoshal: Moved up 77 positions (Original: 289, New: 212)
# Te Amo (Duet) by Pritam, Ash King, Sunidhi Chauhan: Moved down 40 positions (Original: 173, New: 213)
# Zindagi Do Pal Ki by KK: Moved down 44 positions (Original: 170, New: 214)
# Sajde by Shankar-Ehsaan-Loy, Arijit Singh, Nihira Joshi Deshpande, Gulzar: Moved up 106 positions (Original: 321, New: 215)
# Achha Lagta Hai by Shankar-Ehsaan-Loy, Mohit Chauhan, Shreya Ghoshal, Neuman Pinto: Moved down 168 positions (Original: 48, New: 216)
# Ghodey Pe Sawaar (From "Qala") by Amit Trivedi, Amitabh Bhattacharya, Sireesha Bhagavatula: Moved down 208 positions (Original: 9, New: 217)
# Thodi Jagah (From "Marjaavaan") by Arijit Singh, Tanishk Bagchi: Moved down 151 positions (Original: 67, New: 218)
# Laal Ishq by Arijit Singh: Moved down 184 positions (Original: 35, New: 219)
# Aye Khuda by Salim Merchant: Moved up 44 positions (Original: 264, New: 220)
# Wajah Tum Ho by Armaan Malik, Baman, Manoj Muntashir: Moved down 45 positions (Original: 176, New: 221)
# Isq Risk by Sohail Sen, Rahat Fateh Ali Khan, Irshad Kamil: Moved down 67 positions (Original: 155, New: 222)
# Mere Nishaan by Kailash Kher, Meet Bros Anjjan: Moved up 83 positions (Original: 306, New: 223)
# Manmarziyan by Shilpa Rao, Amitabh Bhattacharya, Amit Trivedi: Moved down 126 positions (Original: 98, New: 224)
# Tu Hi Mera by Pritam, Shafqat Amanat Ali: Moved down 65 positions (Original: 160, New: 225)
# Lae Dooba by Sunidhi Chauhan: Moved down 140 positions (Original: 86, New: 226)
# Shukran Allah by Salim–Sulaiman, Sonu Nigam, Shreya Ghoshal, Salim Merchant: Moved down 219 positions (Original: 8, New: 227)
# Sajdaa by Shankar-Ehsaan-Loy, Rahat Fateh Ali Khan, Shankar Mahadevan, Richa Sharma: Moved down 223 positions (Original: 5, New: 228)
# Har Kisi Ko by Arijit Singh, Neeti Mohan: Moved down 180 positions (Original: 49, New: 229)
# Jaan 'Nisaar by Arijit Singh: Moved down 124 positions (Original: 106, New: 230)
# Mann Kunto Maula by Sohail Sen, Shadab Faridi, Altamash Faridi, Irshad Kamil: Moved down 144 positions (Original: 87, New: 231)
# Kahin To by Rashid Ali, Vasundhara Das: Moved down 103 positions (Original: 129, New: 232)
# Humdard by Arijit Singh: Moved down 173 positions (Original: 60, New: 233)
# Kaise Mujhe by Benny Dayal, Shreya Ghoshal: Moved down 154 positions (Original: 80, New: 234)
# Kabhi Kabhi Aditi by Rashid Ali: Moved down 67 positions (Original: 168, New: 235)
# Sunn Raha Hai by Ankit Tiwari: Moved down 151 positions (Original: 85, New: 236)
# Nazar Na Lag Jaaye (From "Stree") by Ash King, Sachin-Jigar: Moved down 184 positions (Original: 53, New: 237)
# Behka by Karthik: Moved down 84 positions (Original: 154, New: 238)
# Masha-Allah by Monty Sharma, Kunal Ganjawala, Shreya Ghoshal: Moved down 55 positions (Original: 184, New: 239)
# Mar Jawaan by Shruti Pathak, Salim Merchant: Moved down 186 positions (Original: 54, New: 240)
# Aise Kyun - Ghazal Version by Rekha Bhardwaj, Anurag Saikia, Raj Shekhar, Mismatched: Moved down 190 positions (Original: 51, New: 241)
# Kitni Baatein by Shankar-Ehsaan-Loy, Sadhana Sargam, Hariharan: Moved down 160 positions (Original: 82, New: 242)
# Tere Pyaar Mein by Pritam, Arijit Singh, Amitabh Bhattacharya, Nikhita Gandhi: Moved down 120 positions (Original: 123, New: 243)
# Humdard by Rahul Sathu: Moved up 21 positions (Original: 265, New: 244)
# Kahani (From "Laal Singh Chaddha") by Pritam, Mohan Kanan, Amitabh Bhattacharya: Moved down 146 positions (Original: 99, New: 245)
# Tu Hai Ki Nahi by Ankit Tiwari: Moved up 64 positions (Original: 310, New: 246)
# Main Agar Kahoon by Sonu Nigam, Shreya Ghoshal: Moved down 143 positions (Original: 104, New: 247)
# Yun Hi by Mohit Chauhan: Moved down 115 positions (Original: 133, New: 248)
# Dil Beparvah - The Dewarists, Season 5 by Ankur Tewari, Prateek Kuhad, Dhruv Bhola, Nikhil Vasudevan: Moved down 174 positions (Original: 75, New: 249)
# Kyun Main Jaagoon by Shafqat Amanat Ali: Moved down 157 positions (Original: 93, New: 250)
# Pani Da Rang - Male Vocals by Ayushmann Khurrana: Moved down 28 positions (Original: 223, New: 251)
# Laal Peeli Akhiyaan (From "Teri Baaton Mein Aisa Uljha Jiya") by Tanishk Bagchi, Romy, Neeraj Rajawat: Moved down 86 positions (Original: 166, New: 252)
# Duaa by Nandini Srikar, Arijit Singh: Moved down 111 positions (Original: 142, New: 253)
# Ravi by Sajjad Ali: Moved down 248 positions (Original: 6, New: 254)
# Naina by Sona Mohapatra, Armaan Malik: Moved down 183 positions (Original: 72, New: 255)
# Tujh Mein Rab Dikhta Hai by Roop Kumar Rathod: Moved down 237 positions (Original: 19, New: 256)
# Galliyan by Ankit Tiwari: Moved down 58 positions (Original: 199, New: 257)
# Khamoshiyan by Jeet Gannguli, Arijit Singh: Moved down 18 positions (Original: 240, New: 258)
# Mora Saiyaan - Khamaaj by Siddharth Slathia: Moved down 168 positions (Original: 91, New: 259)
# In Dino - Refresh Version by Mohammed Irfan: Moved up 14 positions (Original: 274, New: 260)
# Jeena Jeena by Sachin-Jigar, Atif Aslam: Moved down 196 positions (Original: 65, New: 261)
# Sawaar Loon by Monali Thakur: Moved down 201 positions (Original: 62, New: 263)
# Dekh Lena by Arijit Singh, Tulsi Kumar: Moved down 42 positions (Original: 222, New: 264)
# Kali Kali Zulfon Ke - Extended Version by Madhur Sharma: Moved up 32 positions (Original: 297, New: 265)
# Humdard by Mithoon, Palak Muchhal: Moved down 11 positions (Original: 255, New: 266)
# Te Amo (Reprise) by Pritam, Mohit Chauhan: Moved up 13 positions (Original: 280, New: 267)
# Kaise Ab Kahein Acoustic by Aasa Singh, Hansika Pareek: Moved down 18 positions (Original: 251, New: 269)
# Naina Da Kya Kasoor by Amit Trivedi: Moved down 255 positions (Original: 16, New: 271)
# Jiyein Kyun by Pritam, Papon: Moved down 265 positions (Original: 7, New: 272)
# Tujhe Kitna Chahne Lage by Arijit Singh: Moved down 133 positions (Original: 140, New: 273)
# Hoor by Atif Aslam, Sachin-Jigar: Moved down 138 positions (Original: 136, New: 274)
# Pareshaan by Amit Trivedi, Shalmali Kholgade, Kausar Munir: Moved down 187 positions (Original: 88, New: 275)
# Enna Sona by A.R. Rahman, Arijit Singh: Moved down 187 positions (Original: 89, New: 276)
# Phir Mohabbat by Mohammed Irfan, Arijit Singh, Saim Bhat: Moved down 214 positions (Original: 63, New: 277)
# Sanam Re (From "Sanam Re") by Mithoon, Arijit Singh: Moved down 104 positions (Original: 174, New: 278)
# Jab Se Tere Naina by Monty Sharma, Shaan: Moved down 224 positions (Original: 55, New: 279)
# Tujhe Sochta Hoon by Pritam, KK: Moved down 206 positions (Original: 74, New: 280)
# Phir Le Aya Dil - Reprise by Pritam, Arijit Singh: Moved down 34 positions (Original: 247, New: 281)
# Khabar Nahi by Vishal-Shekhar, Shreya Ghoshal, Amanat Ali, Vishal Dadlani, Raja Hasan: Moved down 37 positions (Original: 246, New: 283)
# Ek Dil Ek Jaan (From "Padmaavat") by Shivam Pathak, Sanjay Leela Bhansali: Moved down 280 positions (Original: 4, New: 284)
# Zaalima by Arijit Singh, Harshdeep Kaur: Moved down 123 positions (Original: 162, New: 285)
# Bandook Meri Laila (feat. Raftaar, Sidharth Malhotra) by Ash King, Jigar Saraiya, Raftaar, Sidharth Malhotra: Moved up 30 positions (Original: 316, New: 286)
# Mann Mera by Gajendra Verma: Moved up 21 positions (Original: 308, New: 287)
# Tu Hi Hai (Ali Zafar Version) [From "Dear Zindagi"] by Amit Trivedi, Ali Zafar: Moved down 247 positions (Original: 41, New: 288)
# Javeda Zindagi-Tose Naina Lage by Kshitij Tarey, Shilpa Rao: Moved down 288 positions (Original: 1, New: 289)
# Gallan Goodiyaan by Yashita Sharma, Manish Kumar Tipu, Farhan Akhtar, Shankar Mahadevan, Sukhwinder Singh: Moved down 94 positions (Original: 196, New: 290)
# Rab Ka Shukrana by Pritam, Mohit Chauhan: Moved up 13 positions (Original: 305, New: 292)
# Inn Lamhon Ke Daaman Mein by A.R. Rahman, Sonu Nigam, Madhushree: Moved down 212 positions (Original: 81, New: 293)
# O Saiyyan by Ajay-Atul, Roop Kumar Rathod: Moved down 182 positions (Original: 112, New: 294)
# Tera Rastaa Chhodoon Na by Amitabh Bhattacharya, Anusha Mani: Moved up 24 positions (Original: 319, New: 295)
# Le Le Mazaa Le by Suzanne, Sowmya Raoh, Hrishikesh Kamerkar, Nikita Nigam: Moved down 140 positions (Original: 156, New: 296)
# Tere Bin by Sonu Nigam, Shreya Ghoshal: Moved down 229 positions (Original: 68, New: 297)
# Kehna Hi Kya - From "Bombay" by K. S. Chithra: Moved down 68 positions (Original: 230, New: 298)
# Lagan Laagi Re by Amit Trivedi, Shreya Ghoshal, Kavita Seth: Moved down 29 positions (Original: 270, New: 299)
# O Bedardeya (From "Tu Jhoothi Main Makkaar") by Pritam, Arijit Singh, Amitabh Bhattacharya: Moved down 48 positions (Original: 252, New: 300)
# Chan Kitthan (From "Chan Kitthan") by Ayushmann Khurrana: Moved down 76 positions (Original: 225, New: 301)
# Falak Tak by Vishal-Shekhar, Udit Narayan, Mahalakshmi Iyer, Kausar Munir: Moved down 199 positions (Original: 103, New: 302)
# Abhi Abhi by KK: Moved down 190 positions (Original: 113, New: 303)
# Jiyein Kyun by Papon: Moved down 31 positions (Original: 273, New: 304)
# Ishq Shava by A.R. Rahman, Raghav, Shilpa Rao, Gulzar: Moved down 136 positions (Original: 169, New: 305)
# Sajna Ji Vaari Vaari by Sunidhi Chauhan, Shekhar Ravjiani: Moved down 121 positions (Original: 185, New: 306)
# Dil Ibaadat by Pritam, KK: Moved down 279 positions (Original: 28, New: 307)
# Hua Hain Aaj Pehli Baar by Amaal Mallik, Armaan Malik, Palak Muchhal: Moved down 285 positions (Original: 23, New: 308)
# London Thumakda by Labh Janjua, Sonu Kakkar, Neha Kakkar: Moved down 190 positions (Original: 119, New: 309)
# Kaise Ab Kahein - From "Gutar Gu" by Gaurav Chatterji, Aasa Singh, Hansika Pareek, Hrishi Giridhar, Pratik Gangavane: Moved down 180 positions (Original: 130, New: 310)
# Kya Karoon? (From "Wake Up Sid ") by Shankar-Ehsaan-Loy, Clinton Cerejo, Dominique Cerejo, Loy Mendonsa: Moved down 106 positions (Original: 205, New: 311)
# Maana Ke Hum Yaar Nahin by Sachin-Jigar, Parineeti Chopra, Kausar Munir: Moved down 11 positions (Original: 302, New: 313)
# Tu Hi Re - Bombay / Soundtrack Version by Hariharan, Kavita Krishnamurthy: Moved down 21 positions (Original: 293, New: 314)
# Ajab Si by KK: Moved down 176 positions (Original: 139, New: 315)
# Chahun Main Ya Naa by Palak Muchhal, Arijit Singh: Moved down 79 positions (Original: 238, New: 317)
# Luka Chuppi by A.R. Rahman, Lata Mangeshkar: Moved down 180 positions (Original: 138, New: 318)
# Kaun Mera by Chaitra Ambadipudi: Moved down 32 positions (Original: 287, New: 319)
# Kaise Mein Kahun Tujhse by KK: Moved down 110 positions (Original: 210, New: 320)
# Moh Moh Ke Dhaage (Female) by Anu Malik, Monali Thakur, Varun Grover: Moved down 72 positions (Original: 249, New: 321)

# %%
# --- Confirmation and Update ---
print("\n" + "="*30 + " Update Spotify Playlist " + "="*30)
# Ask for user confirmation before updating the playlist
confirmation = input(f"\nReady to update '{sorter.playlist_name}' on Spotify with the sorted order? \nThis will REPLACE the current playlist content. (yes/no): ").strip().lower()

if confirmation in ['yes', 'y']:
    # Update the playlist on Spotify
    sorter.update_spotify_playlist(sorted_ids)
    # Confirmation message is now inside the update function on success/failure
else:
    print("\nUpdate canceled. Your Spotify playlist remains unchanged.")

# Handle case where sorting failed earlier
if 'sorted_ids' not in locals() or not sorted_ids:
     print("\nSkipping comparison and Spotify update: Playlist was not sorted successfully.")
# Out:
# ============================== Update Spotify Playlist ==============================
# INFO: Fetching URIs for 321 sorted tracks...
# INFO: Updating Spotify playlist 'Simply Bollywood (2000 - 2025)' with 321 tracks.
# INFO: Replaced/set first 100 tracks.
# INFO: Added batch of 100 tracks (starting index 100).
# INFO: Added batch of 100 tracks (starting index 200).
# INFO: Added batch of 21 tracks (starting index 300).
# INFO: Successfully updated playlist 'Simply Bollywood (2000 - 2025)' order on Spotify!
