# %% [markdown]
# # Playlist Sorter Notebook
#
# This notebook implements a `PlaylistSorter` class to sort music playlists based on harmonic mixing (Camelot keys), BPM, and energy.
#
# **Features:**
# *   Loads playlist data from a CSV file.
# *   Requires columns: `Track`, `Camelot`, `BPM`, `Energy`.
# *   Builds a Camelot wheel neighbor map.
# *   Finds a suitable opener track based on energy (and optionally popularity).
# *   Sorts the playlist by finding the best transitions based on Camelot key compatibility and BPM similarity.
# *   Exports the sorted playlist to a new CSV file.
# *   Optionally prints the Camelot and BPM transition paths.

# %% [markdown]
# ## Setting Up a Virtual Environment (Recommended)
#
# Before running this notebook and installing packages, it's best practice to create an isolated Python environment using `venv`. This prevents conflicts between project dependencies.
#
# **Steps:**
#
# 1.  **Open your terminal or command prompt.**
# 2.  **Navigate to your project directory** (where you saved this `.ipynb` file).
# 3.  **Create the virtual environment:**
#     ```bash
#     python -m venv venv
#     ```
#     (You can replace `venv` with any name you prefer for the environment folder).
# 4.  **Activate the virtual environment:**
#     *   **Windows (Command Prompt):** `venv\Scripts\activate`
#     *   **Windows (PowerShell):** `venv\Scripts\Activate.ps1` (You might need to adjust execution policy: `Set-ExecutionPolicy Unrestricted -Scope Process`)
#     *   **macOS/Linux (bash/zsh):** `source venv/bin/activate`
#
#     You'll know it's active because your terminal prompt will usually show the environment name (e.g., `(venv) Your-Computer:project_folder $`).
# 5.  **Install required packages:**
#     ```bash
#     pip install pandas numpy jupyterlab # Or 'pip install pandas numpy notebook' for classic notebook
#     ```
# 6.  **Start JupyterLab (or Notebook):**
#     ```bash
#     jupyter lab
#     # or
#     # jupyter notebook
#     ```
#     This will open Jupyter in your browser, running with the packages installed in your virtual environment.
# 7.  **Deactivate (when done):** Simply type `deactivate` in the terminal.

# %%
import pandas as pd
import argparse
from typing import List, Dict, Optional
import csv
import os # Added for file existence check in notebook example

# %% [markdown]
# ## The PlaylistSorter Class

# %%
class PlaylistSorter:
    """Tool for sorting playlists based on Camelot keys and other audio features."""
    
    def __init__(self, input_file: str):
        """Initialize with input CSV file containing playlist data."""
        self.tracks = self._load_tracks(input_file)
        if self.tracks is not None: # Only build neighbors if loading succeeded
            self.camelot_neighbors = self._build_camelot_neighbors()
        else:
             # Raise an exception or handle the error appropriately
             # For notebook usage, we might let it proceed and fail later, 
             # or raise an exception here.
             # Raising an exception is cleaner if _load_tracks guarantees failure exit.
             # Since _load_tracks uses sys.exit, we might not reach here in script mode,
             # but in notebook mode, sys.exit might just kill the kernel.
             # Let's assume _load_tracks returns None on failure for notebook context.
             raise ValueError(f"Failed to load tracks from {input_file}. Cannot initialize Sorter.")
        
    def _load_tracks(self, input_file: str) -> Optional[pd.DataFrame]:
        """Load tracks from a CSV file."""
        try:
            if not os.path.exists(input_file):
                print(f"Error: Input file not found at '{input_file}'")
                # In a notebook, sys.exit is disruptive. Return None or raise Exception.
                # Returning None allows the caller (__init__) to handle it.
                return None 
                
            df = pd.read_csv(input_file)
            required_columns = ["Track", "Camelot", "BPM", "Energy"]
            
            # Check if all required columns exist
            missing_columns = [col for col in required_columns if col not in df.columns]
            if missing_columns:
                print(f"Error: Missing required columns: {', '.join(missing_columns)}")
                if "Camelot" not in df.columns and "Key" in df.columns:
                    print("Note: 'Camelot' column is missing but 'Key' is present. Consider converting Key to Camelot format.")
                # In a notebook, sys.exit is disruptive. Return None or raise Exception.
                return None
                
            # Attempt to convert relevant columns to numeric, coercing errors
            for col in ['BPM', 'Energy']:
                 if col in df.columns:
                     df[col] = pd.to_numeric(df[col], errors='coerce')
            
            # Handle potential NaN values introduced by coercion or already present
            if df['BPM'].isnull().any() or df['Energy'].isnull().any():
                print("Warning: Found non-numeric or missing values in BPM or Energy columns. Rows with issues:")
                print(df[df['BPM'].isnull() | df['Energy'].isnull()])
                # Option 1: Drop rows with NaN in essential columns
                df.dropna(subset=['BPM', 'Energy'], inplace=True)
                print(f"Removed rows with missing BPM/Energy. {len(df)} tracks remaining.")
                # Option 2: Fill with a default (e.g., median), but dropping is safer for sorting
                # df['BPM'].fillna(df['BPM'].median(), inplace=True)
                # df['Energy'].fillna(df['Energy'].median(), inplace=True)

            if df.empty:
                print("Error: No valid tracks remaining after handling missing/invalid data.")
                return None

            # Ensure Camelot is string type
            if 'Camelot' in df.columns:
                 df['Camelot'] = df['Camelot'].astype(str)

            return df
        except Exception as e:
            print(f"Error loading tracks from {input_file}: {e}")
            # In a notebook, sys.exit is disruptive. Return None or raise Exception.
            return None
    
    def _build_camelot_neighbors(self) -> Dict[str, Dict[str, List[str]]]:
        """Build a dictionary of neighboring keys on the Camelot wheel."""
        neighbors = {}
        
        # For each number 1-12
        for num in range(1, 13):
            # For both A (minor) and B (major)
            for letter in ['A', 'B']:
                key = f"{num}{letter}"
                
                # Same number, different letter (e.g., 1A to 1B)
                related_letter = 'B' if letter == 'A' else 'A'
                related_by_letter = f"{num}{related_letter}"
                
                # Same letter, +1 number (wrapping from 12 to 1)
                next_num = 1 if num == 12 else num + 1
                related_next = f"{next_num}{letter}"
                
                # Same letter, -1 number (wrapping from 1 to 12)
                prev_num = 12 if num == 1 else num - 1
                related_prev = f"{prev_num}{letter}"
                
                # Add all neighbors
                # Primary neighbors (closest matches)
                primary = [related_by_letter, related_next, related_prev]
                # Secondary neighbors (still work but slightly less perfect)
                secondary = []
                
                # Add the +1/-1 for the related letter
                next_num_related = 1 if num == 12 else num + 1
                prev_num_related = 12 if num == 1 else num - 1
                secondary.append(f"{next_num_related}{related_letter}")
                secondary.append(f"{prev_num_related}{related_letter}")
                
                # Add the +2/-2 for the same letter
                # Corrected modulo arithmetic for wrapping
                next_num_2 = (num % 12) + 1 # +1 step
                next_num_2 = (next_num_2 % 12) + 1 # +2 step
                
                prev_num_2 = (num - 2 + 12) % 12 + 1 # -1 step
                prev_num_2 = (prev_num_2 - 2 + 12) % 12 + 1 # -2 step
                
                secondary.append(f"{next_num_2}{letter}")
                secondary.append(f"{prev_num_2}{letter}")
                
                # Remove duplicates just in case logic generated some (e.g., at wraps)
                primary = list(dict.fromkeys(primary))
                secondary = list(dict.fromkeys(secondary))
                all_neighbors = list(dict.fromkeys(primary + secondary))
                
                neighbors[key] = {
                    'primary': primary,
                    'secondary': secondary,
                    'all': all_neighbors
                }
                
        return neighbors
    
    def get_track_by_index(self, index: int) -> Optional[Dict]:
        """Get track information as a dictionary by index."""
        if self.tracks is None:
            print("Error: Tracks not loaded.")
            return None
        if 0 <= index < len(self.tracks):
            return self.tracks.iloc[index].to_dict()
        print(f"Error: Index {index} out of bounds.")
        return None
        
    def find_best_opener(self) -> Optional[int]:
        """Find the best opener track based on energy and popularity."""
        if self.tracks is None or self.tracks.empty:
            print("Error: No tracks available to find an opener.")
            return None
            
        # Prioritize tracks with higher energy and popularity
        # Use .get('Popularity', pd.Series(0, index=self.tracks.index)) for robustness
        popularity_col = self.tracks.get('Popularity', pd.Series(0, index=self.tracks.index))
        # Ensure popularity is numeric, default to 0 if not
        popularity_col = pd.to_numeric(popularity_col, errors='coerce').fillna(0)
        
        # Ensure Energy is present and numeric (already handled in _load_tracks, but double-check)
        if 'Energy' not in self.tracks or not pd.api.types.is_numeric_dtype(self.tracks['Energy']):
             print("Error: 'Energy' column is missing or not numeric.")
             # Fallback: maybe just return the first track index?
             return self.tracks.index[0] if not self.tracks.empty else None
             
        # Normalize popularity (0-100) to 0-1 scale
        max_popularity = popularity_col.max()
        normalized_popularity = popularity_col / 100.0 if max_popularity > 0 else popularity_col
        
        # Normalize energy (assuming it's often 0-1, but check range just in case)
        # If energy is not 0-1, adjust normalization. Assuming it is for now.
        energy_col = self.tracks['Energy']
        
        self.tracks['opener_score'] = (
            energy_col * 0.6 + 
            normalized_popularity * 0.4
        )
        
        # idxmax returns the index label
        best_opener_index_label = self.tracks['opener_score'].idxmax()
        # We need the positional index for list operations later
        best_opener_positional_index = self.tracks.index.get_loc(best_opener_index_label)
        
        # Clean up the temporary column
        # del self.tracks['opener_score'] 
        # Keep score for debugging if needed
        
        print(f"Selected opener: Track '{self.tracks.loc[best_opener_index_label, 'Track']}' (Index: {best_opener_positional_index}) with score {self.tracks.loc[best_opener_index_label, 'opener_score']:.2f}")
        return best_opener_positional_index
    
    def find_best_transition(self, current_track_dict: Dict, remaining_indices: List[int], 
                             allow_secondary: bool = False) -> Optional[int]:
        """Find the best next track based on Camelot compatibility and BPM."""
        if self.tracks is None:
             print("Error: Tracks not loaded.")
             return None
             
        current_camelot = current_track_dict.get('Camelot')
        current_bpm = current_track_dict.get('BPM')
        
        if not current_camelot or not current_bpm or current_camelot not in self.camelot_neighbors:
            print(f"Warning: Invalid current track data (Camelot: {current_camelot}, BPM: {current_bpm}). Cannot find transition.")
            # Fallback: maybe return the first remaining index?
            return remaining_indices[0] if remaining_indices else None
        
        # Get compatible keys
        compatible_keys = self.camelot_neighbors[current_camelot]['primary']
        if allow_secondary:
            compatible_keys += self.camelot_neighbors[current_camelot]['secondary']
        # Ensure unique keys
        compatible_keys = list(dict.fromkeys(compatible_keys))
        
        best_match_idx = None
        best_score = -1
        
        # Use positional indices for iloc
        for positional_idx in remaining_indices:
            # Get track data using positional index
            next_track = self.tracks.iloc[positional_idx].to_dict()
            next_camelot = next_track.get('Camelot')
            next_bpm = next_track.get('BPM')
            
            if not next_camelot or pd.isna(next_bpm):
                # Skip tracks with missing essential data
                continue 
            
            # Check key compatibility
            is_compatible = False
            key_match_score = 0.0
            if next_camelot == current_camelot:
                is_compatible = True
                key_match_score = 1.0
            elif next_camelot in self.camelot_neighbors[current_camelot]['primary']:
                is_compatible = True
                key_match_score = 0.8
            elif allow_secondary and next_camelot in self.camelot_neighbors[current_camelot]['secondary']:
                is_compatible = True
                key_match_score = 0.5
                
            if not is_compatible:
                continue
            
            # Calculate BPM match (closer is better, normalized to a 0-1 scale)
            bpm_diff = abs(next_bpm - current_bpm)
            # Consider a reasonable max diff for normalization, e.g., 30 BPM? 50 seems large.
            # Let's use 30: 0 diff = 1.0, 30+ diff = 0.0
            max_relevant_bpm_diff = 30.0 
            bpm_match_score = max(0, 1 - (bpm_diff / max_relevant_bpm_diff))
            
            # Combined score (weights can be tuned)
            # Give key slightly more weight than BPM
            match_score = (key_match_score * 0.6) + (bpm_match_score * 0.4)
            
            if match_score > best_score:
                best_score = match_score
                best_match_idx = positional_idx # Store the positional index
        
        return best_match_idx
    
    def create_sorted_playlist(self, start_index: Optional[int] = None) -> Optional[List[int]]:
        """Create a sorted playlist starting from the specified track (using positional index)."""
        if self.tracks is None or self.tracks.empty:
            print("Error: No tracks loaded to create a playlist.")
            return None
            
        num_tracks = len(self.tracks)
        if num_tracks == 0:
            print("Playlist is empty.")
            return []
            
        # Validate start_index if provided
        if start_index is not None:
            if not (0 <= start_index < num_tracks):
                print(f"Error: Provided start_index {start_index} is out of bounds (0-{num_tracks-1}). Finding best opener instead.")
                start_index = None
        
        # If no valid start index, find a good opener
        if start_index is None:
            start_index = self.find_best_opener()
            if start_index is None: # Could happen if find_best_opener failed
                 print("Error: Could not determine a starting track. Aborting sort.")
                 return None
            
        # Use positional indices throughout
        sorted_indices = [start_index]
        remaining_indices = list(range(num_tracks))
        remaining_indices.remove(start_index)
        
        current_track_positional_idx = start_index
        
        # Continue while we have tracks remaining
        while remaining_indices:
            current_track_dict = self.get_track_by_index(current_track_positional_idx)
            if current_track_dict is None:
                 print(f"Error: Could not retrieve data for track index {current_track_positional_idx}. Aborting.")
                 return None # Or handle differently
                 
            # Try to find a good transition using primary neighbors
            next_index = self.find_best_transition(current_track_dict, remaining_indices, allow_secondary=False)
            transition_type = "Primary Key Match"
            
            # If no primary match found, try secondary neighbors
            if next_index is None:
                next_index = self.find_best_transition(current_track_dict, remaining_indices, allow_secondary=True)
                transition_type = "Secondary Key Match"
            
            # If still no harmonic match, find the closest BPM among remaining
            if next_index is None:
                transition_type = "Fallback: Closest BPM"
                min_bpm_diff = float('inf')
                fallback_idx = None
                current_bpm = current_track_dict.get('BPM')
                if current_bpm is not None:
                    for idx in remaining_indices:
                        next_track_bpm = self.tracks.iloc[idx].get('BPM')
                        if next_track_bpm is not None:
                            diff = abs(next_track_bpm - current_bpm)
                            if diff < min_bpm_diff:
                                min_bpm_diff = diff
                                fallback_idx = idx
                
                # If we found a closest BPM track, use it. Otherwise, just take the first remaining.
                if fallback_idx is not None:
                     next_index = fallback_idx
                elif remaining_indices: # Ensure list isn't empty
                     next_index = remaining_indices[0]
                else:
                     # Should not happen if loop condition is correct, but defensively:
                     break 
            
            # Debugging print (optional)
            print(f"Transition: {current_track_dict['Track']} -> {self.get_track_by_index(next_index)['Track']} (via {transition_type})")
            
            sorted_indices.append(next_index)
            remaining_indices.remove(next_index)
            current_track_positional_idx = next_index
        
        return sorted_indices
    
    def export_sorted_playlist(self, sorted_indices: List[int], output_file: str) -> None:
        """Export the sorted playlist (using positional indices) to a CSV file."""
        if self.tracks is None:
             print("Error: Tracks not loaded. Cannot export.")
             return
        if not sorted_indices:
            print("Warning: No sorted indices provided or playlist is empty. Nothing to export.")
            return
            
        try:
            # Use positional indices with iloc
            sorted_tracks_df = self.tracks.iloc[sorted_indices].copy()
            
            # Overwrite the existing '#' column or create it if it doesn't exist
            # This ensures the '#' column reflects the NEW sorted order.
            sorted_tracks_df["#"] = range(1, len(sorted_tracks_df) + 1)

            # If the original '#' column was not the first one, ensure it is now.
            if "#" in sorted_tracks_df.columns:
                cols = sorted_tracks_df.columns.tolist()
                if cols[0] != "#":  # Check if '#' is already the first column
                    cols.remove("#")
                    cols.insert(0, "#")
                    sorted_tracks_df = sorted_tracks_df[cols]
            
            # Optionally remove temporary columns like 'opener_score'
            if 'opener_score' in sorted_tracks_df.columns:
                 sorted_tracks_df = sorted_tracks_df.drop(columns=['opener_score'])
                 
            sorted_tracks_df.to_csv(output_file, index=False, quoting=csv.QUOTE_NONNUMERIC)
            print(f"Sorted playlist exported to {output_file}")
        except Exception as e:
            print(f"Error exporting playlist to {output_file}: {e}")
        
    def print_transition_path(self, sorted_indices: List[int]) -> None:
        """Print the Camelot and BPM transition paths for visualization."""
        if self.tracks is None:
             print("Error: Tracks not loaded. Cannot print path.")
             return
        if not sorted_indices:
            print("Playlist is empty. No path to print.")
            return
            
        camelot_path = []
        bpm_path = []
        track_names = []
        
        print("\n--- Transition Path ---")
        print(" # | Track Name                      | Camelot | BPM")
        print("--|---------------------------------|---------|-----")
        
        max_name_len = 30 # Max length for track name column
        
        for i, idx in enumerate(sorted_indices):
            track = self.get_track_by_index(idx)
            if track:
                cmlt = track.get('Camelot', 'N/A')
                bpm = track.get('BPM', 'N/A')
                name = track.get('Track', 'Unknown Track')
                
                camelot_path.append(str(cmlt))
                bpm_path.append(f"{bpm:.0f}" if isinstance(bpm, (int, float)) and not pd.isna(bpm) else str(bpm))
                track_names.append(name)
                
                # Truncate long names for display
                display_name = (name[:max_name_len-3] + '...') if len(name) > max_name_len else name
                print(f"{i+1:<2} | {display_name:<{max_name_len}} | {str(cmlt):<7} | {bpm_path[-1]}")
            else:
                print(f"{i+1:<2} | Error retrieving track index {idx}")
                camelot_path.append("ERR")
                bpm_path.append("ERR")
                track_names.append("Error")

        print("\nCamelot Sequence:")
        print(" → ".join(camelot_path))
        
        print("\nBPM Sequence:")
        print(" → ".join(bpm_path))
        print("-----------------------")

# %% [markdown]
# ## Command-Line Main Function (for reference)
#
# This is the `main` function used when running the script from the command line with `argparse`. We won't call this directly in the notebook, but it's here for completeness.

# %%
def main():
    parser = argparse.ArgumentParser(description='Sort a playlist based on Camelot wheel and audio features')
    parser.add_argument('input_file', help='Input CSV file with playlist data')
    parser.add_argument('-o', '--output', default='sorted_playlist.csv', help='Output CSV file')
    # Ensure start index is treated as positional index (0-based)
    parser.add_argument('-s', '--start', type=int, help='Track positional index (0-based) to start with. If omitted, finds best opener.') 
    parser.add_argument('-v', '--verbose', action='store_true', help='Show transition paths')
    
    # In a script, sys.exit() is fine. In a notebook, it can kill the kernel.
    # The class methods now return None or raise exceptions on critical errors.
    try:
        args = parser.parse_args()
        
        sorter = PlaylistSorter(args.input_file)
        # Check if sorter initialized correctly (tracks loaded)
        if sorter.tracks is None:
             print("Initialization failed. Exiting.")
             # sys.exit(1) # Avoid sys.exit in notebook context if possible
             return # Exit the main function
             
        sorted_indices = sorter.create_sorted_playlist(args.start)
        
        if sorted_indices is not None:
            sorter.export_sorted_playlist(sorted_indices, args.output)
            if args.verbose:
                sorter.print_transition_path(sorted_indices)
        else:
             print("Failed to create sorted playlist.")
             
    except Exception as e:
         # Catch potential errors during argument parsing or execution
         print(f"An error occurred in main: {e}")
         # sys.exit(1)

# Standard script execution guard (won't run in notebook cell execution)
# if __name__ == "__main__":
#     main()

# %% [markdown]
# ## Generating the Input CSV Data
#
# This script requires a CSV file containing track data, including `Track`, `Camelot`, `BPM`, and `Energy` columns.
#
# A convenient way to get this data for a Spotify playlist is using the **Spotify Playlist Analyzer** tool available at:
#
# [https://songdata.io/spotify-playlist-analysis](https://songdata.io/spotify-playlist-analysis)
#
# **How to use it:**
#
# 1.  Go to the website.
# 2.  Paste the link (URL) of your Spotify playlist into the input field.
# 3.  Click "Analyze Playlist".
# 4.  The tool will process the playlist and display a table with various audio features, including Key, Camelot, BPM, Energy, Danceability, Popularity, etc.
# 5.  **Convert the HTML table to CSV:** The easiest way is usually to:
#     *   Select the entire table content on the webpage.
#     *   Copy it (Ctrl+C or Cmd+C).
#     *   Paste it into a spreadsheet program (like Google Sheets, Microsoft Excel, LibreOffice Calc).
#     *   Save or export the sheet as a CSV file (e.g., `your_playlist_data.csv`).
#
# Make sure the resulting CSV file has the necessary column headers (`Track`, `Camelot`, `BPM`, `Energy`). You might need to adjust the header names slightly after pasting if they don't match exactly.

# %% [markdown]
# ## Input Data Format Requirements
#
# Ensure your input CSV file (e.g., the one generated from `songdata.io` and saved) has at least the following columns:
#
# *   `Track`: The name/title of the track (string).
# *   `Camelot`: The Camelot key (e.g., '6A', '12B', '7A') (string).
# *   `BPM`: Beats Per Minute (numeric).
# *   `Energy`: Energy level (numeric, often 0-1 or 0-10, the script assumes higher is more energetic).
#
# **Important:** The values in the `BPM` and `Energy` columns *must* be numeric. Text or missing values in these columns will cause errors or lead to tracks being dropped.
#
# Optional columns used:
#
# *   `Popularity`: Track popularity (numeric, e.g., 0-100) used for finding the opener.
#
# Other columns like `Duration`, `Key`, `Acousticness`, etc., will be kept in the output file but are not directly used in the sorting logic defined here.

# %% [markdown]
# ## Using the PlaylistSorter in the Notebook
#
# Instead of using command-line arguments, we'll set the configuration variables directly in the next cell and then instantiate and use the `PlaylistSorter`.

# %%
# --- Configuration --- 
# <<< CHANGE THESE VALUES >>>
input_csv_file = 'unsorted_input.csv'  # IMPORTANT: Replace with the actual path to your CSV file
output_csv_file = 'sorted_output.csv' # Name for the output file

# Set to a specific 0-based index (e.g., 0, 1, 2...) to force start track,
# or set to None to let the script find the best opener automatically.
start_track_index = None 

show_verbose_path = True # Set to True to print the transition paths, False to hide them
# ---------------------

# --- Execution ---
print(f"Attempting to sort playlist from: {input_csv_file}")

try:
    # 1. Initialize the sorter (loads data)
    sorter = PlaylistSorter(input_csv_file)
    
    # Check if initialization was successful (tracks were loaded)
    if sorter.tracks is not None and not sorter.tracks.empty:
        print(f"Successfully loaded {len(sorter.tracks)} tracks.")
        
        # 2. Create the sorted list of indices
        print("Sorting playlist...")
        sorted_indices = sorter.create_sorted_playlist(start_track_index)
        
        if sorted_indices is not None:
            print(f"Sorting complete. Playlist has {len(sorted_indices)} tracks.")
            
            # 3. Export the sorted playlist
            sorter.export_sorted_playlist(sorted_indices, output_csv_file)
            
            # 4. Optionally print the transition path
            if show_verbose_path:
                sorter.print_transition_path(sorted_indices)
        else:
            print("Could not generate sorted playlist indices.")
            
    else:
        # Error message already printed by _load_tracks or __init__
        print("Playlist sorting aborted due to initialization errors.")

except FileNotFoundError:
    # This might be redundant if _load_tracks handles it, but good as a fallback
    print(f"Error: Input file not found at '{input_csv_file}'")
    print("Please ensure the file exists and the path is correct in the configuration cell.")
except ValueError as ve:
    # Catch ValueErrors raised during initialization or processing
    print(f"Configuration or Data Error: {ve}")
except Exception as e:
    print(f"An unexpected error occurred during notebook execution: {e}")
    # You might want to print traceback for debugging
    # import traceback
    # traceback.print_exc()
# Out:
# Attempting to sort playlist from: unsorted_input.csv
# Successfully loaded 322 tracks.
# Sorting playlist...
# Selected opener: Track 'Dekha Hazaro Dafaa' (Index: 302) with score 6.00
# Transition: Dekha Hazaro Dafaa -> Banjaara (via Primary Key Match)
# Transition: Banjaara -> Javeda Zindagi-Tose Naina Lage (via Primary Key Match)
# Transition: Javeda Zindagi-Tose Naina Lage -> Saware (via Primary Key Match)
# Transition: Saware -> Saware (From "Phantom") (via Primary Key Match)
# Transition: Saware (From "Phantom") -> Tere Naina (via Primary Key Match)
# Transition: Tere Naina -> Chale Aana (From "De De Pyaar De") (via Primary Key Match)
# Transition: Chale Aana (From "De De Pyaar De") -> Ishq Shava (via Primary Key Match)
# Transition: Ishq Shava -> Hasi - Male Version (via Primary Key Match)
# Transition: Hasi - Male Version -> Hua Hain Aaj Pehli Baar (via Primary Key Match)
# Transition: Hua Hain Aaj Pehli Baar -> Tujhko Jo Paaya (From "Crook") (via Primary Key Match)
# Transition: Tujhko Jo Paaya (From "Crook") -> Alvida (via Primary Key Match)
# Transition: Alvida -> Hawa Banke (via Primary Key Match)
# Transition: Hawa Banke -> Wat Wat Wat (via Primary Key Match)
# Transition: Wat Wat Wat -> Humdard (via Primary Key Match)
# Transition: Humdard -> Ae Re Sakhi (via Primary Key Match)
# Transition: Ae Re Sakhi -> Jiyein Kyun (via Primary Key Match)
# Transition: Jiyein Kyun -> Ya Rabba (From "Salaam-E-Ishq") (via Primary Key Match)
# Transition: Ya Rabba (From "Salaam-E-Ishq") -> Abhi Abhi (via Primary Key Match)
# Transition: Abhi Abhi -> Abhi Abhi (via Primary Key Match)
# Transition: Abhi Abhi -> Tere Bina (via Primary Key Match)
# Transition: Tere Bina -> Jashn-E-Bahaaraa (via Primary Key Match)
# Transition: Jashn-E-Bahaaraa -> Sun Le Re (Reprise) (via Primary Key Match)
# Transition: Sun Le Re (Reprise) -> Uff Teri Adaa (via Primary Key Match)
# Transition: Uff Teri Adaa -> I Am In Love (via Primary Key Match)
# Transition: I Am In Love -> Ali Maula (via Primary Key Match)
# Transition: Ali Maula -> Abhi Mujh Mein Kahin (via Primary Key Match)
# Transition: Abhi Mujh Mein Kahin -> Moh Moh Ke Dhaage (Male) (via Primary Key Match)
# Transition: Moh Moh Ke Dhaage (Male) -> Moh Moh Ke Dhaage (Female) (via Primary Key Match)
# Transition: Moh Moh Ke Dhaage (Female) -> Bakhuda Tumhi Ho (via Primary Key Match)
# Transition: Bakhuda Tumhi Ho -> Ay Hairathe (via Primary Key Match)
# Transition: Ay Hairathe -> Chand Sifarish (via Primary Key Match)
# Transition: Chand Sifarish -> Kyon (via Primary Key Match)
# Transition: Kyon -> Intezaar (via Primary Key Match)
# Transition: Intezaar -> Tum Tak (via Primary Key Match)
# Transition: Tum Tak -> Noor E Khuda (via Primary Key Match)
# Transition: Noor E Khuda -> Halka Halka (via Primary Key Match)
# Transition: Halka Halka -> Pee Loon (via Primary Key Match)
# Transition: Pee Loon -> Dil Diyan Gallan (via Primary Key Match)
# Transition: Dil Diyan Gallan -> Kaun Mera (via Primary Key Match)
# Transition: Kaun Mera -> Aazaadiyan (Pairon Ki Bediyan) (via Primary Key Match)
# Transition: Aazaadiyan (Pairon Ki Bediyan) -> Ek Dil Ek Jaan (From "Padmaavat") (via Primary Key Match)
# Transition: Ek Dil Ek Jaan (From "Padmaavat") -> Kaun Mera (via Primary Key Match)
# Transition: Kaun Mera -> Shaayraana (via Primary Key Match)
# Transition: Shaayraana -> Saibo (via Primary Key Match)
# Transition: Saibo -> Saathiyaa (via Primary Key Match)
# Transition: Saathiyaa -> Kabira (via Primary Key Match)
# Transition: Kabira -> Alvida (via Primary Key Match)
# Transition: Alvida -> Mera Pehla Pehla Pyaar (via Primary Key Match)
# Transition: Mera Pehla Pehla Pyaar -> Piya O Re Piya - Sad Version (via Primary Key Match)
# Transition: Piya O Re Piya - Sad Version -> Mera Mann Kehne Laga (via Primary Key Match)
# Transition: Mera Mann Kehne Laga -> Zehnaseeb (via Primary Key Match)
# Transition: Zehnaseeb -> Phir Le Aya Dil - Reprise (via Primary Key Match)
# Transition: Phir Le Aya Dil - Reprise -> Iktara (via Primary Key Match)
# Transition: Iktara -> Nazm Nazm (via Primary Key Match)
# Transition: Nazm Nazm -> Mast Magan (via Primary Key Match)
# Transition: Mast Magan -> Dekho Na (via Primary Key Match)
# Transition: Dekho Na -> Safar (via Primary Key Match)
# Transition: Safar -> Afeemi (From "Meri Pyaari Bindu ") (via Primary Key Match)
# Transition: Afeemi (From "Meri Pyaari Bindu ") -> Khabar Nahi (via Primary Key Match)
# Transition: Khabar Nahi -> Ye Tune Kya Kiya (via Primary Key Match)
# Transition: Ye Tune Kya Kiya -> Dil Kya Kare (via Primary Key Match)
# Transition: Dil Kya Kare -> Raat Ke Dhai Baje (via Primary Key Match)
# Transition: Raat Ke Dhai Baje -> Mehrama (via Primary Key Match)
# Transition: Mehrama -> Such Keh Raha Hai (via Primary Key Match)
# Transition: Such Keh Raha Hai -> Darkhaast (feat. Arijit Singh, Sunidhi Chauhan) (via Primary Key Match)
# Transition: Darkhaast (feat. Arijit Singh, Sunidhi Chauhan) -> Is This Love (via Primary Key Match)
# Transition: Is This Love -> Chiraiyya (via Primary Key Match)
# Transition: Chiraiyya -> Kaise Ab Kahein Acoustic (via Primary Key Match)
# Transition: Kaise Ab Kahein Acoustic -> Kanha - Unplugged (via Primary Key Match)
# Transition: Kanha - Unplugged -> Ye Tune Kya Kiya - Arijit Singh Version (via Primary Key Match)
# Transition: Ye Tune Kya Kiya - Arijit Singh Version -> Te Amo (Reprise) (via Primary Key Match)
# Transition: Te Amo (Reprise) -> Be Intehaan (via Primary Key Match)
# Transition: Be Intehaan -> Second Hand Jawaani (via Primary Key Match)
# Transition: Second Hand Jawaani -> Yaariyaan - Male Vocals (via Primary Key Match)
# Transition: Yaariyaan - Male Vocals -> Jhoom (via Primary Key Match)
# Transition: Jhoom -> Tu Jo Mila (via Primary Key Match)
# Transition: Tu Jo Mila -> Tum Mile (via Primary Key Match)
# Transition: Tum Mile -> Maula Mere Maula (via Primary Key Match)
# Transition: Maula Mere Maula -> Raabta (via Primary Key Match)
# Transition: Raabta -> Challa (via Primary Key Match)
# Transition: Challa -> Tu Hi Meri Shab Hai - From "Gangster" (via Primary Key Match)
# Transition: Tu Hi Meri Shab Hai - From "Gangster" -> Pehli Baar (via Primary Key Match)
# Transition: Pehli Baar -> Kehna Hi Kya - From "Bombay" (via Primary Key Match)
# Transition: Kehna Hi Kya - From "Bombay" -> Haareya (From "Meri Pyaari Bindu ") (via Primary Key Match)
# Transition: Haareya (From "Meri Pyaari Bindu ") -> Disco Disco (via Primary Key Match)
# Transition: Disco Disco -> Tu Jo Hain (From "Mr. X") (via Primary Key Match)
# Transition: Tu Jo Hain (From "Mr. X") -> Jiya Re (via Primary Key Match)
# Transition: Jiya Re -> Mere Rashke Qamar (via Primary Key Match)
# Transition: Mere Rashke Qamar -> Nashe Si Chadh Gayi (via Primary Key Match)
# Transition: Nashe Si Chadh Gayi -> Kya Karoon? (From "Wake Up Sid ") (via Primary Key Match)
# Transition: Kya Karoon? (From "Wake Up Sid ") -> Agar Main Kahoon (via Primary Key Match)
# Transition: Agar Main Kahoon -> Hairat (via Primary Key Match)
# Transition: Hairat -> Dekhte Dekhte (via Primary Key Match)
# Transition: Dekhte Dekhte -> Chahun Main Ya Naa (via Primary Key Match)
# Transition: Chahun Main Ya Naa -> Labon Ko (via Primary Key Match)
# Transition: Labon Ko -> Adhoore (via Primary Key Match)
# Transition: Adhoore -> Locha-E-Ulfat (via Primary Key Match)
# Transition: Locha-E-Ulfat -> In Dino (via Primary Key Match)
# Transition: In Dino -> Matargashti (via Primary Key Match)
# Transition: Matargashti -> Chaleya (From "Jawan") (via Primary Key Match)
# Transition: Chaleya (From "Jawan") -> Kesariya (From "Brahmastra") (via Primary Key Match)
# Transition: Kesariya (From "Brahmastra") -> Tere Naina (via Primary Key Match)
# Transition: Tere Naina -> Tumse Hi Tumse (via Primary Key Match)
# Transition: Tumse Hi Tumse -> Laaree Chootee (via Primary Key Match)
# Transition: Laaree Chootee -> Dil Darbadar (via Primary Key Match)
# Transition: Dil Darbadar -> Kaise Mein Kahun Tujhse (via Primary Key Match)
# Transition: Kaise Mein Kahun Tujhse -> Galliyan (via Primary Key Match)
# Transition: Galliyan -> Teri Fariyad (via Primary Key Match)
# Transition: Teri Fariyad -> Sunn Raha Hai (Female) (via Primary Key Match)
# Transition: Sunn Raha Hai (Female) -> Piya Aaye Na (via Primary Key Match)
# Transition: Piya Aaye Na -> Kuchh Toh Hua Hai (via Primary Key Match)
# Transition: Kuchh Toh Hua Hai -> Teri Deewani (via Primary Key Match)
# Transition: Teri Deewani -> Jee Le Zaraa (via Primary Key Match)
# Transition: Jee Le Zaraa -> Hale Dil (via Primary Key Match)
# Transition: Hale Dil -> Manchala (via Primary Key Match)
# Transition: Manchala -> Dil To Bachcha Hai (via Primary Key Match)
# Transition: Dil To Bachcha Hai -> Soch Na Sake (via Primary Key Match)
# Transition: Soch Na Sake -> Roke Na Ruke Naina (From "Badrinath Ki Dulhania") (via Primary Key Match)
# Transition: Roke Na Ruke Naina (From "Badrinath Ki Dulhania") -> Zaalima (via Primary Key Match)
# Transition: Zaalima -> Rabba Main Toh Mar Gaya Oye (via Primary Key Match)
# Transition: Rabba Main Toh Mar Gaya Oye -> Apna Bana Le (via Primary Key Match)
# Transition: Apna Bana Le -> Tu Hi Hai (via Primary Key Match)
# Transition: Tu Hi Hai -> Abhi Kuch Dino Se (via Primary Key Match)
# Transition: Abhi Kuch Dino Se -> Tum Jo Aaye (From "Once Upon A Time In Mumbaai") (via Primary Key Match)
# Transition: Tum Jo Aaye (From "Once Upon A Time In Mumbaai") -> Mora Saiyyan (via Primary Key Match)
# Transition: Mora Saiyyan -> Tu Hai (via Primary Key Match)
# Transition: Tu Hai -> Jag Ghoomeya (via Primary Key Match)
# Transition: Jag Ghoomeya -> Tu Hi Mera (via Primary Key Match)
# Transition: Tu Hi Mera -> Rishte Naate - From "De Dana Dan" (via Primary Key Match)
# Transition: Rishte Naate - From "De Dana Dan" -> Saiyaara (via Primary Key Match)
# Transition: Saiyaara -> Zaroorat (via Primary Key Match)
# Transition: Zaroorat -> Lae Dooba (via Primary Key Match)
# Transition: Lae Dooba -> Hai Rama (via Primary Key Match)
# Transition: Hai Rama -> Naina (via Primary Key Match)
# Transition: Naina -> Shukran Allah (via Primary Key Match)
# Transition: Shukran Allah -> Heeriye (feat. Arijit Singh) (via Primary Key Match)
# Transition: Heeriye (feat. Arijit Singh) -> Shukran Allah - MTV Unplugged Version (via Primary Key Match)
# Transition: Shukran Allah - MTV Unplugged Version -> Kun Faya Kun (via Primary Key Match)
# Transition: Kun Faya Kun -> Mere Nishaan (via Primary Key Match)
# Transition: Mere Nishaan -> Sajde (via Primary Key Match)
# Transition: Sajde -> Manmarziyan (via Primary Key Match)
# Transition: Manmarziyan -> Zindagi Do Pal Ki (via Primary Key Match)
# Transition: Zindagi Do Pal Ki -> Dil Kyun Yeh Mera (From "Kites") (via Primary Key Match)
# Transition: Dil Kyun Yeh Mera (From "Kites") -> Sooraj Ki Baahon Mein (via Primary Key Match)
# Transition: Sooraj Ki Baahon Mein -> Teri Jhuki Nazar (via Primary Key Match)
# Transition: Teri Jhuki Nazar -> Phir Se Ud Chala (via Primary Key Match)
# Transition: Phir Se Ud Chala -> Te Amo (Duet) (via Primary Key Match)
# Transition: Te Amo (Duet) -> Gulabi (via Primary Key Match)
# Transition: Gulabi -> Pyaar Ke Pal (via Primary Key Match)
# Transition: Pyaar Ke Pal -> Piyu Bole (via Primary Key Match)
# Transition: Piyu Bole -> Raabta (Kehte Hain Khuda Ne) (via Primary Key Match)
# Transition: Raabta (Kehte Hain Khuda Ne) -> Samjhawan (From "Humpty Sharma Ki Dulhania") (via Primary Key Match)
# Transition: Samjhawan (From "Humpty Sharma Ki Dulhania") -> Luka Chuppi (via Primary Key Match)
# Transition: Luka Chuppi -> Tere Hawaale (From "Laal Singh Chaddha") (via Primary Key Match)
# Transition: Tere Hawaale (From "Laal Singh Chaddha") -> Nazrein Milaana Nazrein Churaana (via Primary Key Match)
# Transition: Nazrein Milaana Nazrein Churaana -> Soniyo (via Primary Key Match)
# Transition: Soniyo -> Gallan Goodiyaan (via Primary Key Match)
# Transition: Gallan Goodiyaan -> Ghungroo (From "War") (via Primary Key Match)
# Transition: Ghungroo (From "War") -> Banjaara (via Primary Key Match)
# Transition: Banjaara -> Banjaara (From "Ek Villain") (via Primary Key Match)
# Transition: Banjaara (From "Ek Villain") -> Zaroori Tha (via Primary Key Match)
# Transition: Zaroori Tha -> Phero Na Najariya (via Primary Key Match)
# Transition: Phero Na Najariya -> Bandook Meri Laila (feat. Raftaar, Sidharth Malhotra) (via Primary Key Match)
# Transition: Bandook Meri Laila (feat. Raftaar, Sidharth Malhotra) -> Pasoori (via Primary Key Match)
# Transition: Pasoori -> Labb Par Aaye (via Primary Key Match)
# Transition: Labb Par Aaye -> Tujhe Bhula Diya (via Primary Key Match)
# Transition: Tujhe Bhula Diya -> Milne Hai Mujhse Aayi (via Primary Key Match)
# Transition: Milne Hai Mujhse Aayi -> Zara Zara (via Primary Key Match)
# Transition: Zara Zara -> Khwahishein (via Primary Key Match)
# Transition: Khwahishein -> Deewana Kar Raha Hai (via Primary Key Match)
# Transition: Deewana Kar Raha Hai -> Hasi - Female Version (via Primary Key Match)
# Transition: Hasi - Female Version -> Darmiyaan (via Primary Key Match)
# Transition: Darmiyaan -> O Meri Jaan (via Primary Key Match)
# Transition: O Meri Jaan -> Kali Kali Zulfon Ke - Extended Version (via Primary Key Match)
# Transition: Kali Kali Zulfon Ke - Extended Version -> Beete Lamhein (via Primary Key Match)
# Transition: Beete Lamhein -> Ishq Bulaava (via Primary Key Match)
# Transition: Ishq Bulaava -> Sab Tera (via Primary Key Match)
# Transition: Sab Tera -> Tadap Tadap (via Primary Key Match)
# Transition: Tadap Tadap -> Itni Si Baat Hain (From "Azhar") (via Primary Key Match)
# Transition: Itni Si Baat Hain (From "Azhar") -> Piya O Re Piya (via Primary Key Match)
# Transition: Piya O Re Piya -> Tum Ko (via Primary Key Match)
# Transition: Tum Ko -> Khudaya Khair (via Primary Key Match)
# Transition: Khudaya Khair -> Kabhi Neem Neem (via Primary Key Match)
# Transition: Kabhi Neem Neem -> Tere Bin (via Primary Key Match)
# Transition: Tere Bin -> Aise Kyun (via Primary Key Match)
# Transition: Aise Kyun -> O Saathi Re (via Primary Key Match)
# Transition: O Saathi Re -> Kurbaan Hua (via Primary Key Match)
# Transition: Kurbaan Hua -> Ae Zindagi Gale Laga Le - Take, 1 (via Primary Key Match)
# Transition: Ae Zindagi Gale Laga Le - Take, 1 -> Pareshaan (via Primary Key Match)
# Transition: Pareshaan -> Dil Ibaadat (via Primary Key Match)
# Transition: Dil Ibaadat -> Falak Tak (via Primary Key Match)
# Transition: Falak Tak -> Khamoshiyan (From "Khamoshiyan") (via Primary Key Match)
# Transition: Khamoshiyan (From "Khamoshiyan") -> Khamoshiyan (via Primary Key Match)
# Transition: Khamoshiyan -> Saanson Ko (From "Zid") (via Primary Key Match)
# Transition: Saanson Ko (From "Zid") -> Tu Har Lamha (via Primary Key Match)
# Transition: Tu Har Lamha -> O Meri Jaan (via Primary Key Match)
# Transition: O Meri Jaan -> Maahi Ve (via Primary Key Match)
# Transition: Maahi Ve -> Bolna (From "Kapoor & Sons (Since 1921)") (via Primary Key Match)
# Transition: Bolna (From "Kapoor & Sons (Since 1921)") -> O Rangrez (From "Bhaag Milkha Bhaag") (via Primary Key Match)
# Transition: O Rangrez (From "Bhaag Milkha Bhaag") -> Pardesi (via Primary Key Match)
# Transition: Pardesi -> Zindagi Kuch Toh Bata (Reprise) (via Primary Key Match)
# Transition: Zindagi Kuch Toh Bata (Reprise) -> Yaaron (via Primary Key Match)
# Transition: Yaaron -> Saudebazi (Encore) (via Primary Key Match)
# Transition: Saudebazi (Encore) -> Sawaar Loon (via Primary Key Match)
# Transition: Sawaar Loon -> Mora Saiyaan - Khamaaj (via Primary Key Match)
# Transition: Mora Saiyaan - Khamaaj -> Jeena Jeena (via Primary Key Match)
# Transition: Jeena Jeena -> Saaiyaan (via Primary Key Match)
# Transition: Saaiyaan -> Kaise Ab Kahein - From "Gutar Gu" (via Primary Key Match)
# Transition: Kaise Ab Kahein - From "Gutar Gu" -> Chan Kitthan (From "Chan Kitthan") (via Primary Key Match)
# Transition: Chan Kitthan (From "Chan Kitthan") -> O Bedardeya (From "Tu Jhoothi Main Makkaar") (via Primary Key Match)
# Transition: O Bedardeya (From "Tu Jhoothi Main Makkaar") -> Yoon Shabnami (via Primary Key Match)
# Transition: Yoon Shabnami -> Mann Kunto Maula (via Primary Key Match)
# Transition: Mann Kunto Maula -> Humdard (via Primary Key Match)
# Transition: Humdard -> Bahara (via Primary Key Match)
# Transition: Bahara -> Aas Paas Khuda (via Primary Key Match)
# Transition: Aas Paas Khuda -> Tune Jo Na Kaha (via Primary Key Match)
# Transition: Tune Jo Na Kaha -> Main Dhoondne Ko Zamaane Mein (via Primary Key Match)
# Transition: Main Dhoondne Ko Zamaane Mein -> Bulleya (via Primary Key Match)
# Transition: Bulleya -> Ek Din Teri Raahon (via Primary Key Match)
# Transition: Ek Din Teri Raahon -> Jeene Laga Hoon (via Primary Key Match)
# Transition: Jeene Laga Hoon -> Kabhi Kabhi Aditi (via Primary Key Match)
# Transition: Kabhi Kabhi Aditi -> Enna Sona (via Primary Key Match)
# Transition: Enna Sona -> Sanam Re (From "Sanam Re") (via Primary Key Match)
# Transition: Sanam Re (From "Sanam Re") -> Hey Ya ! (via Primary Key Match)
# Transition: Hey Ya ! -> Dooriyan (via Primary Key Match)
# Transition: Dooriyan -> Baarish (via Primary Key Match)
# Transition: Baarish -> Sapna Jahan (From "Brothers") (via Primary Key Match)
# Transition: Sapna Jahan (From "Brothers") -> Suno- Na Sangemarmar (From "Youngistaan) (via Primary Key Match)
# Transition: Suno- Na Sangemarmar (From "Youngistaan) -> Agar Tum Saath Ho (From "Tamasha") (via Primary Key Match)
# Transition: Agar Tum Saath Ho (From "Tamasha") -> Agar Tum Saath Ho (via Primary Key Match)
# Transition: Agar Tum Saath Ho -> Tera Hone Laga Hoon (via Primary Key Match)
# Transition: Tera Hone Laga Hoon -> Ajab Si (via Primary Key Match)
# Transition: Ajab Si -> Aye Khuda (via Primary Key Match)
# Transition: Aye Khuda -> Achha Lagta Hai (via Primary Key Match)
# Transition: Achha Lagta Hai -> Ghodey Pe Sawaar (From "Qala") (via Primary Key Match)
# Transition: Ghodey Pe Sawaar (From "Qala") -> Tu Hi Re - Bombay / Soundtrack Version (via Primary Key Match)
# Transition: Tu Hi Re - Bombay / Soundtrack Version -> Har Kisi Ko (via Primary Key Match)
# Transition: Har Kisi Ko -> Laal Ishq (via Primary Key Match)
# Transition: Laal Ishq -> In Dino - Refresh Version (via Primary Key Match)
# Transition: In Dino - Refresh Version -> Shubhaarambh (via Primary Key Match)
# Transition: Shubhaarambh -> Shubhaarambh (via Primary Key Match)
# Transition: Shubhaarambh -> Luteron Ka Lutera Version - Kalank Title - From "Kalank" (via Primary Key Match)
# Transition: Luteron Ka Lutera Version - Kalank Title - From "Kalank" -> Kalank - Title Track (via Primary Key Match)
# Transition: Kalank - Title Track -> Aashiyan (via Primary Key Match)
# Transition: Aashiyan -> Daaru Desi (via Primary Key Match)
# Transition: Daaru Desi -> Bekhauff (via Primary Key Match)
# Transition: Bekhauff -> London Thumakda (via Primary Key Match)
# Transition: London Thumakda -> Bairi Piya - Devdas / Soundtrack Version (via Primary Key Match)
# Transition: Bairi Piya - Devdas / Soundtrack Version -> Lagan Laagi Re (via Primary Key Match)
# Transition: Lagan Laagi Re -> Sajna Ji Vaari Vaari (via Primary Key Match)
# Transition: Sajna Ji Vaari Vaari -> Dekh Lena (via Primary Key Match)
# Transition: Dekh Lena -> Bheegi Bheegi - From "Gangster" (via Primary Key Match)
# Transition: Bheegi Bheegi - From "Gangster" -> Pehli Baar Mohabbat (via Primary Key Match)
# Transition: Pehli Baar Mohabbat -> Guzarish (via Primary Key Match)
# Transition: Guzarish -> Guzarish (From "Ghajini") (via Primary Key Match)
# Transition: Guzarish (From "Ghajini") -> Bekhayali (Arijit Singh Version) [From "Kabir Singh"] (via Primary Key Match)
# Transition: Bekhayali (Arijit Singh Version) [From "Kabir Singh"] -> Ambarsariya (via Primary Key Match)
# Transition: Ambarsariya -> Kholo Kholo (via Primary Key Match)
# Transition: Kholo Kholo -> Le Le Mazaa Le (via Primary Key Match)
# Transition: Le Le Mazaa Le -> Kyun Dil Mera - From "Paharganj" (via Primary Key Match)
# Transition: Kyun Dil Mera - From "Paharganj" -> Bin Tere (via Primary Key Match)
# Transition: Bin Tere -> Arziyan (via Primary Key Match)
# Transition: Arziyan -> Saawali Si Raat (via Primary Key Match)
# Transition: Saawali Si Raat -> Ilahi (Reprise) (via Primary Key Match)
# Transition: Ilahi (Reprise) -> Tose Naina (via Primary Key Match)
# Transition: Tose Naina -> Hoor (via Primary Key Match)
# Transition: Hoor -> Monta Re (via Primary Key Match)
# Transition: Monta Re -> Bhare Naina (via Primary Key Match)
# Transition: Bhare Naina -> Mann Mera (via Primary Key Match)
# Transition: Mann Mera -> Tu Hi Hai (Ali Zafar Version) [From "Dear Zindagi"] (via Primary Key Match)
# Transition: Tu Hi Hai (Ali Zafar Version) [From "Dear Zindagi"] -> Tera Rastaa Chhodoon Na (via Primary Key Match)
# Transition: Tera Rastaa Chhodoon Na -> Jiyein Kyun (via Primary Key Match)
# Transition: Jiyein Kyun -> Tujhe Kitna Chahne Lage (via Primary Key Match)
# Transition: Tujhe Kitna Chahne Lage -> Humdard (via Primary Key Match)
# Transition: Humdard -> O Saiyyan (via Primary Key Match)
# Transition: O Saiyyan -> Tere Pyaar Mein (via Primary Key Match)
# Transition: Tere Pyaar Mein -> Kitni Baatein (via Primary Key Match)
# Transition: Kitni Baatein -> Naina (via Primary Key Match)
# Transition: Naina -> Aise Kyun - Ghazal Version (via Primary Key Match)
# Transition: Aise Kyun - Ghazal Version -> Masha-Allah (via Primary Key Match)
# Transition: Masha-Allah -> Mar Jawaan (via Primary Key Match)
# Transition: Mar Jawaan -> Baarish (via Primary Key Match)
# Transition: Baarish -> Nazar Na Lag Jaaye (From "Stree") (via Primary Key Match)
# Transition: Nazar Na Lag Jaaye (From "Stree") -> Behka (via Primary Key Match)
# Transition: Behka -> Phir Mohabbat (via Primary Key Match)
# Transition: Phir Mohabbat -> Sunn Raha Hai (via Primary Key Match)
# Transition: Sunn Raha Hai -> Tujhe Sochta Hoon (via Primary Key Match)
# Transition: Tujhe Sochta Hoon -> Jab Se Tere Naina (via Primary Key Match)
# Transition: Jab Se Tere Naina -> Haule Haule (via Primary Key Match)
# Transition: Haule Haule -> O Saathi (via Primary Key Match)
# Transition: O Saathi -> Bheegi Si Bhaagi Si (via Primary Key Match)
# Transition: Bheegi Si Bhaagi Si -> Maana Ke Hum Yaar Nahin (via Primary Key Match)
# Transition: Maana Ke Hum Yaar Nahin -> Tujh Mein Rab Dikhta Hai (via Primary Key Match)
# Transition: Tujh Mein Rab Dikhta Hai -> Bawara Mann (via Primary Key Match)
# Transition: Bawara Mann -> Sajdaa (via Primary Key Match)
# Transition: Sajdaa -> Laal Peeli Akhiyaan (From "Teri Baaton Mein Aisa Uljha Jiya") (via Primary Key Match)
# Transition: Laal Peeli Akhiyaan (From "Teri Baaton Mein Aisa Uljha Jiya") -> Kyun Main Jaagoon (via Primary Key Match)
# Transition: Kyun Main Jaagoon -> Ravi (via Primary Key Match)
# Transition: Ravi -> Yun Hi (via Primary Key Match)
# Transition: Yun Hi -> Dil Beparvah - The Dewarists, Season 5 (via Primary Key Match)
# Transition: Dil Beparvah - The Dewarists, Season 5 -> Inn Lamhon Ke Daaman Mein (via Primary Key Match)
# Transition: Inn Lamhon Ke Daaman Mein -> Kahani (From "Laal Singh Chaddha") (via Primary Key Match)
# Transition: Kahani (From "Laal Singh Chaddha") -> Tu Hai Ki Nahi (via Primary Key Match)
# Transition: Tu Hai Ki Nahi -> Main Agar Kahoon (via Primary Key Match)
# Transition: Main Agar Kahoon -> Duaa (via Primary Key Match)
# Transition: Duaa -> Pani Da Rang - Male Vocals (via Primary Key Match)
# Transition: Pani Da Rang - Male Vocals -> Rab Ka Shukrana (via Primary Key Match)
# Transition: Rab Ka Shukrana -> O Re Piya (MTV Unplugged) (via Primary Key Match)
# Transition: O Re Piya (MTV Unplugged) -> Isq Risk (via Primary Key Match)
# Transition: Isq Risk -> Wajah Tum Ho (via Primary Key Match)
# Transition: Wajah Tum Ho -> Thodi Jagah (From "Marjaavaan") (via Primary Key Match)
# Transition: Thodi Jagah (From "Marjaavaan") -> Dil Cheez Tujhe Dedi (From "Airlift") (via Secondary Key Match)
# Transition: Dil Cheez Tujhe Dedi (From "Airlift") -> Jaan 'Nisaar (via Secondary Key Match)
# Transition: Jaan 'Nisaar -> Kahin To (via Primary Key Match)
# Transition: Kahin To -> Sunn Raha Hai (via Primary Key Match)
# Transition: Sunn Raha Hai -> Kaise Mujhe (via Primary Key Match)
# Transition: Kaise Mujhe -> Manwa Laage (via Secondary Key Match)
# Transition: Manwa Laage -> Sajni (From "Laapataa Ladies") (via Primary Key Match)
# Transition: Sajni (From "Laapataa Ladies") -> Saiyyan (via Primary Key Match)
# 233 | Ajab Si                        | 4B      | 118
# 234 | Aye Khuda                      | 4B      | 109
# 235 | Achha Lagta Hai                | 4B      | 102
# 236 | Ghodey Pe Sawaar (From "Qala") | 5B      | 102
# 237 | Tu Hi Re - Bombay / Soundtr... | 5B      | 100
# 238 | Har Kisi Ko                    | 5B      | 95
# 239 | Laal Ishq                      | 5B      | 106
# 240 | In Dino - Refresh Version      | 6B      | 106
# 241 | Shubhaarambh                   | 6B      | 115
# 242 | Shubhaarambh                   | 6B      | 115
# 243 | Luteron Ka Lutera Version -... | 6B      | 118
# 244 | Kalank - Title Track           | 6B      | 118
# 245 | Aashiyan                       | 6B      | 132
# 246 | Daaru Desi                     | 7B      | 139
# 247 | Bekhauff                       | 7B      | 140
# 248 | London Thumakda                | 8B      | 140
# 249 | Bairi Piya - Devdas / Sound... | 8B      | 138
# 250 | Lagan Laagi Re                 | 8B      | 138
# 251 | Sajna Ji Vaari Vaari           | 8B      | 144
# 252 | Dekh Lena                      | 8B      | 152
# 253 | Bheegi Bheegi - From "Gangs... | 8B      | 152
# 254 | Pehli Baar Mohabbat            | 8A      | 160
# 255 | Guzarish                       | 8A      | 170
# 256 | Guzarish (From "Ghajini")      | 8A      | 170
# 257 | Bekhayali (Arijit Singh Ver... | 8A      | 172
# 258 | Ambarsariya                    | 9A      | 180
# 259 | Kholo Kholo                    | 10A     | 170
# 260 | Le Le Mazaa Le                 | 10B     | 182
# 261 | Kyun Dil Mera - From "Pahar... | 11B     | 136
# 262 | Bin Tere                       | 11B     | 140
# 263 | Arziyan                        | 11B     | 140
# 264 | Saawali Si Raat                | 11B     | 140
# 265 | Ilahi (Reprise)                | 11B     | 132
# 266 | Tose Naina                     | 12B     | 140
# 267 | Hoor                           | 12B     | 150
# 268 | Monta Re                       | 12B     | 150
# 269 | Bhare Naina                    | 12A     | 147
# 270 | Mann Mera                      | 12A     | 192
# 271 | Tu Hi Hai (Ali Zafar Versio... | 12B     | 188
# 272 | Tera Rastaa Chhodoon Na        | 12B     | 170
# 273 | Jiyein Kyun                    | 12B     | 71
# 274 | Tujhe Kitna Chahne Lage        | 1B      | 70
# 275 | Humdard                        | 2B      | 162
# 276 | O Saiyyan                      | 2B      | 166
# 277 | Tere Pyaar Mein                | 3B      | 160
# 278 | Kitni Baatein                  | 4B      | 159
# 279 | Naina                          | 5B      | 160
# 280 | Aise Kyun - Ghazal Version     | 5B      | 152
# 281 | Masha-Allah                    | 5B      | 150
# 282 | Mar Jawaan                     | 6B      | 150
# 283 | Baarish                        | 6A      | 142
# 284 | Nazar Na Lag Jaaye (From "S... | 6A      | 174
# 285 | Behka                          | 5A      | 192
# 286 | Phir Mohabbat                  | 5A      | 200
# 287 | Sunn Raha Hai                  | 5A      | 82
# 288 | Tujhe Sochta Hoon              | 5A      | 81
# 289 | Jab Se Tere Naina              | 5A      | 80
# 290 | Haule Haule                    | 4A      | 90
# 291 | O Saathi                       | 4B      | 90
# 292 | Bheegi Si Bhaagi Si            | 4B      | 89
# 293 | Maana Ke Hum Yaar Nahin        | 4B      | 91
# 294 | Tujh Mein Rab Dikhta Hai       | 4B      | 85
# 295 | Bawara Mann                    | 4B      | 85
# 296 | Sajdaa                         | 4B      | 80
# 297 | Laal Peeli Akhiyaan (From "... | 4B      | 130
# 298 | Kyun Main Jaagoon              | 4B      | 130
# 299 | Ravi                           | 4B      | 128
# 300 | Yun Hi                         | 4B      | 140
# 301 | Dil Beparvah - The Dewarist... | 3B      | 138
# 302 | Inn Lamhon Ke Daaman Mein      | 3B      | 149
# 303 | Kahani (From "Laal Singh Ch... | 3B      | 150
# 304 | Tu Hai Ki Nahi                 | 3A      | 144
# 305 | Main Agar Kahoon               | 4A      | 147
# 306 | Duaa                           | 4A      | 138
# 307 | Pani Da Rang - Male Vocals     | 4A      | 135
# 308 | Rab Ka Shukrana                | 3A      | 122
# 309 | O Re Piya (MTV Unplugged)      | 3A      | 110
# 310 | Isq Risk                       | 3A      | 105
# 311 | Wajah Tum Ho                   | 4A      | 104
# 312 | Thodi Jagah (From "Marjaava... | 5A      | 107
# 313 | Dil Cheez Tujhe Dedi (From ... | 7A      | 105
# 314 | Jaan 'Nisaar                   | 6B      | 92
# 315 | Kahin To                       | 6B      | 91
# 316 | Sunn Raha Hai                  | 6B      | 83
# 317 | Kaise Mujhe                    | 6B      | 82
# 318 | Manwa Laage                    | 8B      | 81
# 319 | Sajni (From "Laapataa Ladies") | 8B      | 80
# 320 | Saiyyan                        | 8B      | 75
# 321 | Naina Da Kya Kasoor            | 11B     | 63
# 322 | Galliyan (From "Ek Villain")   | 3A      | 90
#
# Camelot Sequence:
# 12A → 12A → 12A → 11A → 11A → 11A → 11A → 11A → 11A → 11A → 11B → 11B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 10B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 9B → 8B → 8B → 8B → 8B → 8B → 8B → 8A → 8A → 8A → 9A → 9A → 10A → 10A → 9A → 9A → 8A → 8A → 8A → 8A → 8A → 8A → 8B → 8B → 8B → 8B → 8B → 8B → 8B → 8B → 8A → 8A → 8A → 8A → 8A → 8A → 9A → 9A → 9A → 9A → 10A → 10A → 11A → 11B → 11B → 11B → 11B → 11B → 12B → 12B → 12B → 12B → 1B → 1B → 1B → 1B → 1A → 2A → 2B → 2B → 2B → 3B → 3B → 3B → 3B → 3B → 3B → 2B → 2B → 2B → 1B → 1B → 1B → 1B → 12B → 12B → 12B → 12B → 12B → 12B → 11B → 11B → 11B → 11A → 11A → 12A → 12A → 1A → 12A → 11A → 10A → 10A → 10A → 10A → 10A → 10A → 10A → 9A → 9B → 9B → 9B → 9B → 9B → 9B → 10B → 10B → 10B → 10B → 9B → 8B → 8B → 7B → 7A → 7A → 7A → 7A → 7A → 7A → 7A → 7A → 7A → 7A → 7A → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7B → 7A → 7A → 7A → 6A → 6A → 6A → 6A → 6A → 6A → 6A → 5A → 5A → 5B → 5B → 4B → 4B → 4B → 4B → 5B → 5B → 5B → 5B → 6B → 6B → 6B → 6B → 6B → 6B → 7B → 7B → 8B → 8B → 8B → 8B → 8B → 8B → 8A → 8A → 8A → 8A → 9A → 10A → 10B → 11B → 11B → 11B → 11B → 